# %% [markdown]
# # Meta-learning classification features: Model

# %% [markdown]
# **Imports**

# %%
# imports

import numpy as np
import pandas as pd
import torch
import torch.nn as nn

import random
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, recall_score

# %% [markdown]
# **Classification model**

# %%
class ClassificationModel():

    def __init__(self, target_label):

        self.all_features = ["darker", "gradient", "reddish", "metallic", "colorful", "black", "black_thin", "dominating_color", "color_bin_1", 
                             "color_bin_2", "color_bin_3", "color_bin_4", "color_bin_5", "color_bin_6", "color_bin_7", "color_bin_8", "color_bin_9", 
                             "color_entropy", "rough", "dominating_texture", "texture_0", "texture_1", "texture_2", "texture_3", "texture_4", 
                             "texture_5", "texture_6", "texture_7", "texture_8", "texture_9", "rough_entropy", "lengthy", "number_lengthy_objects", 
                             "lengthy_aspect_ratio", "rel_length", "in_shape", "roundness", "hu_moment_1", "hu_moment_2", "hu_moment_3", 
                             "hu_moment_4", "hu_moment_5", "hu_moment_6", "hu_moment_7"]

        self.target_label = target_label
        self.dataset = self.load_dataset()
        self.x_train, self.x_test, self.y_train, self.y_test = self.create_train_test_data()
        self.measures = {}

    def load_dataset(self):

        dataset = pd.read_csv("samples_0_6935_all_defects.csv", sep = ",")
        dataset.drop(columns = ["Unnamed: 0", "image_number", "defect_number"], inplace = True)
        dataset.dropna(inplace = True)

        return dataset
    
    def create_train_test_data(self):

        # Create target labels:
        target_class_df = self.dataset.copy()
        target_class_df["target_label"] = target_class_df["label"].apply(lambda x: 1 if x == self.target_label else 0)

        # Apply train test split:
        target_class_df = target_class_df.sort_values(by = "target_label", ascending = False)
        number_of_defects = target_class_df["target_label"].sum()
        target_class_df_1 = target_class_df.iloc[:number_of_defects, :]
        negative_samples = random.sample(range(number_of_defects, len(target_class_df)), number_of_defects)
        target_class_df_0 = target_class_df.iloc[negative_samples, :]
        df = pd.concat([target_class_df_1, target_class_df_0], ignore_index=True)
        x = df.loc[:, self.all_features]
        y = df.loc[:, "target_label"]
        x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

        return x_train, x_test, y_train, y_test

    def select_features(self, features):

        x_train = self.x_train.loc[:, features]
        x_test = self.x_test.loc[:, features]

        return x_train, x_test
    
    def evaluate(self, y_pred):

        accuracy = accuracy_score(self.y_test, y_pred)
        recall = recall_score(self.y_test, y_pred, average=None)[1]

        return accuracy, recall
    
    def run(self, features, number_of_forests=1):

        # Check whether feature combination already exists in measures dictionary:
        feature_combination = ", ".join(sorted(features))
        if feature_combination in self.measures:
            accuracy, recall = self.measures[feature_combination]
        else:

            # Generate train dataset with selected features: 
            x_train, x_test = self.select_features(features)

            # Perform the random forest classifier: 
            for i in range(number_of_forests):
                clf = RandomForestClassifier(n_estimators=50, criterion= "entropy", random_state=i, max_depth=10)
                clf.fit(x_train, self.y_train)
                y_pred = clf.predict(x_test)
                if i == 0:
                    y_pred_final = y_pred
                else:
                    y_pred_final = np.array([1 if y_pred[i] == 1 or y_pred_final[i] == 1 else 0 for i in range(len(y_pred))])

            # Evaluate and store results:
            accuracy, recall = self.evaluate(y_pred_final)
            self.measures[feature_combination] = (accuracy, recall)

        print(f"Feature set: {features}, \nAccuracy: {accuracy}, \nRecall: {recall}\n")
        return recall

# %% [markdown]
# **Environment**

# %%
class State():

    def __init__(self, state, action=None):

        if not action == None:
            state = self.bitflip(state, action)

        self.binary = state.float()

    def bitflip(self, state, action):

        adjusted_state = state.binary.clone()

        for index in action:
            if state.binary[index] == 0:
                adjusted_state[index] = 1
            else:
                adjusted_state[index] = 0

        return adjusted_state


class Dacl10kEnvironment():

    def __init__(self, classifier, initial_state=None):

        self.all_features = ["darker", "gradient", "reddish", "metallic", "colorful", "black", "black_thin", "dominating_color", "color_bin_1", 
                             "color_bin_2", "color_bin_3", "color_bin_4", "color_bin_5", "color_bin_6", "color_bin_7", "color_bin_8", "color_bin_9", 
                             "color_entropy", "rough", "dominating_texture", "texture_0", "texture_1", "texture_2", "texture_3", "texture_4", 
                             "texture_5", "texture_6", "texture_7", "texture_8", "texture_9", "rough_entropy", "lengthy", "number_lengthy_objects", 
                             "lengthy_aspect_ratio", "rel_length", "in_shape", "roundness", "hu_moment_1", "hu_moment_2", "hu_moment_3", 
                             "hu_moment_4", "hu_moment_5", "hu_moment_6", "hu_moment_7"]
        
        self.classifier = classifier
        self.features_dict = {i: feature for i, feature in enumerate(self.all_features)}
        self.statesize = len(self.all_features)

        self.initial_state = State(torch.FloatTensor([i % 2 for i in range(len(self.all_features))])) if initial_state == None else initial_state
        self.state = self.initial_state

        self.table = {}

    def step(self, action):

        next_state = State(self.state, action)
        self.state = next_state

        features_indices = [i for i, value in enumerate(self.state.binary.numpy()) if value == 1]
        features = [self.features_dict[i] for i in features_indices]
        reward = self.classifier.run(features)
        self.table[tuple([self.features_dict[i] for i, binary in enumerate(tuple(self.state.binary.detach().numpy())) if binary == 1])] = reward

        return next_state, reward

# %% [markdown]
# **Reinforcement Agent**

# %%
class FeedforwardNet(nn.Module):

    def __init__(self, env, device, hidden_size):

        super(FeedforwardNet, self).__init__()
        
        self.device = device
        self.statesize = env.statesize
        self.hidden_size = hidden_size
        
        self.hidden_layer = nn.Linear(self.statesize, self.hidden_size).to(self.device)
        self.output_layer = nn.Linear(self.hidden_size, self.statesize).to(self.device)
        self.sigmoid = nn.Sigmoid().to(self.device)

    def forward(self, input):

        x = self.hidden_layer(input)
        x = torch.relu(x)
        x = self.output_layer(x)
        x = self.sigmoid(x)

        return x


class ReinforcementAgent():

    def __init__(self, env):

        self.device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
        self.net = FeedforwardNet(env, self.device, 50)

        self.optimizer = torch.optim.Adam(self.net.parameters(),lr=0.01)

        self.exploration_chance = 0.2
        self.statesize = env.statesize

    def step(self, state):

        probabilities = self.net.forward(state.binary)
        #print(probabilities)
        probability_differences = torch.abs(state.binary - probabilities)
        _, action = torch.topk(probability_differences, random.randint(1, 3))
        action = action.tolist()

        # Exploration adjustments:
        for i, _ in enumerate(action):
            if random.random() < self.exploration_chance:
                action[i] = random.randint(0, self.statesize - 1)

        # If no feature remaining in action, include highest likelihood features
        if torch.sum(State(state, action).binary).item() < 1:
            action = None

        return action

    def update(self, reward):

        reward = torch.tensor(reward, dtype=torch.float32, requires_grad=True)
        #loss = -torch.log(reward)
        loss = torch.sqrt(1 - reward)
        #print(f"Loss: {loss}")

        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

# %% [markdown]
# **Train the reinforcement agent**

# %%
def plot_rewards(rewards):

    x = list(range(len(rewards)))

    moving_average_rewards = []
    window_size = 50
    for i in range(len(rewards)):
        start_index = max(0, i - window_size + 1)
        window = rewards[start_index:i + 1]
        moving_average_rewards.append(sum(window) / len(window))

    plt.figure(figsize=(10, 5))
    plt.plot(x, rewards, marker="o", linestyle="-", color="b")
    plt.plot(x, moving_average_rewards, linestyle="-", color="r")

    plt.title("Rewards")
    plt.xlabel("Epoch")
    plt.ylabel("Reward")
    plt.grid(True)

    plt.show()

def train_agent(classifier, initial_features=None, epochs=500):

    # Initialize variables:
    env = Dacl10kEnvironment(classifier)
    agent = ReinforcementAgent(env)

    state = env.initial_state
    rewards = []

    # Prepare initial state:
    if not initial_features == None:
        initial_state = State(torch.FloatTensor([feature in initial_features for feature in env.all_features]))
        env = Dacl10kEnvironment(classifier, initial_state=initial_state)

    # Run epochs:
    for i in range(epochs): 

        print(f"Epoch {i}")
        
        action = agent.step(state)
        #print(action)
        next_state, reward = env.step(action)
        agent.update(reward)
        state = next_state

        print(f"Reward: {reward}\n")
        rewards.append(reward)

    # Evaluate results:
    plot_rewards(rewards)
    best_feature_set = max(env.table, key=lambda k: env.table[k])
    print(f"Best Feature set: {best_feature_set}\nReward: {env.table[best_feature_set]}\n")

def random_monkey(classifier, repetitions=500):

    # Initialize variables:
    env = Dacl10kEnvironment(classifier)
    rewards = []

    # Run repetitions:
    for i in range(repetitions):

        print(f"Repitition {i}")
        
        random_binary = random.choices([0, 1], k=44)
        features_indices = [i for i, value in enumerate(random_binary) if value == 1]
        features = [env.features_dict[i] for i in features_indices]
        reward = classifier.run(features)
        rewards.append(reward)
        env.table[tuple([env.features_dict[i] for i, binary in enumerate(random_binary) if binary == 1])] = reward
    
    # Evaluate results:
    plot_rewards(rewards)
    best_feature_set = max(env.table, key=lambda k: env.table[k])
    print(f"Best Feature set: {best_feature_set}\nReward: {env.table[best_feature_set]}\n")

# %% [markdown]
# # Meta-learning classification features: Analysis

# %% [markdown]
# **Crack**

# %%
# Create a classifier for crack:

crack_classifier = ClassificationModel("Crack")

# %%
# Run classification on hypothesized features:

hypothesized_features_crack = ["black", "black_thin", "rough", "lengthy", "number_lengthy_objects", "lengthy_aspect_ratio", 
                                  "rel_length", "darker"] ## Insert hypothesized most relevant features here

crack_classifier.run(hypothesized_features_crack)
# Out:
# Feature set: ['black', 'black_thin', 'rough', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'rel_length', 'darker'],
# Accuracy: 0.6963434022257552,
# Recall: 0.748696558915537
# 0.748696558915537

# %%
# Apply meta-learning and compare with random choices:

train_agent(crack_classifier, initial_features=hypothesized_features_crack, epochs=500)
random_monkey(crack_classifier, repetitions=500)
# Out:
# Epoch 0
# Feature set: ['darker', 'black', 'black_thin', 'color_bin_1', 'rough', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'rel_length'],
# Accuracy: 0.6952835188129306,
# Recall: 0.7466110531803962
#
# Reward: 0.7466110531803962
#
# Epoch 1
# Feature set: ['darker', 'black_thin', 'color_bin_1', 'color_entropy', 'rough', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'rel_length', 'roundness'],
# Accuracy: 0.6974032856385798,
# Recall: 0.7591240875912408
#
# Reward: 0.7591240875912408
#
# Epoch 2
# Feature set: ['darker', 'black_thin', 'color_bin_1', 'color_bin_5', 'color_entropy', 'rough', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'rel_length', 'roundness'],
# Accuracy: 0.6926338102808691,
# Recall: 0.7570385818561001
#
# Reward: 0.7570385818561001
#
# Epoch 3
# Feature set: ['darker', 'black_thin', 'color_bin_1', 'color_bin_5', 'color_entropy', 'rough', 'dominating_texture', 'texture_6', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'roundness'],
# Accuracy: 0.7281399046104928,
# Recall: 0.7090719499478624
#
# Reward: 0.7090719499478624
#
# Epoch 4
# Feature set: ['darker', 'black_thin', 'color_bin_1', 'color_bin_2', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_entropy', 'rough', 'dominating_texture', 'texture_6', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'roundness'],
# Accuracy: 0.724960254372019,
# Recall: 0.6976016684045881
#
# Reward: 0.6976016684045881
#
# Epoch 5
# Feature set: ['darker', 'reddish', 'black_thin', 'color_bin_1', 'color_bin_2', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_entropy', 'rough', 'dominating_texture', 'texture_6', 'lengthy', 'number_lengthy_objects', 'roundness'],
# Accuracy: 0.7318494965553789,
# Recall: 0.7174139728884255
#
# Reward: 0.7174139728884255
#
# Epoch 6
# Feature set: ['darker', 'reddish', 'black_thin', 'color_bin_1', 'color_bin_2', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_entropy', 'rough', 'dominating_texture', 'texture_6', 'texture_7', 'lengthy', 'number_lengthy_objects', 'roundness'],
# Accuracy: 0.7429782723900371,
# Recall: 0.7330552659019812
#
# Reward: 0.7330552659019812
#
# Epoch 7
# Feature set: ['darker', 'reddish', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_entropy', 'dominating_texture', 'texture_6', 'texture_7', 'lengthy', 'number_lengthy_objects', 'roundness'],
# Accuracy: 0.7329093799682035,
# Recall: 0.7184567257559958
#
# Reward: 0.7184567257559958
#
# Epoch 8
# Feature set: ['darker', 'reddish', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_entropy', 'texture_6', 'lengthy', 'number_lengthy_objects', 'roundness'],
# Accuracy: 0.7058823529411765,
# Recall: 0.708029197080292
#
# Reward: 0.708029197080292
#
# Epoch 9
# Feature set: ['darker', 'reddish', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_entropy', 'texture_1', 'texture_6', 'texture_7', 'texture_8', 'lengthy', 'number_lengthy_objects', 'roundness'],
# Accuracy: 0.735559088500265,
# Recall: 0.7340980187695516
#
# Reward: 0.7340980187695516
#
# Epoch 10
# Feature set: ['darker', 'reddish', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_entropy', 'texture_1', 'texture_3', 'texture_6', 'texture_7', 'texture_8', 'lengthy', 'number_lengthy_objects', 'roundness'],
# Accuracy: 0.7291997880233174,
# Recall: 0.7132429614181439
#
# Reward: 0.7132429614181439
#
# Epoch 11
# Feature set: ['darker', 'reddish', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_entropy', 'texture_1', 'texture_2', 'texture_3', 'texture_6', 'texture_7', 'texture_8', 'number_lengthy_objects', 'roundness'],
# Accuracy: 0.7397986221515633,
# Recall: 0.7320125130344108
#
# Reward: 0.7320125130344108
#
# Epoch 12
# Feature set: ['darker', 'reddish', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_entropy', 'texture_1', 'texture_2', 'texture_3', 'texture_6', 'texture_7', 'texture_8', 'number_lengthy_objects', 'roundness', 'hu_moment_3', 'hu_moment_7'],
# Accuracy: 0.7403285638579756,
# Recall: 0.7278415015641293
#
# Reward: 0.7278415015641293
#
# Epoch 13
# Feature set: ['darker', 'reddish', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_5', 'color_bin_7', 'color_bin_8', 'color_entropy', 'dominating_texture', 'texture_1', 'texture_2', 'texture_3', 'texture_6', 'texture_7', 'texture_8', 'number_lengthy_objects', 'roundness', 'hu_moment_3', 'hu_moment_7'],
# Accuracy: 0.7366189719130896,
# Recall: 0.7309697601668405
#
# Reward: 0.7309697601668405
#
# Epoch 14
# Feature set: ['darker', 'reddish', 'colorful', 'dominating_color', 'color_bin_1', 'color_bin_5', 'color_bin_7', 'color_bin_8', 'color_entropy', 'dominating_texture', 'texture_1', 'texture_2', 'texture_3', 'texture_5', 'texture_6', 'texture_7', 'texture_8', 'number_lengthy_objects', 'roundness', 'hu_moment_3', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7493375728669847,
# Recall: 0.7413972888425443
#
# Reward: 0.7413972888425443
#
# Epoch 15
# Feature set: ['darker', 'reddish', 'colorful', 'dominating_color', 'color_bin_1', 'color_bin_5', 'color_bin_8', 'color_entropy', 'dominating_texture', 'texture_1', 'texture_2', 'texture_3', 'texture_5', 'texture_6', 'texture_7', 'texture_8', 'number_lengthy_objects', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_7'],
# Accuracy: 0.7493375728669847,
# Recall: 0.748696558915537
#
# Reward: 0.748696558915537
#
# Epoch 16
# Feature set: ['darker', 'reddish', 'colorful', 'dominating_color', 'color_bin_1', 'color_bin_5', 'color_bin_8', 'color_entropy', 'dominating_texture', 'texture_1', 'texture_2', 'texture_3', 'texture_6', 'texture_7', 'texture_8', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_7'],
# Accuracy: 0.7366189719130896,
# Recall: 0.7194994786235662
#
# Reward: 0.7194994786235662
#
# Epoch 17
# Feature set: ['darker', 'reddish', 'colorful', 'dominating_color', 'color_bin_1', 'color_bin_5', 'color_bin_8', 'color_entropy', 'dominating_texture', 'texture_0', 'texture_1', 'texture_2', 'texture_3', 'texture_5', 'texture_6', 'texture_7', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_7'],
# Accuracy: 0.7466878643349232,
# Recall: 0.7330552659019812
#
# Reward: 0.7330552659019812
#
# Epoch 18
# Feature set: ['darker', 'reddish', 'colorful', 'dominating_color', 'color_bin_1', 'color_bin_5', 'color_bin_8', 'color_entropy', 'texture_2', 'texture_3', 'texture_5', 'texture_6', 'texture_7', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_7'],
# Accuracy: 0.7408585055643879,
# Recall: 0.7247132429614181
#
# Reward: 0.7247132429614181
#
# Epoch 19
# Feature set: ['darker', 'colorful', 'color_bin_1', 'color_bin_5', 'color_bin_8', 'color_entropy', 'texture_1', 'texture_2', 'texture_3', 'texture_5', 'texture_6', 'texture_7', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_7'],
# Accuracy: 0.7371489136195019,
# Recall: 0.7174139728884255
#
# Reward: 0.7174139728884255
#
# Epoch 20
# Feature set: ['darker', 'reddish', 'colorful', 'black_thin', 'color_bin_1', 'color_bin_5', 'color_bin_7', 'color_bin_8', 'color_entropy', 'texture_1', 'texture_2', 'texture_3', 'texture_5', 'texture_6', 'texture_7', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_7'],
# Accuracy: 0.7408585055643879,
# Recall: 0.7299270072992701
#
# Reward: 0.7299270072992701
#
# Epoch 21
# Feature set: ['darker', 'reddish', 'colorful', 'black_thin', 'color_bin_5', 'color_bin_7', 'color_bin_8', 'color_entropy', 'rough', 'texture_1', 'texture_2', 'texture_3', 'texture_5', 'texture_6', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_7'],
# Accuracy: 0.7461579226285109,
# Recall: 0.7393117831074035
#
# Reward: 0.7393117831074035
#
# Epoch 22
# Feature set: ['darker', 'reddish', 'colorful', 'black_thin', 'color_bin_1', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_entropy', 'rough', 'texture_1', 'texture_2', 'texture_3', 'texture_5', 'texture_6', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_7'],
# Accuracy: 0.7488076311605724,
# Recall: 0.7455683003128258
#
# Reward: 0.7455683003128258
#
# Epoch 23
# Feature set: ['darker', 'reddish', 'colorful', 'black_thin', 'color_bin_1', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_entropy', 'rough', 'texture_2', 'texture_3', 'texture_6', 'roundness', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_7'],
# Accuracy: 0.7307896131425543,
# Recall: 0.7278415015641293
#
# Reward: 0.7278415015641293
#
# Epoch 24
# Feature set: ['darker', 'reddish', 'colorful', 'black_thin', 'color_bin_1', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_entropy', 'rough', 'texture_1', 'texture_2', 'texture_3', 'texture_6', 'roundness', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_7'],
# Accuracy: 0.7276099629040805,
# Recall: 0.7101147028154328
#
# Reward: 0.7101147028154328
#
# Epoch 25
# Feature set: ['darker', 'reddish', 'colorful', 'black_thin', 'color_bin_1', 'color_bin_2', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_entropy', 'rough', 'texture_1', 'texture_2', 'texture_3', 'texture_6', 'roundness', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_7'],
# Accuracy: 0.7286698463169051,
# Recall: 0.7101147028154328
#
# Reward: 0.7101147028154328
#
# Epoch 26
# Feature set: ['darker', 'reddish', 'colorful', 'black_thin', 'color_bin_1', 'color_bin_2', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_entropy', 'rough', 'texture_1', 'texture_2', 'texture_3', 'texture_6', 'texture_7', 'number_lengthy_objects', 'roundness', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_7'],
# Accuracy: 0.7450980392156863,
# Recall: 0.7340980187695516
#
# Reward: 0.7340980187695516
#
# Epoch 27
# Feature set: ['darker', 'reddish', 'colorful', 'black_thin', 'color_bin_1', 'color_bin_2', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_entropy', 'rough', 'texture_1', 'texture_2', 'texture_3', 'texture_6', 'texture_7', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'roundness', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_5', 'hu_moment_7'],
# Accuracy: 0.7466878643349232,
# Recall: 0.7299270072992701
#
# Reward: 0.7299270072992701
#
# Epoch 28
# Feature set: ['darker', 'reddish', 'colorful', 'black_thin', 'color_bin_1', 'color_bin_2', 'color_bin_5', 'color_bin_6', 'color_bin_8', 'color_entropy', 'rough', 'texture_1', 'texture_2', 'texture_3', 'texture_6', 'texture_7', 'number_lengthy_objects', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_5', 'hu_moment_7'],
# Accuracy: 0.7477477477477478,
# Recall: 0.7361835245046924
#
# Reward: 0.7361835245046924
#
# Epoch 29
# Feature set: ['darker', 'reddish', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_entropy', 'rough', 'texture_1', 'texture_2', 'texture_3', 'texture_6', 'texture_7', 'number_lengthy_objects', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_5', 'hu_moment_7'],
# Accuracy: 0.7514573396926338,
# Recall: 0.735140771637122
#
# Reward: 0.735140771637122
#
# Epoch 30
# Feature set: ['darker', 'reddish', 'colorful', 'black_thin', 'color_bin_1', 'color_bin_5', 'color_bin_7', 'color_bin_8', 'color_entropy', 'texture_1', 'texture_2', 'texture_3', 'texture_6', 'texture_7', 'number_lengthy_objects', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_5', 'hu_moment_7'],
# Accuracy: 0.7366189719130896,
# Recall: 0.7142857142857143
#
# Reward: 0.7142857142857143
#
# Epoch 31
# Feature set: ['darker', 'reddish', 'colorful', 'black_thin', 'color_bin_1', 'color_bin_5', 'color_bin_7', 'color_bin_8', 'color_entropy', 'texture_1', 'texture_2', 'texture_3', 'texture_6', 'texture_7', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_5', 'hu_moment_7'],
# Accuracy: 0.735559088500265,
# Recall: 0.721584984358707
#
# Reward: 0.721584984358707
#
# Epoch 32
# Feature set: ['darker', 'reddish', 'colorful', 'black_thin', 'color_bin_1', 'color_bin_5', 'color_bin_7', 'color_bin_8', 'color_entropy', 'texture_1', 'texture_2', 'texture_3', 'texture_6', 'texture_7', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_7'],
# Accuracy: 0.7339692633810281,
# Recall: 0.7132429614181439
#
# Reward: 0.7132429614181439
#
# Epoch 33
# Feature set: ['darker', 'reddish', 'colorful', 'black_thin', 'color_bin_1', 'color_bin_5', 'color_bin_7', 'color_bin_8', 'color_entropy', 'rough', 'texture_1', 'texture_2', 'texture_3', 'texture_5', 'texture_6', 'texture_7', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_7'],
# Accuracy: 0.7440381558028617,
# Recall: 0.7320125130344108
#
# Reward: 0.7320125130344108
#
# Epoch 34
# Feature set: ['darker', 'reddish', 'colorful', 'black_thin', 'color_bin_1', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_entropy', 'rough', 'texture_1', 'texture_2', 'texture_3', 'texture_5', 'texture_6', 'texture_7', 'roundness', 'hu_moment_1', 'hu_moment_7'],
# Accuracy: 0.7429782723900371,
# Recall: 0.7340980187695516
#
# Reward: 0.7340980187695516
#
# Epoch 35
# Feature set: ['reddish', 'colorful', 'black_thin', 'color_bin_1', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_entropy', 'texture_1', 'texture_2', 'texture_3', 'texture_5', 'texture_6', 'texture_7', 'roundness', 'hu_moment_1', 'hu_moment_2', 'hu_moment_7'],
# Accuracy: 0.7435082140964494,
# Recall: 0.7340980187695516
#
# Reward: 0.7340980187695516
#
# Epoch 36
# Feature set: ['colorful', 'black_thin', 'color_bin_1', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'texture_1', 'texture_2', 'texture_3', 'texture_5', 'texture_6', 'texture_7', 'roundness', 'hu_moment_1', 'hu_moment_2', 'hu_moment_7'],
# Accuracy: 0.7488076311605724,
# Recall: 0.7320125130344108
#
# Reward: 0.7320125130344108
#
# Epoch 37
# Feature set: ['colorful', 'black_thin', 'color_bin_1', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'texture_1', 'texture_2', 'texture_3', 'texture_5', 'texture_6', 'texture_7', 'texture_9', 'roundness', 'hu_moment_1', 'hu_moment_2', 'hu_moment_7'],
# Accuracy: 0.7456279809220986,
# Recall: 0.7236704900938478
#
# Reward: 0.7236704900938478
#
# Epoch 38
# Feature set: ['colorful', 'black_thin', 'color_bin_1', 'color_bin_4', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'texture_1', 'texture_3', 'texture_5', 'texture_6', 'texture_7', 'texture_9', 'roundness', 'hu_moment_1', 'hu_moment_2', 'hu_moment_7'],
# Accuracy: 0.7424483306836248,
# Recall: 0.721584984358707
#
# Reward: 0.721584984358707
#
# Epoch 39
# Feature set: ['reddish', 'colorful', 'black_thin', 'color_bin_1', 'color_bin_4', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_entropy', 'texture_1', 'texture_3', 'texture_5', 'texture_6', 'texture_7', 'texture_9', 'roundness', 'hu_moment_1', 'hu_moment_2', 'hu_moment_7'],
# Accuracy: 0.7435082140964494,
# Recall: 0.7330552659019812
#
# Reward: 0.7330552659019812
#
# Epoch 40
# Feature set: ['reddish', 'colorful', 'black_thin', 'color_bin_1', 'color_bin_4', 'color_bin_5', 'color_bin_6', 'color_bin_8', 'color_entropy', 'texture_1', 'texture_2', 'texture_3', 'texture_5', 'texture_6', 'texture_7', 'texture_9', 'roundness', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_7'],
# Accuracy: 0.7403285638579756,
# Recall: 0.7309697601668405
#
# Reward: 0.7309697601668405
#
# Epoch 41
# Feature set: ['reddish', 'colorful', 'black_thin', 'color_bin_1', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_8', 'color_entropy', 'texture_1', 'texture_2', 'texture_3', 'texture_5', 'texture_6', 'texture_7', 'roundness', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_7'],
# Accuracy: 0.7419183889772125,
# Recall: 0.735140771637122
#
# Reward: 0.735140771637122
#
# Epoch 42
# Feature set: ['reddish', 'colorful', 'black_thin', 'color_bin_1', 'color_bin_5', 'color_bin_6', 'color_bin_8', 'color_entropy', 'texture_1', 'texture_2', 'texture_3', 'texture_5', 'texture_6', 'texture_7', 'roundness', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_7'],
# Accuracy: 0.7413884472708002,
# Recall: 0.7267987486965589
#
# Reward: 0.7267987486965589
#
# Epoch 43
# Feature set: ['reddish', 'colorful', 'black_thin', 'color_bin_1', 'color_bin_5', 'color_bin_6', 'color_bin_8', 'color_entropy', 'texture_1', 'texture_2', 'texture_3', 'texture_5', 'texture_6', 'texture_7', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_7'],
# Accuracy: 0.7477477477477478,
# Recall: 0.7403545359749739
#
# Reward: 0.7403545359749739
#
# Epoch 44
# Feature set: ['reddish', 'colorful', 'black_thin', 'color_bin_1', 'color_bin_5', 'color_bin_7', 'color_bin_8', 'color_entropy', 'rough', 'texture_1', 'texture_2', 'texture_3', 'texture_5', 'texture_6', 'texture_7', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_7'],
# Accuracy: 0.7509273979862215,
# Recall: 0.7424400417101147
#
# Reward: 0.7424400417101147
#
# Epoch 45
# Feature set: ['reddish', 'colorful', 'black_thin', 'color_bin_1', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_entropy', 'rough', 'texture_1', 'texture_2', 'texture_3', 'texture_5', 'texture_6', 'texture_7', 'roundness', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_7'],
# Accuracy: 0.7456279809220986,
# Recall: 0.7413972888425443
#
# Reward: 0.7413972888425443
#
# Epoch 46
# Feature set: ['reddish', 'colorful', 'black_thin', 'color_bin_1', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_entropy', 'rough', 'texture_1', 'texture_2', 'texture_3', 'texture_5', 'texture_6', 'roundness', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_7'],
# Accuracy: 0.7488076311605724,
# Recall: 0.7424400417101147
#
# Reward: 0.7424400417101147
#
# Epoch 47
# Feature set: ['gradient', 'reddish', 'colorful', 'black_thin', 'color_bin_1', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_entropy', 'rough', 'texture_1', 'texture_2', 'texture_3', 'texture_5', 'texture_6', 'roundness', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_7'],
# Accuracy: 0.7567567567567568,
# Recall: 0.7507820646506778
#
# Reward: 0.7507820646506778
#
# Epoch 48
# Feature set: ['gradient', 'reddish', 'colorful', 'black_thin', 'color_bin_1', 'color_bin_2', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_entropy', 'rough', 'texture_1', 'texture_2', 'texture_3', 'texture_6', 'roundness', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_7'],
# Accuracy: 0.7424483306836248,
# Recall: 0.7340980187695516
#
# Reward: 0.7340980187695516
#
# Epoch 49
# Feature set: ['gradient', 'reddish', 'colorful', 'black_thin', 'color_bin_1', 'color_bin_2', 'color_bin_4', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_entropy', 'rough', 'texture_1', 'texture_2', 'texture_3', 'texture_6', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_5', 'hu_moment_7'],
# Accuracy: 0.735559088500265,
# Recall: 0.7194994786235662
#
# Reward: 0.7194994786235662
#
# Epoch 50
# Feature set: ['gradient', 'reddish', 'colorful', 'black_thin', 'color_bin_1', 'color_bin_2', 'color_bin_4', 'color_bin_5', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'rough', 'texture_1', 'texture_3', 'texture_6', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_5', 'hu_moment_7'],
# Accuracy: 0.7403285638579756,
# Recall: 0.7361835245046924
#
# Reward: 0.7361835245046924
#
# Epoch 51
# Feature set: ['gradient', 'reddish', 'colorful', 'black_thin', 'color_bin_1', 'color_bin_2', 'color_bin_4', 'color_bin_5', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_1', 'texture_2', 'texture_3', 'texture_6', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_5', 'hu_moment_7'],
# Accuracy: 0.7350291467938527,
# Recall: 0.721584984358707
#
# Reward: 0.721584984358707
#
# Epoch 52
# Feature set: ['gradient', 'reddish', 'colorful', 'black_thin', 'color_bin_1', 'color_bin_2', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_1', 'texture_2', 'texture_3', 'texture_6', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_5', 'hu_moment_7'],
# Accuracy: 0.7397986221515633,
# Recall: 0.7267987486965589
#
# Reward: 0.7267987486965589
#
# Epoch 53
# Feature set: ['darker', 'gradient', 'reddish', 'colorful', 'black_thin', 'color_bin_1', 'color_bin_2', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_entropy', 'rough', 'texture_1', 'texture_2', 'texture_3', 'texture_6', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_5', 'hu_moment_7'],
# Accuracy: 0.7440381558028617,
# Recall: 0.7413972888425443
#
# Reward: 0.7413972888425443
#
# Epoch 54
# Feature set: ['darker', 'reddish', 'colorful', 'black_thin', 'color_bin_1', 'color_bin_2', 'color_bin_5', 'color_bin_7', 'color_bin_8', 'color_entropy', 'rough', 'texture_1', 'texture_2', 'texture_3', 'texture_6', 'texture_7', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_5', 'hu_moment_7'],
# Accuracy: 0.7435082140964494,
# Recall: 0.7236704900938478
#
# Reward: 0.7236704900938478
#
# Epoch 55
# Feature set: ['darker', 'reddish', 'colorful', 'black_thin', 'color_bin_1', 'color_bin_2', 'color_bin_5', 'color_bin_7', 'color_bin_8', 'color_entropy', 'rough', 'texture_1', 'texture_2', 'texture_3', 'texture_6', 'texture_7', 'lengthy', 'number_lengthy_objects', 'roundness', 'hu_moment_1', 'hu_moment_5', 'hu_moment_7'],
# Accuracy: 0.7477477477477478,
# Recall: 0.735140771637122
#
# Reward: 0.735140771637122
#
# Epoch 56
# Feature set: ['darker', 'reddish', 'colorful', 'black_thin', 'color_bin_1', 'color_bin_2', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_entropy', 'rough', 'texture_1', 'texture_2', 'texture_3', 'texture_6', 'texture_7', 'lengthy', 'number_lengthy_objects', 'roundness', 'hu_moment_1', 'hu_moment_5', 'hu_moment_7'],
# Accuracy: 0.7456279809220986,
# Recall: 0.7340980187695516
#
# Reward: 0.7340980187695516
#
# Epoch 57
# Feature set: ['darker', 'reddish', 'colorful', 'black_thin', 'color_bin_1', 'color_bin_2', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_entropy', 'rough', 'texture_1', 'texture_2', 'texture_3', 'texture_6', 'texture_7', 'number_lengthy_objects', 'roundness', 'hu_moment_1', 'hu_moment_5', 'hu_moment_7'],
# Accuracy: 0.7599364069952306,
# Recall: 0.7507820646506778
#
# Reward: 0.7507820646506778
#
# Epoch 58
# Feature set: ['darker', 'reddish', 'colorful', 'black_thin', 'color_bin_1', 'color_bin_2', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_entropy', 'rough', 'texture_1', 'texture_2', 'texture_3', 'texture_6', 'texture_7', 'texture_9', 'number_lengthy_objects', 'roundness', 'hu_moment_1', 'hu_moment_5', 'hu_moment_7'],
# Accuracy: 0.7530471648118707,
# Recall: 0.7372262773722628
#
# Reward: 0.7372262773722628
#
# Epoch 59
# Feature set: ['darker', 'reddish', 'colorful', 'black_thin', 'color_bin_1', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_entropy', 'texture_1', 'texture_2', 'texture_3', 'texture_6', 'texture_7', 'texture_9', 'number_lengthy_objects', 'roundness', 'hu_moment_1', 'hu_moment_7'],
# Accuracy: 0.7456279809220986,
# Recall: 0.7194994786235662
#
# Reward: 0.7194994786235662
#
# Epoch 60
# Feature set: ['darker', 'reddish', 'colorful', 'black_thin', 'color_bin_1', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_entropy', 'texture_1', 'texture_2', 'texture_3', 'texture_5', 'texture_7', 'texture_9', 'number_lengthy_objects', 'roundness', 'hu_moment_1', 'hu_moment_7'],
# Accuracy: 0.7503974562798092,
# Recall: 0.7726798748696558
#
# Reward: 0.7726798748696558
#
# Epoch 61
# Feature set: ['darker', 'reddish', 'colorful', 'color_bin_1', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_entropy', 'texture_1', 'texture_2', 'texture_3', 'texture_5', 'texture_7', 'texture_9', 'number_lengthy_objects', 'roundness', 'hu_moment_1', 'hu_moment_7'],
# Accuracy: 0.7382087970323264,
# Recall: 0.7591240875912408
#
# Reward: 0.7591240875912408
#
# Epoch 62
# Feature set: ['darker', 'reddish', 'colorful', 'color_bin_1', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_entropy', 'texture_1', 'texture_2', 'texture_3', 'texture_5', 'texture_9', 'number_lengthy_objects', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_7'],
# Accuracy: 0.7429782723900371,
# Recall: 0.7737226277372263
#
# Reward: 0.7737226277372263
#
# Epoch 63
# Feature set: ['darker', 'reddish', 'colorful', 'black_thin', 'color_bin_1', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_entropy', 'rough', 'texture_1', 'texture_2', 'texture_3', 'texture_5', 'texture_9', 'number_lengthy_objects', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_7'],
# Accuracy: 0.7440381558028617,
# Recall: 0.7705943691345151
#
# Reward: 0.7705943691345151
#
# Epoch 64
# Feature set: ['darker', 'reddish', 'colorful', 'black_thin', 'color_bin_1', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_entropy', 'rough', 'texture_1', 'texture_2', 'texture_3', 'texture_6', 'texture_9', 'number_lengthy_objects', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_7'],
# Accuracy: 0.7562268150503445,
# Recall: 0.7413972888425443
#
# Reward: 0.7413972888425443
#
# Epoch 65
# Feature set: ['darker', 'reddish', 'colorful', 'color_bin_1', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_entropy', 'rough', 'texture_1', 'texture_2', 'texture_3', 'texture_6', 'texture_9', 'number_lengthy_objects', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_7'],
# Accuracy: 0.7466878643349232,
# Recall: 0.7257559958289885
#
# Reward: 0.7257559958289885
#
# Epoch 66
# Feature set: ['darker', 'reddish', 'colorful', 'black_thin', 'color_bin_1', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_entropy', 'texture_1', 'texture_2', 'texture_3', 'texture_6', 'texture_9', 'number_lengthy_objects', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_5', 'hu_moment_7'],
# Accuracy: 0.7339692633810281,
# Recall: 0.7142857142857143
#
# Reward: 0.7142857142857143
#
# Epoch 67
# Feature set: ['darker', 'reddish', 'colorful', 'black_thin', 'color_bin_1', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_entropy', 'rough', 'texture_1', 'texture_2', 'texture_3', 'texture_6', 'texture_7', 'number_lengthy_objects', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_5', 'hu_moment_7'],
# Accuracy: 0.7419183889772125,
# Recall: 0.7340980187695516
#
# Reward: 0.7340980187695516
#
# Epoch 68
# Feature set: ['darker', 'reddish', 'colorful', 'black_thin', 'color_bin_1', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_entropy', 'texture_1', 'texture_2', 'texture_3', 'texture_6', 'texture_7', 'number_lengthy_objects', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_5', 'hu_moment_7'],
# Accuracy: 0.7334393216746158,
# Recall: 0.7090719499478624
#
# Reward: 0.7090719499478624
#
# Epoch 69
# Feature set: ['darker', 'reddish', 'colorful', 'black_thin', 'color_bin_1', 'color_bin_4', 'color_bin_5', 'color_bin_7', 'color_entropy', 'texture_1', 'texture_2', 'texture_3', 'texture_6', 'texture_7', 'number_lengthy_objects', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_5', 'hu_moment_7'],
# Accuracy: 0.7419183889772125,
# Recall: 0.7247132429614181
#
# Reward: 0.7247132429614181
#
# Epoch 70
# Feature set: ['darker', 'reddish', 'colorful', 'black_thin', 'color_bin_1', 'color_bin_4', 'color_bin_5', 'color_bin_7', 'color_entropy', 'rough', 'texture_1', 'texture_2', 'texture_3', 'texture_6', 'texture_7', 'number_lengthy_objects', 'in_shape', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_5', 'hu_moment_7'],
# Accuracy: 0.7519872813990461,
# Recall: 0.7330552659019812
#
# Reward: 0.7330552659019812
#
# Epoch 71
# Feature set: ['darker', 'reddish', 'colorful', 'black_thin', 'color_bin_1', 'color_bin_4', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_entropy', 'rough', 'texture_1', 'texture_2', 'texture_3', 'texture_6', 'texture_7', 'number_lengthy_objects', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_5', 'hu_moment_7'],
# Accuracy: 0.7424483306836248,
# Recall: 0.7320125130344108
#
# Reward: 0.7320125130344108
#
# Epoch 72
# Feature set: ['darker', 'reddish', 'colorful', 'black_thin', 'color_bin_1', 'color_bin_4', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_entropy', 'rough', 'texture_1', 'texture_2', 'texture_3', 'texture_6', 'texture_7', 'number_lengthy_objects', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_5', 'hu_moment_7'],
# Accuracy: 0.7408585055643879,
# Recall: 0.7194994786235662
#
# Reward: 0.7194994786235662
#
# Epoch 73
# Feature set: ['darker', 'reddish', 'colorful', 'black_thin', 'color_bin_1', 'color_bin_4', 'color_bin_5', 'color_bin_7', 'color_bin_8', 'color_entropy', 'rough', 'texture_1', 'texture_3', 'texture_6', 'texture_7', 'number_lengthy_objects', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_5', 'hu_moment_7'],
# Accuracy: 0.7403285638579756,
# Recall: 0.7226277372262774
#
# Reward: 0.7226277372262774
#
# Epoch 74
# Feature set: ['darker', 'reddish', 'colorful', 'color_bin_1', 'color_bin_5', 'color_bin_7', 'color_bin_8', 'color_entropy', 'rough', 'texture_1', 'texture_2', 'texture_3', 'texture_6', 'texture_7', 'number_lengthy_objects', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_5', 'hu_moment_7'],
# Accuracy: 0.7435082140964494,
# Recall: 0.7288842544316997
#
# Reward: 0.7288842544316997
#
# Epoch 75
# Feature set: ['darker', 'reddish', 'colorful', 'color_bin_1', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_entropy', 'texture_1', 'texture_2', 'texture_3', 'texture_6', 'texture_7', 'number_lengthy_objects', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_5', 'hu_moment_7'],
# Accuracy: 0.7461579226285109,
# Recall: 0.7257559958289885
#
# Reward: 0.7257559958289885
#
# Epoch 76
# Feature set: ['darker', 'reddish', 'colorful', 'color_bin_1', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_entropy', 'texture_1', 'texture_2', 'texture_3', 'texture_5', 'texture_6', 'texture_7', 'number_lengthy_objects', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_5', 'hu_moment_7'],
# Accuracy: 0.7525172231054584,
# Recall: 0.7612095933263816
#
# Reward: 0.7612095933263816
#
# Epoch 77
# Feature set: ['darker', 'reddish', 'colorful', 'color_bin_1', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_entropy', 'rough', 'texture_2', 'texture_3', 'texture_5', 'texture_6', 'texture_7', 'texture_9', 'number_lengthy_objects', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_5', 'hu_moment_7'],
# Accuracy: 0.7519872813990461,
# Recall: 0.7413972888425443
#
# Reward: 0.7413972888425443
#
# Epoch 78
# Feature set: ['darker', 'reddish', 'colorful', 'color_bin_1', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_entropy', 'rough', 'texture_1', 'texture_2', 'texture_3', 'texture_5', 'texture_6', 'texture_7', 'texture_9', 'number_lengthy_objects', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_5', 'hu_moment_7'],
# Accuracy: 0.7546369899311076,
# Recall: 0.7476538060479666
#
# Reward: 0.7476538060479666
#
# Epoch 79
# Feature set: ['darker', 'reddish', 'colorful', 'black_thin', 'color_bin_1', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_entropy', 'rough', 'texture_1', 'texture_2', 'texture_3', 'texture_5', 'texture_6', 'texture_7', 'texture_9', 'number_lengthy_objects', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_5', 'hu_moment_7'],
# Accuracy: 0.7562268150503445,
# Recall: 0.7507820646506778
#
# Reward: 0.7507820646506778
#
# Epoch 80
# Feature set: ['darker', 'reddish', 'colorful', 'black_thin', 'color_bin_1', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_entropy', 'rough', 'texture_1', 'texture_2', 'texture_3', 'texture_5', 'texture_6', 'texture_7', 'number_lengthy_objects', 'roundness', 'hu_moment_1', 'hu_moment_5', 'hu_moment_7'],
# Accuracy: 0.753577106518283,
# Recall: 0.7518248175182481
#
# Reward: 0.7518248175182481
#
# Epoch 81
# Feature set: ['darker', 'reddish', 'colorful', 'black_thin', 'color_bin_1', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_entropy', 'texture_1', 'texture_2', 'texture_3', 'texture_5', 'texture_6', 'texture_7', 'number_lengthy_objects', 'roundness', 'hu_moment_1', 'hu_moment_7'],
# Accuracy: 0.7488076311605724,
# Recall: 0.7372262773722628
#
# Reward: 0.7372262773722628
#
# Epoch 82
# Feature set: ['darker', 'reddish', 'colorful', 'black_thin', 'color_bin_1', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_entropy', 'texture_1', 'texture_2', 'texture_3', 'texture_5', 'texture_7', 'number_lengthy_objects', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_7'],
# Accuracy: 0.739268680445151,
# Recall: 0.7737226277372263
#
# Reward: 0.7737226277372263
#
# Epoch 83
# Feature set: ['darker', 'reddish', 'colorful', 'black_thin', 'color_bin_1', 'color_bin_5', 'color_bin_6', 'color_bin_8', 'color_entropy', 'rough', 'texture_1', 'texture_2', 'texture_3', 'texture_5', 'texture_6', 'texture_7', 'number_lengthy_objects', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_7'],
# Accuracy: 0.7477477477477478,
# Recall: 0.748696558915537
#
# Reward: 0.748696558915537
#
# Epoch 84
# Feature set: ['darker', 'reddish', 'colorful', 'black_thin', 'color_bin_1', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_8', 'color_entropy', 'rough', 'texture_1', 'texture_2', 'texture_3', 'texture_5', 'texture_6', 'texture_7', 'number_lengthy_objects', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_7'],
# Accuracy: 0.7493375728669847,
# Recall: 0.7372262773722628
#
# Reward: 0.7372262773722628
#
# Epoch 85
# Feature set: ['darker', 'reddish', 'colorful', 'black_thin', 'color_bin_1', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_8', 'color_entropy', 'rough', 'texture_2', 'texture_3', 'texture_5', 'texture_6', 'texture_7', 'number_lengthy_objects', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_7'],
# Accuracy: 0.7530471648118707,
# Recall: 0.7445255474452555
#
# Reward: 0.7445255474452555
#
# Epoch 86
# Feature set: ['darker', 'reddish', 'colorful', 'black_thin', 'color_bin_1', 'color_bin_5', 'color_bin_6', 'color_bin_8', 'color_entropy', 'rough', 'texture_1', 'texture_2', 'texture_3', 'texture_6', 'texture_7', 'number_lengthy_objects', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_7'],
# Accuracy: 0.7509273979862215,
# Recall: 0.7382690302398331
#
# Reward: 0.7382690302398331
#
# Epoch 87
# Feature set: ['darker', 'reddish', 'colorful', 'black_thin', 'color_bin_1', 'color_bin_5', 'color_bin_8', 'color_entropy', 'rough', 'texture_1', 'texture_2', 'texture_3', 'texture_7', 'number_lengthy_objects', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_7'],
# Accuracy: 0.730259671436142,
# Recall: 0.7466110531803962
#
# Reward: 0.7466110531803962
#
# Epoch 88
# Feature set: ['darker', 'reddish', 'colorful', 'color_bin_1', 'color_bin_5', 'color_bin_8', 'color_entropy', 'rough', 'texture_1', 'texture_2', 'texture_3', 'texture_6', 'texture_7', 'number_lengthy_objects', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_7'],
# Accuracy: 0.7440381558028617,
# Recall: 0.7330552659019812
#
# Reward: 0.7330552659019812
#
# Epoch 89
# Feature set: ['darker', 'reddish', 'colorful', 'black_thin', 'color_bin_1', 'color_bin_5', 'color_bin_8', 'color_entropy', 'rough', 'texture_1', 'texture_2', 'texture_3', 'texture_6', 'texture_7', 'number_lengthy_objects', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_5', 'hu_moment_7'],
# Accuracy: 0.739268680445151,
# Recall: 0.7320125130344108
#
# Reward: 0.7320125130344108
#
# Epoch 90
# Feature set: ['darker', 'colorful', 'black_thin', 'color_bin_1', 'color_bin_5', 'color_bin_6', 'color_bin_8', 'color_entropy', 'rough', 'texture_1', 'texture_2', 'texture_3', 'texture_6', 'texture_7', 'number_lengthy_objects', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_5', 'hu_moment_7'],
# Accuracy: 0.7429782723900371,
# Recall: 0.7267987486965589
#
# Reward: 0.7267987486965589
#
# Epoch 91
# Feature set: ['darker', 'reddish', 'colorful', 'black_thin', 'color_bin_1', 'color_bin_5', 'color_bin_6', 'color_bin_8', 'color_entropy', 'texture_1', 'texture_2', 'texture_3', 'texture_6', 'texture_7', 'number_lengthy_objects', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_5', 'hu_moment_7'],
# Accuracy: 0.735559088500265,
# Recall: 0.7153284671532847
#
# Reward: 0.7153284671532847
#
# Epoch 92
# Feature set: ['darker', 'reddish', 'colorful', 'black_thin', 'color_bin_1', 'color_bin_5', 'color_bin_7', 'color_bin_8', 'color_entropy', 'texture_1', 'texture_2', 'texture_3', 'texture_6', 'texture_7', 'number_lengthy_objects', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_5', 'hu_moment_7'],
# Accuracy: 0.7366189719130896,
# Recall: 0.7142857142857143
#
# Reward: 0.7142857142857143
#
# Epoch 93
# Feature set: ['darker', 'reddish', 'colorful', 'color_bin_1', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_entropy', 'texture_1', 'texture_2', 'texture_3', 'texture_6', 'texture_7', 'number_lengthy_objects', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_5', 'hu_moment_7'],
# Accuracy: 0.7461579226285109,
# Recall: 0.7257559958289885
#
# Reward: 0.7257559958289885
#
# Epoch 94
# Feature set: ['darker', 'reddish', 'colorful', 'black_thin', 'color_bin_1', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_entropy', 'texture_1', 'texture_2', 'texture_3', 'texture_6', 'texture_7', 'number_lengthy_objects', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_5', 'hu_moment_7'],
# Accuracy: 0.7397986221515633,
# Recall: 0.7288842544316997
#
# Reward: 0.7288842544316997
#
# Epoch 95
# Feature set: ['darker', 'reddish', 'colorful', 'black_thin', 'color_bin_1', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_entropy', 'texture_1', 'texture_2', 'texture_3', 'texture_6', 'texture_7', 'number_lengthy_objects', 'roundness', 'hu_moment_3', 'hu_moment_5', 'hu_moment_7'],
# Accuracy: 0.735559088500265,
# Recall: 0.7163712200208551
#
# Reward: 0.7163712200208551
#
# Epoch 96
# Feature set: ['darker', 'reddish', 'colorful', 'black_thin', 'color_bin_1', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_entropy', 'texture_1', 'texture_2', 'texture_3', 'texture_6', 'texture_7', 'number_lengthy_objects', 'roundness', 'hu_moment_3', 'hu_moment_5', 'hu_moment_7'],
# Accuracy: 0.735559088500265,
# Recall: 0.7101147028154328
#
# Reward: 0.7101147028154328
#
# Epoch 97
# Feature set: ['darker', 'reddish', 'colorful', 'black_thin', 'color_bin_1', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_entropy', 'texture_1', 'texture_2', 'texture_3', 'texture_6', 'texture_7', 'number_lengthy_objects', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_5', 'hu_moment_7'],
# Accuracy: 0.7334393216746158,
# Recall: 0.7090719499478624
#
# Reward: 0.7090719499478624
#
# Epoch 98
# Feature set: ['darker', 'reddish', 'colorful', 'black_thin', 'color_bin_1', 'color_bin_5', 'color_bin_7', 'color_bin_8', 'color_entropy', 'texture_1', 'texture_2', 'texture_3', 'texture_6', 'texture_7', 'number_lengthy_objects', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_5', 'hu_moment_7'],
# Accuracy: 0.7366189719130896,
# Recall: 0.7142857142857143
#
# Reward: 0.7142857142857143
#
# Epoch 99
# Feature set: ['darker', 'reddish', 'colorful', 'black_thin', 'color_bin_1', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_entropy', 'texture_1', 'texture_2', 'texture_3', 'texture_6', 'texture_7', 'number_lengthy_objects', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_5', 'hu_moment_7'],
# Accuracy: 0.7334393216746158,
# Recall: 0.7090719499478624
#
# Reward: 0.7090719499478624
#
# Epoch 100
# Feature set: ['darker', 'reddish', 'colorful', 'black_thin', 'color_bin_1', 'color_bin_5', 'color_bin_7', 'color_bin_8', 'color_entropy', 'texture_1', 'texture_2', 'texture_3', 'texture_7', 'number_lengthy_objects', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_5'],
# Accuracy: 0.7350291467938527,
# Recall: 0.7497393117831074
#
# Reward: 0.7497393117831074
#
# Epoch 101
# Feature set: ['darker', 'reddish', 'colorful', 'black_thin', 'color_bin_1', 'color_bin_5', 'color_bin_7', 'color_bin_8', 'color_entropy', 'texture_1', 'texture_2', 'texture_3', 'texture_7', 'number_lengthy_objects', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_5', 'hu_moment_7'],
# Accuracy: 0.7329093799682035,
# Recall: 0.7455683003128258
#
# Reward: 0.7455683003128258
#
# Epoch 102
# Feature set: ['darker', 'reddish', 'color_bin_1', 'color_bin_5', 'color_bin_7', 'color_bin_8', 'color_entropy', 'texture_1', 'texture_2', 'texture_3', 'texture_7', 'number_lengthy_objects', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_5', 'hu_moment_7'],
# Accuracy: 0.724960254372019,
# Recall: 0.7330552659019812
#
# Reward: 0.7330552659019812
#
# Epoch 103
# Feature set: ['darker', 'reddish', 'colorful', 'color_bin_1', 'color_bin_5', 'color_bin_7', 'color_bin_8', 'color_entropy', 'texture_1', 'texture_2', 'texture_3', 'texture_7', 'number_lengthy_objects', 'hu_moment_1', 'hu_moment_3', 'hu_moment_5', 'hu_moment_7'],
# Accuracy: 0.7291997880233174,
# Recall: 0.7413972888425443
#
# Reward: 0.7413972888425443
#
# Epoch 104
# Feature set: ['darker', 'reddish', 'colorful', 'color_bin_1', 'color_bin_5', 'color_bin_7', 'color_bin_8', 'color_entropy', 'texture_1', 'texture_2', 'texture_3', 'texture_7', 'number_lengthy_objects', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_5', 'hu_moment_7'],
# Accuracy: 0.7207207207207207,
# Recall: 0.7288842544316997
#
# Reward: 0.7288842544316997
#
# Epoch 105
# Feature set: ['darker', 'reddish', 'colorful', 'color_bin_1', 'color_bin_5', 'color_bin_6', 'color_bin_8', 'color_entropy', 'texture_1', 'texture_2', 'texture_3', 'texture_7', 'texture_9', 'number_lengthy_objects', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_5', 'hu_moment_7'],
# Accuracy: 0.739268680445151,
# Recall: 0.7466110531803962
#
# Reward: 0.7466110531803962
#
# Epoch 106
# Feature set: ['darker', 'reddish', 'colorful', 'black_thin', 'color_bin_1', 'color_bin_5', 'color_bin_7', 'color_bin_8', 'color_entropy', 'texture_1', 'texture_2', 'texture_3', 'texture_7', 'texture_9', 'number_lengthy_objects', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_5', 'hu_moment_7'],
# Accuracy: 0.7482776894541601,
# Recall: 0.7539103232533889
#
# Reward: 0.7539103232533889
#
# Epoch 107
# Feature set: ['darker', 'reddish', 'colorful', 'black_thin', 'color_bin_1', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_entropy', 'texture_1', 'texture_2', 'texture_3', 'texture_7', 'texture_9', 'number_lengthy_objects', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_5', 'hu_moment_7'],
# Accuracy: 0.7419183889772125,
# Recall: 0.7539103232533889
#
# Reward: 0.7539103232533889
#
# Epoch 108
# Feature set: ['darker', 'reddish', 'colorful', 'black_thin', 'color_bin_1', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_entropy', 'texture_1', 'texture_2', 'texture_3', 'texture_7', 'number_lengthy_objects', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_5', 'hu_moment_7'],
# Accuracy: 0.7376788553259142,
# Recall: 0.7612095933263816
#
# Reward: 0.7612095933263816
#
# Epoch 109
# Feature set: ['darker', 'reddish', 'colorful', 'color_bin_1', 'color_bin_5', 'color_bin_7', 'color_bin_8', 'color_entropy', 'texture_1', 'texture_2', 'texture_3', 'texture_6', 'texture_7', 'number_lengthy_objects', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_5', 'hu_moment_7'],
# Accuracy: 0.7339692633810281,
# Recall: 0.7205422314911366
#
# Reward: 0.7205422314911366
#
# Epoch 110
# Feature set: ['darker', 'reddish', 'colorful', 'color_bin_1', 'color_bin_5', 'color_bin_7', 'color_bin_8', 'color_entropy', 'texture_1', 'texture_2', 'texture_3', 'texture_9', 'number_lengthy_objects', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_5', 'hu_moment_7'],
# Accuracy: 0.7329093799682035,
# Recall: 0.7393117831074035
#
# Reward: 0.7393117831074035
#
# Epoch 111
# Feature set: ['darker', 'reddish', 'colorful', 'black_thin', 'color_bin_1', 'color_bin_5', 'color_bin_7', 'color_bin_8', 'color_entropy', 'rough', 'texture_1', 'texture_2', 'texture_3', 'texture_9', 'number_lengthy_objects', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_5', 'hu_moment_7'],
# Accuracy: 0.7366189719130896,
# Recall: 0.7403545359749739
#
# Reward: 0.7403545359749739
#
# Epoch 112
# Feature set: ['darker', 'reddish', 'colorful', 'black_thin', 'color_bin_1', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_entropy', 'rough', 'texture_1', 'texture_2', 'texture_3', 'texture_9', 'number_lengthy_objects', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_5', 'hu_moment_7'],
# Accuracy: 0.7371489136195019,
# Recall: 0.7403545359749739
#
# Reward: 0.7403545359749739
#
# Epoch 113
# Feature set: ['darker', 'reddish', 'colorful', 'black_thin', 'color_bin_1', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_entropy', 'rough', 'texture_1', 'texture_2', 'texture_3', 'texture_9', 'number_lengthy_objects', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_5'],
# Accuracy: 0.7466878643349232,
# Recall: 0.748696558915537
#
# Reward: 0.748696558915537
#
# Epoch 114
# Feature set: ['darker', 'reddish', 'colorful', 'black_thin', 'color_bin_1', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_entropy', 'texture_1', 'texture_2', 'texture_3', 'number_lengthy_objects', 'roundness', 'hu_moment_1', 'hu_moment_5'],
# Accuracy: 0.7180710121886592,
# Recall: 0.7340980187695516
#
# Reward: 0.7340980187695516
#
# Epoch 115
# Feature set: ['darker', 'reddish', 'colorful', 'black_thin', 'color_bin_1', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_entropy', 'texture_1', 'texture_2', 'texture_3', 'number_lengthy_objects', 'roundness', 'hu_moment_1', 'hu_moment_5', 'hu_moment_7'],
# Accuracy: 0.7101218865924749,
# Recall: 0.7299270072992701
#
# Reward: 0.7299270072992701
#
# Epoch 116
# Feature set: ['darker', 'reddish', 'colorful', 'black_thin', 'color_bin_1', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_entropy', 'texture_1', 'texture_2', 'texture_3', 'number_lengthy_objects', 'roundness', 'hu_moment_1', 'hu_moment_7'],
# Accuracy: 0.712241653418124,
# Recall: 0.7340980187695516
#
# Reward: 0.7340980187695516
#
# Epoch 117
# Feature set: ['darker', 'reddish', 'colorful', 'black_thin', 'color_bin_1', 'color_bin_5', 'color_bin_6', 'color_bin_8', 'color_entropy', 'texture_1', 'texture_2', 'texture_3', 'number_lengthy_objects', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_7'],
# Accuracy: 0.71595124536301,
# Recall: 0.7413972888425443
#
# Reward: 0.7413972888425443
#
# Epoch 118
# Feature set: ['darker', 'reddish', 'colorful', 'black_thin', 'color_bin_1', 'color_bin_5', 'color_bin_6', 'color_bin_8', 'color_entropy', 'texture_1', 'texture_2', 'texture_3', 'texture_6', 'number_lengthy_objects', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_7'],
# Accuracy: 0.7339692633810281,
# Recall: 0.735140771637122
#
# Reward: 0.735140771637122
#
# Epoch 119
# Feature set: ['darker', 'reddish', 'colorful', 'black_thin', 'color_bin_1', 'color_bin_5', 'color_bin_6', 'color_bin_8', 'color_entropy', 'texture_1', 'texture_2', 'texture_3', 'texture_6', 'texture_7', 'number_lengthy_objects', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_4', 'hu_moment_7'],
# Accuracy: 0.7382087970323264,
# Recall: 0.7184567257559958
#
# Reward: 0.7184567257559958
#
# Epoch 120
# Feature set: ['darker', 'reddish', 'colorful', 'black_thin', 'color_bin_1', 'color_bin_5', 'color_bin_8', 'color_entropy', 'texture_1', 'texture_2', 'texture_3', 'texture_6', 'texture_7', 'number_lengthy_objects', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_7'],
# Accuracy: 0.7339692633810281,
# Recall: 0.7194994786235662
#
# Reward: 0.7194994786235662
#
# Epoch 121
# Feature set: ['darker', 'reddish', 'colorful', 'black_thin', 'color_bin_1', 'color_bin_5', 'color_bin_7', 'color_bin_8', 'color_entropy', 'rough', 'texture_1', 'texture_2', 'texture_3', 'texture_5', 'texture_6', 'texture_7', 'number_lengthy_objects', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_7'],
# Accuracy: 0.7546369899311076,
# Recall: 0.7455683003128258
#
# Reward: 0.7455683003128258
#
# Epoch 122
# ...
# Accuracy: 0.7461579226285109,
# Recall: 0.7601668404588112
#
# Repitition 461
# Feature set: ['darker', 'reddish', 'metallic', 'colorful', 'black_thin', 'color_bin_2', 'color_bin_5', 'color_bin_7', 'color_entropy', 'rough', 'texture_0', 'texture_1', 'texture_2', 'texture_4', 'texture_5', 'lengthy', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7376788553259142,
# Recall: 0.7601668404588112
#
# Repitition 462
# Feature set: ['gradient', 'reddish', 'black', 'black_thin', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_4', 'color_bin_5', 'color_bin_6', 'color_bin_8', 'texture_0', 'texture_1', 'texture_2', 'texture_5', 'texture_6', 'texture_7', 'texture_9', 'lengthy', 'number_lengthy_objects', 'in_shape', 'hu_moment_1', 'hu_moment_7'],
# Accuracy: 0.7530471648118707,
# Recall: 0.7507820646506778
#
# Repitition 463
# Feature set: ['darker', 'reddish', 'metallic', 'dominating_color', 'color_bin_1', 'color_bin_4', 'color_bin_6', 'color_bin_7', 'dominating_texture', 'texture_0', 'texture_1', 'texture_2', 'texture_8', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7133015368309485,
# Recall: 0.7413972888425443
#
# Repitition 464
# Feature set: ['gradient', 'reddish', 'metallic', 'black', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_4', 'color_bin_5', 'color_bin_6', 'rough', 'dominating_texture', 'texture_1', 'texture_2', 'texture_5', 'texture_6', 'number_lengthy_objects', 'rel_length', 'roundness', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_7'],
# Accuracy: 0.7673555908850026,
# Recall: 0.7747653806047967
#
# Repitition 465
# Feature set: ['darker', 'reddish', 'black', 'black_thin', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_4', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'texture_1', 'texture_2', 'texture_4', 'texture_5', 'texture_6', 'texture_7', 'rel_length', 'roundness', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5'],
# Accuracy: 0.7509273979862215,
# Recall: 0.7476538060479666
#
# Repitition 466
# Feature set: ['metallic', 'dominating_color', 'color_bin_2', 'color_bin_3', 'color_bin_4', 'color_bin_7', 'rough', 'texture_0', 'texture_1', 'texture_2', 'texture_7', 'texture_8', 'lengthy', 'in_shape', 'hu_moment_2', 'hu_moment_3'],
# Accuracy: 0.7074721780604134,
# Recall: 0.7111574556830031
#
# Repitition 467
# Feature set: ['gradient', 'metallic', 'color_bin_4', 'color_bin_8', 'color_bin_9', 'rough', 'dominating_texture', 'texture_0', 'texture_1', 'texture_2', 'texture_6', 'texture_9', 'lengthy', 'rel_length', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_7'],
# Accuracy: 0.7551669316375199,
# Recall: 0.7455683003128258
#
# Repitition 468
# Feature set: ['metallic', 'colorful', 'black', 'black_thin', 'color_bin_1', 'color_bin_2', 'color_bin_4', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'dominating_texture', 'texture_1', 'texture_2', 'texture_3', 'texture_7', 'texture_9', 'lengthy', 'number_lengthy_objects', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_3', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7408585055643879,
# Recall: 0.7476538060479666
#
# Repitition 469
# Feature set: ['darker', 'reddish', 'dominating_color', 'color_bin_2', 'color_entropy', 'rough', 'texture_0', 'texture_1', 'texture_3', 'texture_5', 'number_lengthy_objects', 'hu_moment_1', 'hu_moment_3', 'hu_moment_4', 'hu_moment_7'],
# Accuracy: 0.730259671436142,
# Recall: 0.7497393117831074
#
# Repitition 470
# Feature set: ['metallic', 'colorful', 'color_bin_1', 'color_bin_2', 'color_bin_5', 'color_entropy', 'rough', 'dominating_texture', 'texture_3', 'texture_5', 'texture_6', 'texture_7', 'rough_entropy', 'lengthy', 'lengthy_aspect_ratio', 'in_shape', 'roundness', 'hu_moment_1', 'hu_moment_2'],
# Accuracy: 0.7488076311605724,
# Recall: 0.7403545359749739
#
# Repitition 471
# Feature set: ['darker', 'reddish', 'colorful', 'black', 'color_bin_1', 'color_bin_3', 'color_bin_8', 'color_entropy', 'rough', 'texture_1', 'texture_2', 'texture_5', 'texture_7', 'rough_entropy', 'lengthy', 'in_shape', 'roundness', 'hu_moment_1', 'hu_moment_3'],
# Accuracy: 0.7260201377848436,
# Recall: 0.7413972888425443
#
# Repitition 472
# Feature set: ['darker', 'gradient', 'colorful', 'black', 'color_bin_1', 'color_bin_3', 'color_bin_4', 'color_bin_6', 'color_bin_8', 'color_bin_9', 'color_entropy', 'rough', 'texture_2', 'texture_3', 'texture_4', 'texture_5', 'rough_entropy', 'lengthy_aspect_ratio', 'rel_length', 'in_shape', 'hu_moment_3', 'hu_moment_4', 'hu_moment_7'],
# Accuracy: 0.7609962904080552,
# Recall: 0.7924921793534933
#
# Repitition 473
# Feature set: ['colorful', 'black_thin', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_4', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'rough', 'texture_1', 'texture_2', 'texture_3', 'texture_5', 'texture_7', 'texture_9', 'rough_entropy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_4', 'hu_moment_5', 'hu_moment_7'],
# Accuracy: 0.7514573396926338,
# Recall: 0.7831074035453598
#
# Repitition 474
# Feature set: ['gradient', 'reddish', 'colorful', 'black', 'black_thin', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_8', 'color_entropy', 'rough', 'texture_0', 'texture_5', 'texture_6', 'texture_7', 'texture_9', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'rel_length', 'hu_moment_2', 'hu_moment_4', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7620561738208798,
# Recall: 0.7570385818561001
#
# Repitition 475
# Feature set: ['darker', 'gradient', 'metallic', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_6', 'color_bin_9', 'color_entropy', 'dominating_texture', 'texture_2', 'texture_4', 'texture_5', 'texture_7', 'texture_8', 'texture_9', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'in_shape', 'hu_moment_1', 'hu_moment_2'],
# Accuracy: 0.7503974562798092,
# Recall: 0.7716371220020855
#
# Repitition 476
# Feature set: ['darker', 'metallic', 'black', 'black_thin', 'color_bin_2', 'color_bin_4', 'color_bin_6', 'color_bin_8', 'texture_0', 'texture_1', 'texture_3', 'texture_5', 'texture_7', 'texture_8', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'rel_length', 'in_shape', 'hu_moment_2'],
# Accuracy: 0.7525172231054584,
# Recall: 0.7726798748696558
#
# Repitition 477
# Feature set: ['metallic', 'black_thin', 'color_bin_1', 'color_bin_4', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'color_entropy', 'dominating_texture', 'texture_0', 'texture_2', 'texture_3', 'texture_4', 'texture_7', 'texture_8', 'texture_9', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_2', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7424483306836248,
# Recall: 0.7518248175182481
#
# Repitition 478
# Feature set: ['colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_2', 'color_bin_3', 'color_bin_4', 'color_bin_6', 'color_bin_8', 'color_bin_9', 'rough', 'dominating_texture', 'texture_0', 'texture_1', 'texture_2', 'texture_3', 'texture_4', 'texture_5', 'texture_8', 'rough_entropy', 'number_lengthy_objects', 'roundness', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.7413884472708002,
# Recall: 0.781021897810219
#
# Repitition 479
# Feature set: ['reddish', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'rough', 'texture_1', 'texture_3', 'texture_6', 'texture_8', 'rough_entropy', 'number_lengthy_objects', 'rel_length', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_5'],
# Accuracy: 0.7397986221515633,
# Recall: 0.7288842544316997
#
# Repitition 480
# Feature set: ['darker', 'metallic', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_entropy', 'rough', 'texture_0', 'texture_3', 'texture_4', 'texture_5', 'texture_7', 'texture_9', 'rough_entropy', 'lengthy', 'roundness', 'hu_moment_1', 'hu_moment_2', 'hu_moment_7'],
# Accuracy: 0.7424483306836248,
# Recall: 0.7591240875912408
#
# Repitition 481
# Feature set: ['reddish', 'metallic', 'colorful', 'black', 'black_thin', 'color_bin_2', 'color_bin_3', 'color_bin_4', 'color_bin_5', 'color_bin_6', 'color_bin_8', 'color_bin_9', 'dominating_texture', 'texture_6', 'texture_8', 'rough_entropy', 'in_shape', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5'],
# Accuracy: 0.7334393216746158,
# Recall: 0.7153284671532847
#
# Repitition 482
# Feature set: ['gradient', 'reddish', 'colorful', 'color_bin_4', 'color_bin_6', 'color_bin_8', 'dominating_texture', 'texture_0', 'texture_1', 'texture_3', 'texture_5', 'rough_entropy', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_1', 'hu_moment_4', 'hu_moment_6'],
# Accuracy: 0.7419183889772125,
# Recall: 0.762252346193952
#
# Repitition 483
# Feature set: ['darker', 'gradient', 'black', 'dominating_color', 'color_bin_2', 'color_bin_3', 'color_bin_9', 'rough', 'texture_1', 'texture_2', 'texture_3', 'texture_4', 'texture_5', 'texture_7', 'texture_8', 'texture_9', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5'],
# Accuracy: 0.7583465818759937,
# Recall: 0.7768508863399375
#
# Repitition 484
# Feature set: ['colorful', 'black', 'color_bin_1', 'color_bin_3', 'color_bin_4', 'color_bin_6', 'color_entropy', 'dominating_texture', 'texture_0', 'texture_6', 'texture_7', 'texture_9', 'rough_entropy', 'lengthy', 'lengthy_aspect_ratio', 'rel_length', 'in_shape', 'hu_moment_2', 'hu_moment_3', 'hu_moment_7'],
# Accuracy: 0.749867514573397,
# Recall: 0.7309697601668405
#
# Repitition 485
# Feature set: ['reddish', 'colorful', 'dominating_color', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'rough', 'dominating_texture', 'texture_0', 'texture_1', 'texture_3', 'texture_4', 'texture_6', 'texture_7', 'texture_8', 'lengthy', 'number_lengthy_objects', 'roundness', 'hu_moment_3', 'hu_moment_5'],
# Accuracy: 0.7493375728669847,
# Recall: 0.7372262773722628
#
# Repitition 486
# Feature set: ['metallic', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_3', 'color_bin_4', 'color_bin_6', 'color_bin_7', 'color_entropy', 'rough', 'texture_1', 'texture_2', 'texture_4', 'texture_7', 'lengthy_aspect_ratio', 'roundness', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7196608373078961,
# Recall: 0.7205422314911366
#
# Repitition 487
# Feature set: ['darker', 'gradient', 'reddish', 'colorful', 'black', 'dominating_color', 'color_bin_3', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_entropy', 'dominating_texture', 'texture_0', 'texture_3', 'texture_9', 'rough_entropy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'roundness', 'hu_moment_1', 'hu_moment_2', 'hu_moment_4', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.739268680445151,
# Recall: 0.7361835245046924
#
# Repitition 488
# Feature set: ['darker', 'reddish', 'metallic', 'black', 'black_thin', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'rough', 'texture_1', 'texture_4', 'texture_5', 'texture_6', 'texture_7', 'texture_8', 'lengthy_aspect_ratio', 'hu_moment_1', 'hu_moment_3', 'hu_moment_6'],
# Accuracy: 0.7435082140964494,
# Recall: 0.7340980187695516
#
# Repitition 489
# Feature set: ['darker', 'reddish', 'colorful', 'black', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_4', 'color_bin_5', 'color_bin_7', 'color_bin_9', 'rough', 'texture_0', 'texture_2', 'texture_3', 'texture_5', 'texture_9', 'rough_entropy', 'number_lengthy_objects', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.7525172231054584,
# Recall: 0.7789363920750783
#
# Repitition 490
# Feature set: ['darker', 'metallic', 'black', 'black_thin', 'color_bin_3', 'color_bin_5', 'color_bin_7', 'rough', 'texture_1', 'texture_3', 'texture_8', 'lengthy', 'hu_moment_1', 'hu_moment_2', 'hu_moment_4', 'hu_moment_7'],
# Accuracy: 0.6984631690514044,
# Recall: 0.694473409801877
#
# Repitition 491
# Feature set: ['darker', 'metallic', 'black', 'black_thin', 'color_bin_1', 'color_bin_2', 'color_bin_4', 'color_bin_7', 'rough', 'texture_0', 'texture_1', 'texture_3', 'texture_4', 'texture_7', 'texture_8', 'lengthy_aspect_ratio', 'roundness', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5'],
# Accuracy: 0.7260201377848436,
# Recall: 0.735140771637122
#
# Repitition 492
# Feature set: ['gradient', 'color_bin_1', 'color_bin_2', 'color_bin_4', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'texture_1', 'texture_4', 'texture_6', 'texture_7', 'texture_9', 'rough_entropy', 'lengthy', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5'],
# Accuracy: 0.7376788553259142,
# Recall: 0.7174139728884255
#
# Repitition 493
# Feature set: ['reddish', 'metallic', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'rough', 'texture_0', 'texture_6', 'texture_7', 'texture_8', 'lengthy', 'lengthy_aspect_ratio', 'rel_length'],
# Accuracy: 0.7509273979862215,
# Recall: 0.7403545359749739
#
# Repitition 494
# Feature set: ['gradient', 'reddish', 'metallic', 'color_bin_1', 'color_bin_2', 'color_bin_4', 'color_bin_6', 'color_entropy', 'rough', 'texture_0', 'texture_3', 'texture_4', 'texture_5', 'texture_7', 'texture_8', 'rough_entropy', 'rel_length', 'hu_moment_2', 'hu_moment_4', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7546369899311076,
# Recall: 0.7799791449426486
#
# Repitition 495
# Feature set: ['metallic', 'colorful', 'color_bin_5', 'color_bin_6', 'color_entropy', 'texture_1', 'texture_4', 'texture_5', 'texture_6', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'in_shape', 'roundness', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.7509273979862215,
# Recall: 0.7518248175182481
#
# Repitition 496
# Feature set: ['gradient', 'reddish', 'metallic', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_3', 'color_bin_7', 'color_bin_9', 'color_entropy', 'dominating_texture', 'texture_1', 'texture_3', 'texture_4', 'texture_6', 'texture_7', 'rough_entropy', 'lengthy', 'lengthy_aspect_ratio', 'roundness', 'hu_moment_1', 'hu_moment_2', 'hu_moment_4'],
# Accuracy: 0.7562268150503445,
# Recall: 0.7424400417101147
#
# Repitition 497
# Feature set: ['metallic', 'black', 'color_bin_1', 'color_bin_3', 'color_bin_4', 'color_bin_5', 'color_bin_6', 'color_bin_8', 'color_bin_9', 'rough', 'texture_1', 'texture_2', 'texture_3', 'texture_6', 'texture_9', 'rough_entropy', 'roundness', 'hu_moment_1', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.7339692633810281,
# Recall: 0.7059436913451512
#
# Repitition 498
# Feature set: ['metallic', 'colorful', 'dominating_color', 'color_bin_1', 'color_bin_4', 'color_bin_8', 'color_bin_9', 'dominating_texture', 'texture_0', 'texture_4', 'texture_7', 'texture_9', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7111817700052994,
# Recall: 0.7090719499478624
#
# Repitition 499
# Feature set: ['gradient', 'metallic', 'colorful', 'dominating_color', 'color_bin_1', 'color_bin_5', 'color_bin_6', 'color_bin_9', 'color_entropy', 'texture_1', 'texture_2', 'texture_4', 'texture_5', 'texture_7', 'texture_9', 'lengthy', 'number_lengthy_objects', 'in_shape', 'roundness', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_7'],
# Accuracy: 0.7509273979862215,
# Recall: 0.7747653806047967
# Best Feature set: ('gradient', 'metallic', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_4', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_entropy', 'texture_0', 'texture_1', 'texture_3', 'texture_4', 'texture_5', 'texture_7', 'texture_8', 'texture_9', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3')
# Reward: 0.8133472367049009

# %%
crack_classifier.run(['darker', 'reddish', 'colorful', 'color_bin_1', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 
                      'color_entropy', 'texture_2', 'texture_3', 'texture_5', 'texture_9', 'number_lengthy_objects', 'roundness', 
                      'hu_moment_1', 'hu_moment_2', 'hu_moment_7'])
# Out:
# Feature set: ['darker', 'reddish', 'colorful', 'color_bin_1', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_entropy', 'texture_2', 'texture_3', 'texture_5', 'texture_9', 'number_lengthy_objects', 'roundness', 'hu_moment_1', 'hu_moment_2', 'hu_moment_7'],
# Accuracy: 0.7551669316375199,
# Recall: 0.7851929092805006
# 0.7851929092805006

# %% [markdown]
# **Analysis Graffiti**

# %%
# Create a classifier for graffiti:

graffiti_classifier = ClassificationModel("Graffiti")

# %%
# Run classification on hypothesized features:

hypothesized_features_graffiti = ["colorful", "hu_moment_1", "hu_moment_2", "hu_moment_3", "hu_moment_4", "hu_moment_5", "hu_moment_6", 
                                  "hu_moment_7", "in_shape", "roundness", "darker"] ## Insert hypothesized most relevant features here

graffiti_classifier.run(hypothesized_features_graffiti)
# Out:
# Feature set: ['colorful', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7', 'in_shape', 'roundness', 'darker'],
# Accuracy: 0.6187943262411347,
# Recall: 0.6884681583476764
# 0.6884681583476764

# %%
# Apply meta-learning and compare with random choices:

train_agent(graffiti_classifier, initial_features=hypothesized_features_graffiti, epochs=500)
#random_monkey(graffiti_classifier, repetitions=500)
# Out:
# Epoch 0
# Feature set: ['darker', 'colorful', 'black_thin', 'in_shape', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.6294326241134752,
# Recall: 0.6867469879518072
#
# Reward: 0.6867469879518072
#
# Epoch 1
# Feature set: ['darker', 'colorful', 'black_thin', 'texture_6', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.6320921985815603,
# Recall: 0.7005163511187608
#
# Reward: 0.7005163511187608
#
# Epoch 2
# Feature set: ['darker', 'colorful', 'black_thin', 'color_bin_3', 'texture_6', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.648936170212766,
# Recall: 0.6987951807228916
#
# Reward: 0.6987951807228916
#
# Epoch 3
# Feature set: ['darker', 'reddish', 'colorful', 'black_thin', 'color_bin_3', 'texture_6', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.6985815602836879,
# Recall: 0.6764199655765921
#
# Reward: 0.6764199655765921
#
# Epoch 4
# Feature set: ['darker', 'reddish', 'colorful', 'black_thin', 'color_bin_3', 'color_bin_9', 'texture_6', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.6923758865248227,
# Recall: 0.6781411359724613
#
# Reward: 0.6781411359724613
#
# Epoch 5
# Feature set: ['darker', 'reddish', 'colorful', 'color_bin_3', 'color_bin_9', 'rough', 'texture_6', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.6976950354609929,
# Recall: 0.7074010327022375
#
# Reward: 0.7074010327022375
#
# Epoch 6
# Feature set: ['darker', 'reddish', 'colorful', 'color_bin_3', 'color_bin_5', 'color_bin_9', 'rough', 'dominating_texture', 'texture_6', 'number_lengthy_objects', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7065602836879432,
# Recall: 0.6746987951807228
#
# Reward: 0.6746987951807228
#
# Epoch 7
# Feature set: ['darker', 'reddish', 'colorful', 'color_bin_3', 'color_bin_5', 'color_bin_9', 'rough', 'dominating_texture', 'texture_1', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7136524822695035,
# Recall: 0.6867469879518072
#
# Reward: 0.6867469879518072
#
# Epoch 8
# Feature set: ['darker', 'reddish', 'colorful', 'color_bin_3', 'color_bin_5', 'color_bin_9', 'rough', 'dominating_texture', 'texture_1', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7367021276595744,
# Recall: 0.7160068846815835
#
# Reward: 0.7160068846815835
#
# Epoch 9
# Feature set: ['darker', 'reddish', 'color_bin_3', 'color_bin_5', 'color_bin_9', 'rough', 'dominating_texture', 'texture_1', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7207446808510638,
# Recall: 0.7022375215146299
#
# Reward: 0.7022375215146299
#
# Epoch 10
# Feature set: ['darker', 'reddish', 'color_bin_3', 'color_bin_5', 'color_bin_7', 'color_bin_9', 'rough', 'dominating_texture', 'texture_1', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7296099290780141,
# Recall: 0.7211703958691911
#
# Reward: 0.7211703958691911
#
# Epoch 11
# Feature set: ['darker', 'color_bin_3', 'color_bin_5', 'color_bin_7', 'color_bin_9', 'rough', 'dominating_texture', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7180851063829787,
# Recall: 0.6970740103270223
#
# Reward: 0.6970740103270223
#
# Epoch 12
# Feature set: ['darker', 'color_bin_3', 'color_bin_5', 'color_bin_9', 'rough', 'dominating_texture', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.700354609929078,
# Recall: 0.6901893287435457
#
# Reward: 0.6901893287435457
#
# Epoch 13
# Feature set: ['darker', 'reddish', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_9', 'rough', 'dominating_texture', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7136524822695035,
# Recall: 0.7022375215146299
#
# Reward: 0.7022375215146299
#
# Epoch 14
# Feature set: ['darker', 'reddish', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_9', 'rough', 'dominating_texture', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7171985815602837,
# Recall: 0.6987951807228916
#
# Reward: 0.6987951807228916
#
# Epoch 15
# Feature set: ['darker', 'reddish', 'metallic', 'color_bin_2', 'color_bin_3', 'color_bin_4', 'color_bin_5', 'color_bin_6', 'color_bin_9', 'rough', 'dominating_texture', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.6985815602836879,
# Recall: 0.6626506024096386
#
# Reward: 0.6626506024096386
#
# Epoch 16
# Feature set: ['darker', 'reddish', 'metallic', 'black_thin', 'color_bin_2', 'color_bin_3', 'color_bin_4', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'rough', 'dominating_texture', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7180851063829787,
# Recall: 0.7039586919104991
#
# Reward: 0.7039586919104991
#
# Epoch 17
# Feature set: ['darker', 'reddish', 'metallic', 'black_thin', 'color_bin_2', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'rough', 'dominating_texture', 'texture_3', 'texture_4', 'texture_5', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7109929078014184,
# Recall: 0.6901893287435457
#
# Reward: 0.6901893287435457
#
# Epoch 18
# Feature set: ['darker', 'metallic', 'black_thin', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'rough', 'dominating_texture', 'texture_3', 'texture_4', 'texture_5', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7171985815602837,
# Recall: 0.7039586919104991
#
# Reward: 0.7039586919104991
#
# Epoch 19
# Feature set: ['darker', 'metallic', 'black_thin', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'rough', 'texture_4', 'texture_5', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7180851063829787,
# Recall: 0.6953528399311532
#
# Reward: 0.6953528399311532
#
# Epoch 20
# Feature set: ['darker', 'metallic', 'black_thin', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'rough', 'dominating_texture', 'texture_4', 'texture_5', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7154255319148937,
# Recall: 0.6987951807228916
#
# Reward: 0.6987951807228916
#
# Epoch 21
# Feature set: ['darker', 'black_thin', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'rough', 'dominating_texture', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7171985815602837,
# Recall: 0.6867469879518072
#
# Reward: 0.6867469879518072
#
# Epoch 22
# Feature set: ['darker', 'black_thin', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'rough', 'dominating_texture', 'texture_4', 'texture_6', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7269503546099291,
# Recall: 0.7194492254733219
#
# Reward: 0.7194492254733219
#
# Epoch 23
# Feature set: ['darker', 'black_thin', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'rough', 'dominating_texture', 'texture_4', 'texture_6', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7189716312056738,
# Recall: 0.7091222030981067
#
# Reward: 0.7091222030981067
#
# Epoch 24
# Feature set: ['darker', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'rough', 'dominating_texture', 'texture_4', 'texture_6', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7145390070921985,
# Recall: 0.7022375215146299
#
# Reward: 0.7022375215146299
#
# Epoch 25
# Feature set: ['darker', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_9', 'rough', 'dominating_texture', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'rel_length', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7216312056737588,
# Recall: 0.6953528399311532
#
# Reward: 0.6953528399311532
#
# Epoch 26
# Feature set: ['darker', 'reddish', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_9', 'rough', 'dominating_texture', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'rel_length', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7269503546099291,
# Recall: 0.7142857142857143
#
# Reward: 0.7142857142857143
#
# Epoch 27
# Feature set: ['darker', 'reddish', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'rough', 'dominating_texture', 'texture_1', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'rel_length', 'roundness', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7136524822695035,
# Recall: 0.6970740103270223
#
# Reward: 0.6970740103270223
#
# Epoch 28
# Feature set: ['darker', 'reddish', 'black_thin', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'rough', 'dominating_texture', 'texture_1', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'rel_length', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7384751773049646,
# Recall: 0.7246127366609294
#
# Reward: 0.7246127366609294
#
# Epoch 29
# Feature set: ['darker', 'reddish', 'black_thin', 'color_bin_3', 'color_bin_5', 'color_bin_7', 'color_bin_9', 'rough', 'dominating_texture', 'texture_1', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'rel_length', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7296099290780141,
# Recall: 0.7332185886402753
#
# Reward: 0.7332185886402753
#
# Epoch 30
# Feature set: ['darker', 'reddish', 'black_thin', 'color_bin_3', 'color_bin_5', 'color_bin_7', 'rough', 'dominating_texture', 'texture_1', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7189716312056738,
# Recall: 0.6987951807228916
#
# Reward: 0.6987951807228916
#
# Epoch 31
# Feature set: ['darker', 'reddish', 'color_bin_3', 'color_bin_5', 'color_bin_7', 'rough', 'dominating_texture', 'texture_1', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7136524822695035,
# Recall: 0.7125645438898451
#
# Reward: 0.7125645438898451
#
# Epoch 32
# Feature set: ['darker', 'reddish', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_7', 'rough', 'dominating_texture', 'texture_3', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7092198581560284,
# Recall: 0.7091222030981067
#
# Reward: 0.7091222030981067
#
# Epoch 33
# Feature set: ['darker', 'reddish', 'metallic', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'rough', 'dominating_texture', 'texture_3', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7101063829787234,
# Recall: 0.6798623063683304
#
# Reward: 0.6798623063683304
#
# Epoch 34
# Feature set: ['darker', 'reddish', 'metallic', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'rough', 'dominating_texture', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7039007092198581,
# Recall: 0.6712564543889845
#
# Reward: 0.6712564543889845
#
# Epoch 35
# Feature set: ['darker', 'reddish', 'metallic', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'rough', 'dominating_texture', 'texture_6', 'number_lengthy_objects', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7101063829787234,
# Recall: 0.7039586919104991
#
# Reward: 0.7039586919104991
#
# Epoch 36
# Feature set: ['darker', 'reddish', 'metallic', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'rough', 'dominating_texture', 'texture_6', 'texture_9', 'rough_entropy', 'number_lengthy_objects', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7127659574468085,
# Recall: 0.6970740103270223
#
# Reward: 0.6970740103270223
#
# Epoch 37
# Feature set: ['darker', 'reddish', 'metallic', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'rough', 'dominating_texture', 'texture_4', 'texture_6', 'texture_9', 'rough_entropy', 'number_lengthy_objects', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.723404255319149,
# Recall: 0.7142857142857143
#
# Reward: 0.7142857142857143
#
# Epoch 38
# Feature set: ['darker', 'metallic', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'rough', 'dominating_texture', 'texture_4', 'texture_9', 'rough_entropy', 'number_lengthy_objects', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7163120567375887,
# Recall: 0.7022375215146299
#
# Reward: 0.7022375215146299
#
# Epoch 39
# Feature set: ['darker', 'metallic', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'rough', 'dominating_texture', 'texture_4', 'texture_6', 'texture_9', 'rough_entropy', 'number_lengthy_objects', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7163120567375887,
# Recall: 0.6901893287435457
#
# Reward: 0.6901893287435457
#
# Epoch 40
# Feature set: ['darker', 'metallic', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'rough', 'dominating_texture', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7074468085106383,
# Recall: 0.7074010327022375
#
# Reward: 0.7074010327022375
#
# Epoch 41
# Feature set: ['darker', 'color_bin_3', 'color_bin_5', 'color_bin_7', 'color_bin_9', 'rough', 'dominating_texture', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'rel_length', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.723404255319149,
# Recall: 0.7160068846815835
#
# Reward: 0.7160068846815835
#
# Epoch 42
# Feature set: ['darker', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'rough', 'dominating_texture', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7145390070921985,
# Recall: 0.7074010327022375
#
# Reward: 0.7074010327022375
#
# Epoch 43
# Feature set: ['darker', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'rough', 'dominating_texture', 'texture_2', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7127659574468085,
# Recall: 0.6884681583476764
#
# Reward: 0.6884681583476764
#
# Epoch 44
# Feature set: ['darker', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'rough', 'dominating_texture', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7021276595744681,
# Recall: 0.6798623063683304
#
# Reward: 0.6798623063683304
#
# Epoch 45
# Feature set: ['darker', 'colorful', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_9', 'rough', 'dominating_texture', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.726063829787234,
# Recall: 0.7108433734939759
#
# Reward: 0.7108433734939759
#
# Epoch 46
# Feature set: ['darker', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_9', 'rough', 'dominating_texture', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7021276595744681,
# Recall: 0.6867469879518072
#
# Reward: 0.6867469879518072
#
# Epoch 47
# Feature set: ['darker', 'reddish', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_9', 'rough', 'dominating_texture', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'rel_length', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7216312056737588,
# Recall: 0.7142857142857143
#
# Reward: 0.7142857142857143
#
# Epoch 48
# Feature set: ['darker', 'reddish', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'rough', 'dominating_texture', 'texture_3', 'texture_4', 'texture_6', 'texture_8', 'rough_entropy', 'number_lengthy_objects', 'rel_length', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7189716312056738,
# Recall: 0.7022375215146299
#
# Reward: 0.7022375215146299
#
# Epoch 49
# Feature set: ['darker', 'reddish', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'rough', 'dominating_texture', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'rel_length', 'roundness', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7198581560283688,
# Recall: 0.7039586919104991
#
# Reward: 0.7039586919104991
#
# Epoch 50
# Feature set: ['darker', 'reddish', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'rough', 'dominating_texture', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'rel_length', 'roundness', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7145390070921985,
# Recall: 0.6970740103270223
#
# Reward: 0.6970740103270223
#
# Epoch 51
# Feature set: ['darker', 'reddish', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'dominating_texture', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'rel_length', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7216312056737588,
# Recall: 0.7160068846815835
#
# Reward: 0.7160068846815835
#
# Epoch 52
# Feature set: ['darker', 'reddish', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_8', 'color_bin_9', 'color_entropy', 'rough', 'dominating_texture', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'rel_length', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.725177304964539,
# Recall: 0.7108433734939759
#
# Reward: 0.7108433734939759
#
# Epoch 53
# Feature set: ['darker', 'reddish', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_9', 'rough', 'dominating_texture', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'rel_length', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7269503546099291,
# Recall: 0.7142857142857143
#
# Reward: 0.7142857142857143
#
# Epoch 54
# Feature set: ['darker', 'reddish', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'rough', 'dominating_texture', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7287234042553191,
# Recall: 0.7108433734939759
#
# Reward: 0.7108433734939759
#
# Epoch 55
# Feature set: ['darker', 'reddish', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_9', 'dominating_texture', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.724290780141844,
# Recall: 0.7160068846815835
#
# Reward: 0.7160068846815835
#
# Epoch 56
# Feature set: ['darker', 'reddish', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_9', 'rough', 'dominating_texture', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7278368794326241,
# Recall: 0.7211703958691911
#
# Reward: 0.7211703958691911
#
# Epoch 57
# Feature set: ['darker', 'reddish', 'metallic', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_9', 'rough', 'dominating_texture', 'texture_4', 'texture_6', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7278368794326241,
# Recall: 0.7108433734939759
#
# Reward: 0.7108433734939759
#
# Epoch 58
# Feature set: ['darker', 'reddish', 'metallic', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'rough', 'dominating_texture', 'texture_3', 'texture_4', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7269503546099291,
# Recall: 0.7160068846815835
#
# Reward: 0.7160068846815835
#
# Epoch 59
# Feature set: ['darker', 'reddish', 'metallic', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'rough', 'dominating_texture', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7225177304964538,
# Recall: 0.7022375215146299
#
# Reward: 0.7022375215146299
#
# Epoch 60
# Feature set: ['darker', 'reddish', 'metallic', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'rough', 'dominating_texture', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'roundness', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7340425531914894,
# Recall: 0.7177280550774526
#
# Reward: 0.7177280550774526
#
# Epoch 61
# Feature set: ['darker', 'metallic', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'rough', 'dominating_texture', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'rel_length', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7109929078014184,
# Recall: 0.6953528399311532
#
# Reward: 0.6953528399311532
#
# Epoch 62
# Feature set: ['darker', 'color_bin_3', 'color_bin_5', 'color_bin_9', 'rough', 'dominating_texture', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'rel_length', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7101063829787234,
# Recall: 0.693631669535284
#
# Reward: 0.693631669535284
#
# Epoch 63
# Feature set: ['darker', 'color_bin_3', 'color_bin_5', 'color_bin_9', 'rough', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'rel_length', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7287234042553191,
# Recall: 0.7228915662650602
#
# Reward: 0.7228915662650602
#
# Epoch 64
# Feature set: ['darker', 'reddish', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_9', 'rough', 'dominating_texture', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'rel_length', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7269503546099291,
# Recall: 0.7142857142857143
#
# Reward: 0.7142857142857143
#
# Epoch 65
# Feature set: ['darker', 'reddish', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'rough', 'dominating_texture', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.7083333333333334,
# Recall: 0.7005163511187608
#
# Reward: 0.7005163511187608
#
# Epoch 66
# Feature set: ['darker', 'reddish', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'rough', 'dominating_texture', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7322695035460993,
# Recall: 0.7194492254733219
#
# Reward: 0.7194492254733219
#
# Epoch 67
# Feature set: ['darker', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'rough', 'dominating_texture', 'texture_3', 'texture_4', 'rough_entropy', 'number_lengthy_objects', 'rel_length', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7109929078014184,
# Recall: 0.6919104991394148
#
# Reward: 0.6919104991394148
#
# Epoch 68
# Feature set: ['darker', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'rough', 'dominating_texture', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'rel_length', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7207446808510638,
# Recall: 0.7091222030981067
#
# Reward: 0.7091222030981067
#
# Epoch 69
# Feature set: ['darker', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'rough', 'dominating_texture', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'rel_length', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.725177304964539,
# Recall: 0.7211703958691911
#
# Reward: 0.7211703958691911
#
# Epoch 70
# Feature set: ['darker', 'black_thin', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_9', 'rough', 'dominating_texture', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'rel_length', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7313829787234043,
# Recall: 0.7177280550774526
#
# Reward: 0.7177280550774526
#
# Epoch 71
# Feature set: ['darker', 'reddish', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_9', 'rough', 'dominating_texture', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'rel_length', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7269503546099291,
# Recall: 0.7142857142857143
#
# Reward: 0.7142857142857143
#
# Epoch 72
# Feature set: ['darker', 'reddish', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'rough', 'dominating_texture', 'texture_1', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'rel_length', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7198581560283688,
# Recall: 0.7125645438898451
#
# Reward: 0.7125645438898451
#
# Epoch 73
# Feature set: ['darker', 'color_bin_3', 'color_bin_5', 'color_bin_7', 'color_bin_9', 'rough', 'dominating_texture', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'rel_length', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7065602836879432,
# Recall: 0.6901893287435457
#
# Reward: 0.6901893287435457
#
# Epoch 74
# Feature set: ['darker', 'color_bin_1', 'color_bin_3', 'color_bin_5', 'color_bin_9', 'rough', 'dominating_texture', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'rel_length', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7136524822695035,
# Recall: 0.6884681583476764
#
# Reward: 0.6884681583476764
#
# Epoch 75
# Feature set: ['darker', 'reddish', 'color_bin_1', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_9', 'rough', 'dominating_texture', 'texture_3', 'texture_4', 'texture_6', 'number_lengthy_objects', 'rel_length', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7021276595744681,
# Recall: 0.6867469879518072
#
# Reward: 0.6867469879518072
#
# Epoch 76
# Feature set: ['darker', 'reddish', 'color_bin_1', 'color_bin_3', 'color_bin_6', 'color_bin_9', 'rough', 'dominating_texture', 'texture_3', 'texture_4', 'texture_6', 'number_lengthy_objects', 'rel_length', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7189716312056738,
# Recall: 0.7142857142857143
#
# Reward: 0.7142857142857143
#
# Epoch 77
# Feature set: ['darker', 'reddish', 'color_bin_3', 'color_bin_6', 'color_bin_9', 'rough', 'dominating_texture', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'rel_length', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7198581560283688,
# Recall: 0.7211703958691911
#
# Reward: 0.7211703958691911
#
# Epoch 78
# Feature set: ['darker', 'reddish', 'color_bin_3', 'color_bin_6', 'color_bin_9', 'rough', 'dominating_texture', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'rel_length', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7171985815602837,
# Recall: 0.7125645438898451
#
# Reward: 0.7125645438898451
#
# Epoch 79
# Feature set: ['reddish', 'color_bin_3', 'color_bin_6', 'color_bin_9', 'rough', 'dominating_texture', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'rel_length', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7092198581560284,
# Recall: 0.7022375215146299
#
# Reward: 0.7022375215146299
#
# Epoch 80
# Feature set: ['darker', 'reddish', 'color_bin_3', 'color_bin_6', 'color_bin_9', 'rough', 'dominating_texture', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'rel_length', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7171985815602837,
# Recall: 0.7125645438898451
#
# Reward: 0.7125645438898451
#
# Epoch 81
# Feature set: ['darker', 'reddish', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_9', 'rough', 'dominating_texture', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'rel_length', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7198581560283688,
# Recall: 0.7091222030981067
#
# Reward: 0.7091222030981067
#
# Epoch 82
# Feature set: ['darker', 'reddish', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'rough', 'dominating_texture', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'rel_length', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7375886524822695,
# Recall: 0.7280550774526678
#
# Reward: 0.7280550774526678
#
# Epoch 83
# Feature set: ['darker', 'black_thin', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'rough', 'dominating_texture', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'rel_length', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.726063829787234,
# Recall: 0.7125645438898451
#
# Reward: 0.7125645438898451
#
# Epoch 84
# Feature set: ['darker', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'rough', 'dominating_texture', 'texture_3', 'texture_4', 'texture_6', 'texture_9', 'rough_entropy', 'number_lengthy_objects', 'rel_length', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7189716312056738,
# Recall: 0.7022375215146299
#
# Reward: 0.7022375215146299
#
# Epoch 85
# Feature set: ['darker', 'black_thin', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'rough', 'dominating_texture', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'rel_length', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7198581560283688,
# Recall: 0.7108433734939759
#
# Reward: 0.7108433734939759
#
# Epoch 86
# Feature set: ['darker', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'rough', 'dominating_texture', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'rel_length', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.725177304964539,
# Recall: 0.7211703958691911
#
# Reward: 0.7211703958691911
#
# Epoch 87
# Feature set: ['darker', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_9', 'rough', 'dominating_texture', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'rel_length', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7216312056737588,
# Recall: 0.6953528399311532
#
# Reward: 0.6953528399311532
#
# Epoch 88
# Feature set: ['darker', 'metallic', 'colorful', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_9', 'rough', 'dominating_texture', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'rel_length', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7163120567375887,
# Recall: 0.685025817555938
#
# Reward: 0.685025817555938
#
# Epoch 89
# Feature set: ['darker', 'metallic', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_9', 'rough', 'dominating_texture', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'rel_length', 'in_shape', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7225177304964538,
# Recall: 0.7091222030981067
#
# Reward: 0.7091222030981067
#
# Epoch 90
# Feature set: ['darker', 'metallic', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_9', 'rough', 'dominating_texture', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'rel_length', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7127659574468085,
# Recall: 0.693631669535284
#
# Reward: 0.693631669535284
#
# Epoch 91
# Feature set: ['darker', 'reddish', 'metallic', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_9', 'rough', 'dominating_texture', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'rel_length', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7349290780141844,
# Recall: 0.7125645438898451
#
# Reward: 0.7125645438898451
#
# Epoch 92
# Feature set: ['darker', 'reddish', 'metallic', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'rough', 'dominating_texture', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'rel_length', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.723404255319149,
# Recall: 0.7125645438898451
#
# Reward: 0.7125645438898451
#
# Epoch 93
# Feature set: ['darker', 'metallic', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_7', 'color_bin_9', 'rough', 'dominating_texture', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'rel_length', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7109929078014184,
# Recall: 0.6953528399311532
#
# Reward: 0.6953528399311532
#
# Epoch 94
# Feature set: ['darker', 'metallic', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_7', 'color_bin_9', 'rough', 'dominating_texture', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7039007092198581,
# Recall: 0.6833046471600689
#
# Reward: 0.6833046471600689
#
# Epoch 95
# Feature set: ['darker', 'metallic', 'black_thin', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'rough', 'dominating_texture', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7207446808510638,
# Recall: 0.6953528399311532
#
# Reward: 0.6953528399311532
#
# Epoch 96
# Feature set: ['darker', 'metallic', 'black_thin', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'rough', 'dominating_texture', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.724290780141844,
# Recall: 0.7211703958691911
#
# Reward: 0.7211703958691911
#
# Epoch 97
# Feature set: ['darker', 'metallic', 'black_thin', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'rough', 'dominating_texture', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7163120567375887,
# Recall: 0.7005163511187608
#
# Reward: 0.7005163511187608
#
# Epoch 98
# Feature set: ['darker', 'metallic', 'black_thin', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'rough', 'dominating_texture', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7127659574468085,
# Recall: 0.685025817555938
#
# Reward: 0.685025817555938
#
# Epoch 99
# Feature set: ['darker', 'metallic', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'rough', 'dominating_texture', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.699468085106383,
# Recall: 0.6815834767641996
#
# Reward: 0.6815834767641996
#
# Epoch 100
# Feature set: ['darker', 'metallic', 'black_thin', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'rough', 'dominating_texture', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'rel_length', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7109929078014184,
# Recall: 0.7022375215146299
#
# Reward: 0.7022375215146299
#
# Epoch 101
# Feature set: ['darker', 'metallic', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'rough', 'dominating_texture', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'rel_length', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7056737588652482,
# Recall: 0.6987951807228916
#
# Reward: 0.6987951807228916
#
# Epoch 102
# Feature set: ['darker', 'metallic', 'color_bin_3', 'color_bin_5', 'color_bin_7', 'rough', 'dominating_texture', 'texture_3', 'texture_4', 'texture_6', 'texture_9', 'rough_entropy', 'number_lengthy_objects', 'rel_length', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7154255319148937,
# Recall: 0.6970740103270223
#
# Reward: 0.6970740103270223
#
# Epoch 103
# Feature set: ['darker', 'metallic', 'color_bin_3', 'color_bin_5', 'color_bin_7', 'rough', 'dominating_texture', 'texture_3', 'texture_4', 'texture_6', 'texture_9', 'rough_entropy', 'number_lengthy_objects', 'roundness', 'hu_moment_3', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7092198581560284,
# Recall: 0.6919104991394148
#
# Reward: 0.6919104991394148
#
# Epoch 104
# Feature set: ['darker', 'metallic', 'black_thin', 'color_bin_3', 'color_bin_5', 'color_bin_7', 'rough', 'dominating_texture', 'texture_3', 'texture_4', 'texture_6', 'texture_9', 'rough_entropy', 'number_lengthy_objects', 'roundness', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7163120567375887,
# Recall: 0.7108433734939759
#
# Reward: 0.7108433734939759
#
# Epoch 105
# Feature set: ['darker', 'metallic', 'black_thin', 'color_bin_3', 'color_bin_5', 'color_bin_7', 'color_bin_9', 'rough', 'dominating_texture', 'texture_3', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'roundness', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7216312056737588,
# Recall: 0.7091222030981067
#
# Reward: 0.7091222030981067
#
# Epoch 106
# Feature set: ['darker', 'metallic', 'black_thin', 'color_bin_3', 'color_bin_5', 'color_bin_9', 'rough', 'dominating_texture', 'texture_3', 'texture_4', 'texture_6', 'texture_9', 'rough_entropy', 'number_lengthy_objects', 'roundness', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.725177304964539,
# Recall: 0.7177280550774526
#
# Reward: 0.7177280550774526
#
# Epoch 107
# Feature set: ['darker', 'metallic', 'black_thin', 'color_bin_3', 'color_bin_5', 'color_bin_7', 'color_bin_9', 'rough', 'dominating_texture', 'texture_3', 'texture_4', 'texture_6', 'texture_9', 'rough_entropy', 'number_lengthy_objects', 'roundness', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7207446808510638,
# Recall: 0.7039586919104991
#
# Reward: 0.7039586919104991
#
# Epoch 108
# Feature set: ['darker', 'black_thin', 'color_bin_3', 'color_bin_5', 'color_bin_7', 'color_bin_9', 'rough', 'dominating_texture', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'roundness', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7180851063829787,
# Recall: 0.7228915662650602
#
# Reward: 0.7228915662650602
#
# Epoch 109
# Feature set: ['darker', 'black_thin', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_9', 'rough', 'dominating_texture', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'roundness', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.725177304964539,
# Recall: 0.7125645438898451
#
# Reward: 0.7125645438898451
#
# Epoch 110
# Feature set: ['darker', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_9', 'rough', 'dominating_texture', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7154255319148937,
# Recall: 0.693631669535284
#
# Reward: 0.693631669535284
#
# Epoch 111
# Feature set: ['darker', 'metallic', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_9', 'rough', 'dominating_texture', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'rel_length', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7127659574468085,
# Recall: 0.693631669535284
#
# Reward: 0.693631669535284
#
# Epoch 112
# Feature set: ['darker', 'reddish', 'metallic', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_9', 'rough', 'dominating_texture', 'texture_1', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'rel_length', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7198581560283688,
# Recall: 0.6970740103270223
#
# Reward: 0.6970740103270223
#
# Epoch 113
# Feature set: ['darker', 'gradient', 'reddish', 'metallic', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'rough', 'dominating_texture', 'texture_1', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7136524822695035,
# Recall: 0.693631669535284
#
# Reward: 0.693631669535284
#
# Epoch 114
# Feature set: ['darker', 'metallic', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'rough', 'dominating_texture', 'texture_1', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7030141843971631,
# Recall: 0.6815834767641996
#
# Reward: 0.6815834767641996
#
# Epoch 115
# ...
# Accuracy: 0.7304964539007093,
# Recall: 0.7091222030981067
#
# Reward: 0.7091222030981067
#
# Epoch 464
# Feature set: ['darker', 'black_thin', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_9', 'color_entropy', 'rough', 'dominating_texture', 'texture_1', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'in_shape', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7358156028368794,
# Recall: 0.7211703958691911
#
# Reward: 0.7211703958691911
#
# Epoch 465
# Feature set: ['darker', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_9', 'color_entropy', 'rough', 'dominating_texture', 'texture_1', 'texture_2', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7065602836879432,
# Recall: 0.6764199655765921
#
# Reward: 0.6764199655765921
#
# Epoch 466
# Feature set: ['darker', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'rough', 'dominating_texture', 'texture_1', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7136524822695035,
# Recall: 0.7074010327022375
#
# Reward: 0.7074010327022375
#
# Epoch 467
# Feature set: ['darker', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'rough', 'dominating_texture', 'texture_1', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'rel_length', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7127659574468085,
# Recall: 0.7074010327022375
#
# Reward: 0.7074010327022375
#
# Epoch 468
# Feature set: ['darker', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'rough', 'dominating_texture', 'texture_1', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'rel_length', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_7'],
# Accuracy: 0.7207446808510638,
# Recall: 0.7091222030981067
#
# Reward: 0.7091222030981067
#
# Epoch 469
# Feature set: ['darker', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'rough', 'dominating_texture', 'texture_1', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'rel_length', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_7'],
# Accuracy: 0.7056737588652482,
# Recall: 0.685025817555938
#
# Reward: 0.685025817555938
#
# Epoch 470
# Feature set: ['darker', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'rough', 'dominating_texture', 'texture_1', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'rel_length', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.6985815602836879,
# Recall: 0.6609294320137694
#
# Reward: 0.6609294320137694
#
# Epoch 471
# Feature set: ['darker', 'color_bin_3', 'color_bin_5', 'color_bin_9', 'rough', 'dominating_texture', 'texture_1', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'rel_length', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.723404255319149,
# Recall: 0.7108433734939759
#
# Reward: 0.7108433734939759
#
# Epoch 472
# Feature set: ['darker', 'reddish', 'color_bin_3', 'color_bin_5', 'color_bin_7', 'color_bin_9', 'rough', 'dominating_texture', 'texture_1', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'rel_length', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7163120567375887,
# Recall: 0.6901893287435457
#
# Reward: 0.6901893287435457
#
# Epoch 473
# Feature set: ['darker', 'color_bin_3', 'color_bin_5', 'color_bin_7', 'color_bin_9', 'rough', 'dominating_texture', 'texture_1', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7207446808510638,
# Recall: 0.7177280550774526
#
# Reward: 0.7177280550774526
#
# Epoch 474
# Feature set: ['darker', 'color_bin_3', 'color_bin_5', 'color_bin_7', 'color_bin_9', 'rough', 'dominating_texture', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'rel_length', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7065602836879432,
# Recall: 0.6901893287435457
#
# Reward: 0.6901893287435457
#
# Epoch 475
# Feature set: ['darker', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_9', 'rough', 'dominating_texture', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'rel_length', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7216312056737588,
# Recall: 0.6953528399311532
#
# Reward: 0.6953528399311532
#
# Epoch 476
# Feature set: ['darker', 'reddish', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'rough', 'dominating_texture', 'texture_3', 'texture_4', 'rough_entropy', 'number_lengthy_objects', 'rel_length', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7136524822695035,
# Recall: 0.6729776247848537
#
# Reward: 0.6729776247848537
#
# Epoch 477
# Feature set: ['darker', 'reddish', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'rough', 'dominating_texture', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7225177304964538,
# Recall: 0.7091222030981067
#
# Reward: 0.7091222030981067
#
# Epoch 478
# Feature set: ['darker', 'reddish', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_9', 'rough', 'dominating_texture', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7278368794326241,
# Recall: 0.7211703958691911
#
# Reward: 0.7211703958691911
#
# Epoch 479
# Feature set: ['darker', 'reddish', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_9', 'rough', 'dominating_texture', 'texture_3', 'texture_4', 'texture_6', 'lengthy', 'number_lengthy_objects', 'rel_length', 'in_shape', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7349290780141844,
# Recall: 0.7349397590361446
#
# Reward: 0.7349397590361446
#
# Epoch 480
# Feature set: ['darker', 'reddish', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_9', 'rough', 'dominating_texture', 'texture_1', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7287234042553191,
# Recall: 0.7194492254733219
#
# Reward: 0.7194492254733219
#
# Epoch 481
# Feature set: ['darker', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_9', 'dominating_texture', 'texture_1', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'rel_length', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7012411347517731,
# Recall: 0.6798623063683304
#
# Reward: 0.6798623063683304
#
# Epoch 482
# Feature set: ['darker', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'rough', 'dominating_texture', 'texture_1', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'rel_length', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7180851063829787,
# Recall: 0.7074010327022375
#
# Reward: 0.7074010327022375
#
# Epoch 483
# Feature set: ['darker', 'black_thin', 'color_bin_3', 'color_bin_5', 'color_bin_7', 'color_bin_9', 'rough', 'dominating_texture', 'texture_1', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'rel_length', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7358156028368794,
# Recall: 0.7211703958691911
#
# Reward: 0.7211703958691911
#
# Epoch 484
# Feature set: ['darker', 'color_bin_3', 'color_bin_5', 'color_bin_7', 'color_bin_9', 'rough', 'dominating_texture', 'texture_1', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'rel_length', 'roundness', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7136524822695035,
# Recall: 0.7039586919104991
#
# Reward: 0.7039586919104991
#
# Epoch 485
# Feature set: ['darker', 'color_bin_3', 'color_bin_5', 'color_bin_7', 'color_bin_9', 'rough', 'dominating_texture', 'texture_1', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'rel_length', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7012411347517731,
# Recall: 0.7022375215146299
#
# Reward: 0.7022375215146299
#
# Epoch 486
# Feature set: ['darker', 'color_bin_3', 'color_bin_5', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'rough', 'dominating_texture', 'texture_1', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'rel_length', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7109929078014184,
# Recall: 0.7074010327022375
#
# Reward: 0.7074010327022375
#
# Epoch 487
# Feature set: ['darker', 'color_bin_3', 'color_bin_5', 'color_bin_7', 'color_bin_9', 'rough', 'dominating_texture', 'texture_1', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'in_shape', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.725177304964539,
# Recall: 0.7056798623063684
#
# Reward: 0.7056798623063684
#
# Epoch 488
# Feature set: ['darker', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'rough', 'dominating_texture', 'texture_1', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7136524822695035,
# Recall: 0.7074010327022375
#
# Reward: 0.7074010327022375
#
# Epoch 489
# Feature set: ['darker', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'rough', 'dominating_texture', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7030141843971631,
# Recall: 0.6729776247848537
#
# Reward: 0.6729776247848537
#
# Epoch 490
# Feature set: ['darker', 'black_thin', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'rough', 'dominating_texture', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7189716312056738,
# Recall: 0.7005163511187608
#
# Reward: 0.7005163511187608
#
# Epoch 491
# Feature set: ['darker', 'black_thin', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'rough', 'dominating_texture', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'rel_length', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.726063829787234,
# Recall: 0.7177280550774526
#
# Reward: 0.7177280550774526
#
# Epoch 492
# Feature set: ['darker', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'rough', 'dominating_texture', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'rel_length', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7207446808510638,
# Recall: 0.7091222030981067
#
# Reward: 0.7091222030981067
#
# Epoch 493
# Feature set: ['darker', 'color_bin_3', 'color_bin_4', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'rough', 'dominating_texture', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'rel_length', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7030141843971631,
# Recall: 0.6884681583476764
#
# Reward: 0.6884681583476764
#
# Epoch 494
# Feature set: ['darker', 'black_thin', 'color_bin_3', 'color_bin_4', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'rough', 'dominating_texture', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'rel_length', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7163120567375887,
# Recall: 0.7160068846815835
#
# Reward: 0.7160068846815835
#
# Epoch 495
# Feature set: ['darker', 'black_thin', 'color_bin_3', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'rough', 'dominating_texture', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'rel_length', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7216312056737588,
# Recall: 0.7401032702237521
#
# Reward: 0.7401032702237521
#
# Epoch 496
# Feature set: ['darker', 'reddish', 'color_bin_3', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'rough', 'dominating_texture', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7198581560283688,
# Recall: 0.7160068846815835
#
# Reward: 0.7160068846815835
#
# Epoch 497
# Feature set: ['darker', 'reddish', 'metallic', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'rough', 'dominating_texture', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.725177304964539,
# Recall: 0.7211703958691911
#
# Reward: 0.7211703958691911
#
# Epoch 498
# Feature set: ['darker', 'metallic', 'color_bin_3', 'color_bin_5', 'color_bin_7', 'color_bin_9', 'rough', 'dominating_texture', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7056737588652482,
# Recall: 0.6987951807228916
#
# Reward: 0.6987951807228916
#
# Epoch 499
# Feature set: ['darker', 'color_bin_3', 'color_bin_5', 'color_bin_9', 'rough', 'dominating_texture', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.700354609929078,
# Recall: 0.6901893287435457
#
# Reward: 0.6901893287435457
# Best Feature set: ('darker', 'black', 'color_bin_3', 'color_bin_5', 'color_bin_7', 'color_bin_9', 'rough', 'dominating_texture', 'texture_1', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'rel_length', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7')
# Reward: 0.7487091222030982

# %%
graffiti_classifier.run(['darker', 'black', 'color_bin_3', 'color_bin_5', 'color_bin_7', 'color_bin_9', 'rough', 'dominating_texture', 
                         'texture_1', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'rel_length', 
                         'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'])
# Out:
# Feature set: ['darker', 'black', 'color_bin_3', 'color_bin_5', 'color_bin_7', 'color_bin_9', 'rough', 'dominating_texture', 'texture_1', 'texture_3', 'texture_4', 'texture_6', 'rough_entropy', 'number_lengthy_objects', 'rel_length', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7331560283687943,
# Recall: 0.7487091222030982
# 0.7487091222030982

# %% [markdown]
# **Analysis Drainage**

# %%
# Create a classifier for drainage:

drainage_classifier = ClassificationModel("Drainage")

# %%
# Run classification on hypothesized features:

hypothesized_features_drainage = ["darker", "black", "color_bin_1", "color_bin_2", "color_bin_3", "color_bin_4", "color_bin_5", "color_bin_6", 
                                  "color_bin_7", "color_bin_8", "color_bin_9", "color_entropy", "rough", "texture_0", "texture_1", "texture_2", 
                                  "texture_3", "texture_4", "texture_5", "texture_6", "texture_7", "texture_8", "texture_9", "rough_entropy",
                                  "lengthy", "number_lengthy_objects", "lengthy_aspect_ratio", "rel_length", "hu_moment_1", "hu_moment_2", 
                                  "hu_moment_3", "hu_moment_4", "hu_moment_5", "hu_moment_6", "hu_moment_7"] ## Insert hypothesized most relevant features here

drainage_classifier.run(hypothesized_features_drainage)
# Out:
# Feature set: ['darker', 'black', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_4', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'rough', 'texture_0', 'texture_1', 'texture_2', 'texture_3', 'texture_4', 'texture_5', 'texture_6', 'texture_7', 'texture_8', 'texture_9', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'rel_length', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7326607818411097,
# Recall: 0.7655860349127181
# 0.7655860349127181

# %%
# Apply meta-learning and compare with random choices:

train_agent(drainage_classifier, initial_features=hypothesized_features_drainage, epochs=500)
random_monkey(drainage_classifier, repetitions=500)
# Out:
# Epoch 0
# Feature set: ['darker', 'black', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_4', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'rough', 'texture_0', 'texture_1', 'texture_2', 'texture_3', 'texture_4', 'texture_5', 'texture_6', 'texture_7', 'texture_8', 'texture_9', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'rel_length', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7377049180327869,
# Recall: 0.7755610972568578
#
# Reward: 0.7755610972568578
#
# Epoch 1
# Feature set: ['darker', 'black', 'color_bin_1', 'color_bin_2', 'color_bin_4', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'rough', 'texture_0', 'texture_1', 'texture_2', 'texture_3', 'texture_4', 'texture_5', 'texture_6', 'texture_7', 'texture_8', 'texture_9', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'rel_length', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7490542244640606,
# Recall: 0.8054862842892768
#
# Reward: 0.8054862842892768
#
# Epoch 2
# Feature set: ['darker', 'black', 'color_bin_1', 'color_bin_2', 'color_bin_4', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'rough', 'texture_0', 'texture_1', 'texture_2', 'texture_3', 'texture_4', 'texture_5', 'texture_6', 'texture_7', 'texture_8', 'texture_9', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'rel_length', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.7465321563682219,
# Recall: 0.7880299251870324
#
# Reward: 0.7880299251870324
#
# Epoch 3
# Feature set: ['darker', 'black', 'color_bin_1', 'color_bin_2', 'color_bin_4', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'rough', 'texture_0', 'texture_1', 'texture_2', 'texture_3', 'texture_5', 'texture_6', 'texture_7', 'texture_8', 'texture_9', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'rel_length', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.7414880201765448,
# Recall: 0.770573566084788
#
# Reward: 0.770573566084788
#
# Epoch 4
# Feature set: ['darker', 'colorful', 'black', 'color_bin_1', 'color_bin_2', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'rough', 'texture_0', 'texture_1', 'texture_2', 'texture_5', 'texture_6', 'texture_7', 'texture_8', 'texture_9', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'rel_length', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.7440100882723834,
# Recall: 0.7880299251870324
#
# Reward: 0.7880299251870324
#
# Epoch 5
# Feature set: ['darker', 'colorful', 'black', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'texture_0', 'texture_1', 'texture_2', 'texture_5', 'texture_6', 'texture_8', 'texture_9', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'rel_length', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.7490542244640606,
# Recall: 0.8054862842892768
#
# Reward: 0.8054862842892768
#
# Epoch 6
# Feature set: ['darker', 'gradient', 'metallic', 'colorful', 'black', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_4', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'texture_0', 'texture_1', 'texture_2', 'texture_5', 'texture_6', 'texture_8', 'texture_9', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'rel_length', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.7313997477931904,
# Recall: 0.7655860349127181
#
# Reward: 0.7655860349127181
#
# Epoch 7
# Feature set: ['darker', 'gradient', 'metallic', 'colorful', 'black', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_4', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'texture_1', 'texture_2', 'texture_5', 'texture_6', 'texture_8', 'texture_9', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'rel_length', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.7351828499369483,
# Recall: 0.770573566084788
#
# Reward: 0.770573566084788
#
# Epoch 8
# Feature set: ['darker', 'gradient', 'colorful', 'black', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_4', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'texture_1', 'texture_2', 'texture_5', 'texture_6', 'texture_8', 'texture_9', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'rel_length', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.742749054224464,
# Recall: 0.7805486284289277
#
# Reward: 0.7805486284289277
#
# Epoch 9
# Feature set: ['darker', 'gradient', 'colorful', 'black', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_4', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'texture_1', 'texture_2', 'texture_5', 'texture_6', 'texture_7', 'texture_8', 'texture_9', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'rel_length', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.7440100882723834,
# Recall: 0.7780548628428927
#
# Reward: 0.7780548628428927
#
# Epoch 10
# Feature set: ['darker', 'gradient', 'colorful', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_4', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'texture_1', 'texture_2', 'texture_5', 'texture_6', 'texture_7', 'texture_8', 'texture_9', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'rel_length', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.7175283732660782,
# Recall: 0.7506234413965087
#
# Reward: 0.7506234413965087
#
# Epoch 11
# Feature set: ['darker', 'gradient', 'colorful', 'color_bin_1', 'color_bin_4', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'texture_1', 'texture_2', 'texture_5', 'texture_6', 'texture_7', 'texture_8', 'texture_9', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'rel_length', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.7162673392181589,
# Recall: 0.7581047381546134
#
# Reward: 0.7581047381546134
#
# Epoch 12
# Feature set: ['darker', 'gradient', 'colorful', 'color_bin_1', 'color_bin_2', 'color_bin_4', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'texture_1', 'texture_2', 'texture_5', 'texture_6', 'texture_7', 'texture_8', 'texture_9', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'rel_length', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.725094577553594,
# Recall: 0.770573566084788
#
# Reward: 0.770573566084788
#
# Epoch 13
# Feature set: ['gradient', 'colorful', 'color_bin_1', 'color_bin_2', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'texture_1', 'texture_2', 'texture_5', 'texture_6', 'texture_7', 'texture_8', 'texture_9', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.7225725094577553,
# Recall: 0.7331670822942643
#
# Reward: 0.7331670822942643
#
# Epoch 14
# Feature set: ['gradient', 'color_bin_1', 'color_bin_2', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'texture_1', 'texture_2', 'texture_5', 'texture_6', 'texture_7', 'texture_8', 'texture_9', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'rel_length', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.7187894073139974,
# Recall: 0.7182044887780549
#
# Reward: 0.7182044887780549
#
# Epoch 15
# Feature set: ['gradient', 'color_bin_1', 'color_bin_2', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'texture_0', 'texture_1', 'texture_2', 'texture_5', 'texture_6', 'texture_7', 'texture_8', 'texture_9', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'rel_length', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.725094577553594,
# Recall: 0.7356608478802993
#
# Reward: 0.7356608478802993
#
# Epoch 16
# Feature set: ['gradient', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'texture_0', 'texture_1', 'texture_2', 'texture_5', 'texture_6', 'texture_7', 'texture_8', 'texture_9', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'rel_length', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.7364438839848676,
# Recall: 0.7256857855361596
#
# Reward: 0.7256857855361596
#
# Epoch 17
# Feature set: ['gradient', 'colorful', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'texture_0', 'texture_1', 'texture_2', 'texture_5', 'texture_6', 'texture_7', 'texture_8', 'texture_9', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'rel_length', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.7276166456494325,
# Recall: 0.7331670822942643
#
# Reward: 0.7331670822942643
#
# Epoch 18
# Feature set: ['gradient', 'colorful', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'texture_0', 'texture_1', 'texture_2', 'texture_5', 'texture_6', 'texture_7', 'texture_8', 'texture_9', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'hu_moment_4', 'hu_moment_5'],
# Accuracy: 0.7288776796973518,
# Recall: 0.7381546134663342
#
# Reward: 0.7381546134663342
#
# Epoch 19
# Feature set: ['gradient', 'colorful', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'texture_0', 'texture_1', 'texture_2', 'texture_5', 'texture_6', 'texture_7', 'texture_8', 'texture_9', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio'],
# Accuracy: 0.7036569987389659,
# Recall: 0.7182044887780549
#
# Reward: 0.7182044887780549
#
# Epoch 20
# Feature set: ['gradient', 'colorful', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'texture_0', 'texture_1', 'texture_2', 'texture_4', 'texture_5', 'texture_6', 'texture_7', 'texture_8', 'texture_9', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio'],
# Accuracy: 0.7351828499369483,
# Recall: 0.7556109725685786
#
# Reward: 0.7556109725685786
#
# Epoch 21
# Feature set: ['gradient', 'colorful', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'texture_0', 'texture_1', 'texture_2', 'texture_4', 'texture_5', 'texture_6', 'texture_7', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio'],
# Accuracy: 0.7238335435056746,
# Recall: 0.743142144638404
#
# Reward: 0.743142144638404
#
# Epoch 22
# Feature set: ['gradient', 'colorful', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'texture_0', 'texture_1', 'texture_2', 'texture_4', 'texture_6', 'texture_7', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio'],
# Accuracy: 0.7238335435056746,
# Recall: 0.7456359102244389
#
# Reward: 0.7456359102244389
#
# Epoch 23
# Feature set: ['gradient', 'colorful', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'texture_0', 'texture_1', 'texture_4', 'texture_6', 'texture_7', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'hu_moment_7'],
# Accuracy: 0.7301387137452712,
# Recall: 0.743142144638404
#
# Reward: 0.743142144638404
#
# Epoch 24
# Feature set: ['gradient', 'colorful', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'texture_0', 'texture_1', 'texture_4', 'texture_6', 'texture_7', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio'],
# Accuracy: 0.7288776796973518,
# Recall: 0.743142144638404
#
# Reward: 0.743142144638404
#
# Epoch 25
# Feature set: ['gradient', 'colorful', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'rough', 'texture_1', 'texture_4', 'texture_6', 'texture_7', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio'],
# Accuracy: 0.7213114754098361,
# Recall: 0.7456359102244389
#
# Reward: 0.7456359102244389
#
# Epoch 26
# Feature set: ['gradient', 'colorful', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'rough', 'texture_1', 'texture_4', 'texture_6', 'texture_7', 'texture_8', 'rough_entropy', 'lengthy', 'lengthy_aspect_ratio'],
# Accuracy: 0.7150063051702396,
# Recall: 0.7331670822942643
#
# Reward: 0.7331670822942643
#
# Epoch 27
# Feature set: ['gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'rough', 'texture_1', 'texture_4', 'texture_6', 'texture_7', 'texture_8', 'texture_9', 'rough_entropy', 'lengthy', 'lengthy_aspect_ratio'],
# Accuracy: 0.7364438839848676,
# Recall: 0.7630922693266833
#
# Reward: 0.7630922693266833
#
# Epoch 28
# Feature set: ['gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'rough', 'texture_1', 'texture_4', 'texture_7', 'texture_8', 'rough_entropy', 'lengthy', 'lengthy_aspect_ratio'],
# Accuracy: 0.7402269861286255,
# Recall: 0.7655860349127181
#
# Reward: 0.7655860349127181
#
# Epoch 29
# Feature set: ['gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'rough', 'texture_1', 'texture_4', 'texture_7', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'rel_length'],
# Accuracy: 0.7477931904161412,
# Recall: 0.7605985037406484
#
# Reward: 0.7605985037406484
#
# Epoch 30
# Feature set: ['gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'rough', 'texture_1', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'rel_length', 'hu_moment_5'],
# Accuracy: 0.733921815889029,
# Recall: 0.7605985037406484
#
# Reward: 0.7605985037406484
#
# Epoch 31
# Feature set: ['gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'rough', 'texture_1', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'rel_length', 'hu_moment_5'],
# Accuracy: 0.7402269861286255,
# Recall: 0.7680798004987531
#
# Reward: 0.7680798004987531
#
# Epoch 32
# Feature set: ['gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'rough', 'texture_1', 'texture_2', 'texture_6', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'rel_length', 'hu_moment_5'],
# Accuracy: 0.7477931904161412,
# Recall: 0.773067331670823
#
# Reward: 0.773067331670823
#
# Epoch 33
# Feature set: ['gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'texture_1', 'texture_2', 'texture_6', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'hu_moment_5'],
# Accuracy: 0.725094577553594,
# Recall: 0.7381546134663342
#
# Reward: 0.7381546134663342
#
# Epoch 34
# Feature set: ['gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'texture_1', 'texture_2', 'texture_6', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'hu_moment_1', 'hu_moment_2', 'hu_moment_5'],
# Accuracy: 0.7263556116015133,
# Recall: 0.7356608478802993
#
# Reward: 0.7356608478802993
#
# Epoch 35
# Feature set: ['gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'texture_1', 'texture_2', 'texture_6', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'hu_moment_2', 'hu_moment_5'],
# Accuracy: 0.742749054224464,
# Recall: 0.7755610972568578
#
# Reward: 0.7755610972568578
#
# Epoch 36
# Feature set: ['gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'texture_1', 'texture_2', 'texture_6', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'hu_moment_5'],
# Accuracy: 0.7288776796973518,
# Recall: 0.7556109725685786
#
# Reward: 0.7556109725685786
#
# Epoch 37
# Feature set: ['gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'texture_1', 'texture_2', 'texture_6', 'texture_7', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'hu_moment_5'],
# Accuracy: 0.7326607818411097,
# Recall: 0.7381546134663342
#
# Reward: 0.7381546134663342
#
# Epoch 38
# Feature set: ['gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'texture_1', 'texture_6', 'texture_7', 'texture_8', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio'],
# Accuracy: 0.7477931904161412,
# Recall: 0.7655860349127181
#
# Reward: 0.7655860349127181
#
# Epoch 39
# Feature set: ['gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'texture_1', 'texture_2', 'texture_6', 'texture_7', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio'],
# Accuracy: 0.742749054224464,
# Recall: 0.7556109725685786
#
# Reward: 0.7556109725685786
#
# Epoch 40
# Feature set: ['gradient', 'metallic', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'texture_1', 'texture_2', 'texture_6', 'texture_7', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio'],
# Accuracy: 0.7414880201765448,
# Recall: 0.7630922693266833
#
# Reward: 0.7630922693266833
#
# Epoch 41
# Feature set: ['gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'texture_1', 'texture_2', 'texture_6', 'texture_7', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio'],
# Accuracy: 0.742749054224464,
# Recall: 0.7556109725685786
#
# Reward: 0.7556109725685786
#
# Epoch 42
# Feature set: ['gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'texture_1', 'texture_6', 'texture_7', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio'],
# Accuracy: 0.7313997477931904,
# Recall: 0.7581047381546134
#
# Reward: 0.7581047381546134
#
# Epoch 43
# Feature set: ['gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'texture_0', 'texture_1', 'texture_6', 'texture_7', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'roundness'],
# Accuracy: 0.742749054224464,
# Recall: 0.7630922693266833
#
# Reward: 0.7630922693266833
#
# Epoch 44
# Feature set: ['gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'texture_0', 'texture_1', 'texture_6', 'texture_7', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio'],
# Accuracy: 0.7288776796973518,
# Recall: 0.7605985037406484
#
# Reward: 0.7605985037406484
#
# Epoch 45
# Feature set: ['gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'texture_0', 'texture_1', 'texture_2', 'texture_6', 'texture_7', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio'],
# Accuracy: 0.7288776796973518,
# Recall: 0.7481296758104738
#
# Reward: 0.7481296758104738
#
# Epoch 46
# Feature set: ['gradient', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'texture_0', 'texture_1', 'texture_2', 'texture_6', 'texture_7', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio'],
# Accuracy: 0.7477931904161412,
# Recall: 0.7955112219451371
#
# Reward: 0.7955112219451371
#
# Epoch 47
# Feature set: ['gradient', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'texture_0', 'texture_1', 'texture_6', 'texture_7', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio'],
# Accuracy: 0.7490542244640606,
# Recall: 0.7780548628428927
#
# Reward: 0.7780548628428927
#
# Epoch 48
# Feature set: ['gradient', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'texture_0', 'texture_1', 'texture_6', 'texture_7', 'texture_8', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'in_shape', 'roundness'],
# Accuracy: 0.7503152585119798,
# Recall: 0.7830423940149626
#
# Reward: 0.7830423940149626
#
# Epoch 49
# Feature set: ['gradient', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'texture_0', 'texture_1', 'texture_6', 'texture_7', 'texture_8', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'roundness'],
# Accuracy: 0.7528373266078184,
# Recall: 0.770573566084788
#
# Reward: 0.770573566084788
#
# Epoch 50
# Feature set: ['gradient', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'texture_1', 'texture_6', 'texture_7', 'texture_8', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'roundness'],
# Accuracy: 0.7402269861286255,
# Recall: 0.7780548628428927
#
# Reward: 0.7780548628428927
#
# Epoch 51
# Feature set: ['gradient', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'texture_1', 'texture_3', 'texture_6', 'texture_7', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio'],
# Accuracy: 0.7402269861286255,
# Recall: 0.7755610972568578
#
# Reward: 0.7755610972568578
#
# Epoch 52
# Feature set: ['gradient', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'texture_1', 'texture_6', 'texture_7', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'hu_moment_4'],
# Accuracy: 0.7515762925598991,
# Recall: 0.7830423940149626
#
# Reward: 0.7830423940149626
#
# Epoch 53
# Feature set: ['gradient', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'texture_1', 'texture_6', 'texture_7', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'hu_moment_4', 'hu_moment_5'],
# Accuracy: 0.7288776796973518,
# Recall: 0.7605985037406484
#
# Reward: 0.7605985037406484
#
# Epoch 54
# Feature set: ['gradient', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'texture_1', 'texture_6', 'texture_7', 'texture_8', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'hu_moment_4', 'hu_moment_5'],
# Accuracy: 0.742749054224464,
# Recall: 0.7830423940149626
#
# Reward: 0.7830423940149626
#
# Epoch 55
# Feature set: ['gradient', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_4', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'texture_1', 'texture_6', 'texture_7', 'texture_8', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'rel_length', 'hu_moment_4', 'hu_moment_5'],
# Accuracy: 0.7276166456494325,
# Recall: 0.7581047381546134
#
# Reward: 0.7581047381546134
#
# Epoch 56
# Feature set: ['gradient', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'texture_0', 'texture_1', 'texture_3', 'texture_6', 'texture_7', 'texture_8', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'rel_length', 'hu_moment_4', 'hu_moment_5'],
# Accuracy: 0.7364438839848676,
# Recall: 0.773067331670823
#
# Reward: 0.773067331670823
#
# Epoch 57
# Feature set: ['gradient', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'texture_1', 'texture_3', 'texture_6', 'texture_7', 'texture_8', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'rel_length', 'hu_moment_4', 'hu_moment_5'],
# Accuracy: 0.7288776796973518,
# Recall: 0.7556109725685786
#
# Reward: 0.7556109725685786
#
# Epoch 58
# Feature set: ['gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'texture_1', 'texture_2', 'texture_3', 'texture_6', 'texture_7', 'texture_8', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'rel_length', 'hu_moment_4', 'hu_moment_5'],
# Accuracy: 0.7465321563682219,
# Recall: 0.7456359102244389
#
# Reward: 0.7456359102244389
#
# Epoch 59
# Feature set: ['gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'texture_1', 'texture_2', 'texture_3', 'texture_6', 'texture_7', 'texture_8', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'rel_length', 'hu_moment_4'],
# Accuracy: 0.7477931904161412,
# Recall: 0.7605985037406484
#
# Reward: 0.7605985037406484
#
# Epoch 60
# Feature set: ['gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'texture_1', 'texture_2', 'texture_6', 'texture_7', 'texture_8', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'rel_length', 'hu_moment_4'],
# Accuracy: 0.7301387137452712,
# Recall: 0.7281795511221946
#
# Reward: 0.7281795511221946
#
# Epoch 61
# Feature set: ['gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'texture_1', 'texture_2', 'texture_6', 'texture_7', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'hu_moment_4'],
# Accuracy: 0.7414880201765448,
# Recall: 0.7556109725685786
#
# Reward: 0.7556109725685786
#
# Epoch 62
# Feature set: ['gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'texture_1', 'texture_2', 'texture_6', 'texture_7', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'rel_length', 'hu_moment_4'],
# Accuracy: 0.7402269861286255,
# Recall: 0.7655860349127181
#
# Reward: 0.7655860349127181
#
# Epoch 63
# Feature set: ['gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'texture_1', 'texture_2', 'texture_6', 'texture_7', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'rel_length', 'hu_moment_4'],
# Accuracy: 0.7326607818411097,
# Recall: 0.7556109725685786
#
# Reward: 0.7556109725685786
#
# Epoch 64
# Feature set: ['gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'texture_1', 'texture_6', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'hu_moment_4'],
# Accuracy: 0.7288776796973518,
# Recall: 0.7556109725685786
#
# Reward: 0.7556109725685786
#
# Epoch 65
# Feature set: ['gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'texture_1', 'texture_6', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'hu_moment_4'],
# Accuracy: 0.7150063051702396,
# Recall: 0.7456359102244389
#
# Reward: 0.7456359102244389
#
# Epoch 66
# Feature set: ['gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'texture_1', 'texture_6', 'texture_7', 'texture_8', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'hu_moment_4'],
# Accuracy: 0.7263556116015133,
# Recall: 0.7581047381546134
#
# Reward: 0.7581047381546134
#
# Epoch 67
# Feature set: ['gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'texture_1', 'texture_6', 'texture_7', 'texture_8', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio'],
# Accuracy: 0.7301387137452712,
# Recall: 0.7506234413965087
#
# Reward: 0.7506234413965087
#
# Epoch 68
# Feature set: ['gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'texture_1', 'texture_6', 'texture_7', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio'],
# Accuracy: 0.7414880201765448,
# Recall: 0.7531172069825436
#
# Reward: 0.7531172069825436
#
# Epoch 69
# Feature set: ['gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'texture_1', 'texture_6', 'texture_7', 'texture_8', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio'],
# Accuracy: 0.7301387137452712,
# Recall: 0.7506234413965087
#
# Reward: 0.7506234413965087
#
# Epoch 70
# Feature set: ['gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'texture_1', 'texture_6', 'texture_7', 'texture_8', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio'],
# Accuracy: 0.7477931904161412,
# Recall: 0.7655860349127181
#
# Reward: 0.7655860349127181
#
# Epoch 71
# Feature set: ['gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'texture_1', 'texture_6', 'texture_7', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'roundness'],
# Accuracy: 0.7288776796973518,
# Recall: 0.7605985037406484
#
# Reward: 0.7605985037406484
#
# Epoch 72
# Feature set: ['gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'texture_1', 'texture_6', 'texture_7', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'roundness'],
# Accuracy: 0.7288776796973518,
# Recall: 0.7356608478802993
#
# Reward: 0.7356608478802993
#
# Epoch 73
# Feature set: ['gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'texture_1', 'texture_6', 'texture_7', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'roundness'],
# Accuracy: 0.7288776796973518,
# Recall: 0.7605985037406484
#
# Reward: 0.7605985037406484
#
# Epoch 74
# Feature set: ['gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'texture_1', 'texture_4', 'texture_6', 'texture_7', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'roundness'],
# Accuracy: 0.7440100882723834,
# Recall: 0.7680798004987531
#
# Reward: 0.7680798004987531
#
# Epoch 75
# Feature set: ['gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'texture_1', 'texture_4', 'texture_6', 'texture_7', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio'],
# Accuracy: 0.7452711223203027,
# Recall: 0.7605985037406484
#
# Reward: 0.7605985037406484
#
# Epoch 76
# Feature set: ['gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'texture_1', 'texture_6', 'texture_7', 'texture_8', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio'],
# Accuracy: 0.7477931904161412,
# Recall: 0.7655860349127181
#
# Reward: 0.7655860349127181
#
# Epoch 77
# Feature set: ['gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'texture_1', 'texture_6', 'texture_7', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio'],
# Accuracy: 0.7313997477931904,
# Recall: 0.7581047381546134
#
# Reward: 0.7581047381546134
#
# Epoch 78
# Feature set: ['gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'texture_1', 'texture_2', 'texture_6', 'texture_7', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio'],
# Accuracy: 0.7288776796973518,
# Recall: 0.7481296758104738
#
# Reward: 0.7481296758104738
#
# Epoch 79
# Feature set: ['gradient', 'metallic', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'texture_1', 'texture_2', 'texture_4', 'texture_6', 'texture_7', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio'],
# Accuracy: 0.7452711223203027,
# Recall: 0.7655860349127181
#
# Reward: 0.7655860349127181
#
# Epoch 80
# Feature set: ['gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'texture_1', 'texture_2', 'texture_6', 'texture_7', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio'],
# Accuracy: 0.7288776796973518,
# Recall: 0.7481296758104738
#
# Reward: 0.7481296758104738
#
# Epoch 81
# Feature set: ['gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'texture_1', 'texture_6', 'texture_7', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio'],
# Accuracy: 0.7313997477931904,
# Recall: 0.7581047381546134
#
# Reward: 0.7581047381546134
#
# Epoch 82
# Feature set: ['gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'texture_1', 'texture_2', 'texture_6', 'texture_7', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'roundness'],
# Accuracy: 0.7389659520807061,
# Recall: 0.7481296758104738
#
# Reward: 0.7481296758104738
#
# Epoch 83
# Feature set: ['gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'texture_1', 'texture_2', 'texture_6', 'texture_7', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'roundness', 'hu_moment_7'],
# Accuracy: 0.7465321563682219,
# Recall: 0.770573566084788
#
# Reward: 0.770573566084788
#
# Epoch 84
# Feature set: ['gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'texture_1', 'texture_2', 'texture_6', 'texture_7', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'roundness'],
# Accuracy: 0.7389659520807061,
# Recall: 0.7481296758104738
#
# Reward: 0.7481296758104738
#
# Epoch 85
# Feature set: ['gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'texture_1', 'texture_6', 'texture_7', 'texture_8', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio'],
# Accuracy: 0.7477931904161412,
# Recall: 0.7655860349127181
#
# Reward: 0.7655860349127181
#
# Epoch 86
# Feature set: ['gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_4', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'texture_1', 'texture_6', 'texture_7', 'texture_8', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio'],
# Accuracy: 0.7225725094577553,
# Recall: 0.7531172069825436
#
# Reward: 0.7531172069825436
#
# Epoch 87
# Feature set: ['gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'texture_1', 'texture_6', 'texture_7', 'texture_8', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio'],
# Accuracy: 0.7477931904161412,
# Recall: 0.7655860349127181
#
# Reward: 0.7655860349127181
#
# Epoch 88
# Feature set: ['gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'texture_1', 'texture_6', 'texture_7', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio'],
# Accuracy: 0.725094577553594,
# Recall: 0.7331670822942643
#
# Reward: 0.7331670822942643
#
# Epoch 89
# Feature set: ['gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'texture_1', 'texture_6', 'texture_7', 'lengthy', 'lengthy_aspect_ratio'],
# Accuracy: 0.725094577553594,
# Recall: 0.7381546134663342
#
# Reward: 0.7381546134663342
#
# Epoch 90
# Feature set: ['gradient', 'reddish', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'texture_1', 'texture_6', 'texture_7', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio'],
# Accuracy: 0.7301387137452712,
# Recall: 0.7556109725685786
#
# Reward: 0.7556109725685786
#
# Epoch 91
# Feature set: ['gradient', 'reddish', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'texture_1', 'texture_4', 'texture_6', 'texture_7', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio'],
# Accuracy: 0.742749054224464,
# Recall: 0.773067331670823
#
# Reward: 0.773067331670823
#
# Epoch 92
# Feature set: ['gradient', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'texture_1', 'texture_4', 'texture_6', 'texture_7', 'texture_8', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'rel_length'],
# Accuracy: 0.7528373266078184,
# Recall: 0.7955112219451371
#
# Reward: 0.7955112219451371
#
# Epoch 93
# Feature set: ['gradient', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'texture_1', 'texture_4', 'texture_6', 'texture_7', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'rel_length', 'hu_moment_5'],
# Accuracy: 0.7490542244640606,
# Recall: 0.7855361596009975
#
# Reward: 0.7855361596009975
#
# Epoch 94
# Feature set: ['gradient', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'texture_1', 'texture_6', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'rel_length', 'hu_moment_5'],
# Accuracy: 0.7326607818411097,
# Recall: 0.770573566084788
#
# Reward: 0.770573566084788
#
# Epoch 95
# Feature set: ['gradient', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_4', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'texture_1', 'texture_6', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'rel_length', 'hu_moment_5'],
# Accuracy: 0.7414880201765448,
# Recall: 0.7830423940149626
#
# Reward: 0.7830423940149626
#
# Epoch 96
# Feature set: ['gradient', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_4', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'texture_1', 'texture_6', 'texture_8', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'rel_length', 'roundness', 'hu_moment_5'],
# Accuracy: 0.7377049180327869,
# Recall: 0.7655860349127181
#
# Reward: 0.7655860349127181
#
# Epoch 97
# Feature set: ['gradient', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_4', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'texture_1', 'texture_3', 'texture_6', 'texture_8', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'rel_length', 'roundness', 'hu_moment_5'],
# Accuracy: 0.7225725094577553,
# Recall: 0.7630922693266833
#
# Reward: 0.7630922693266833
#
# Epoch 98
# Feature set: ['gradient', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_4', 'color_bin_5', 'color_bin_6', 'color_bin_8', 'color_bin_9', 'texture_1', 'texture_3', 'texture_6', 'texture_8', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'rel_length', 'roundness', 'hu_moment_1', 'hu_moment_5'],
# Accuracy: 0.7440100882723834,
# Recall: 0.770573566084788
#
# Reward: 0.770573566084788
#
# Epoch 99
# Feature set: ['gradient', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_4', 'color_bin_5', 'color_bin_6', 'color_bin_8', 'color_bin_9', 'texture_1', 'texture_3', 'texture_6', 'texture_8', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'rel_length', 'roundness', 'hu_moment_5'],
# Accuracy: 0.7402269861286255,
# Recall: 0.7605985037406484
#
# Reward: 0.7605985037406484
#
# Epoch 100
# Feature set: ['gradient', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_4', 'color_bin_5', 'color_bin_6', 'color_bin_8', 'color_bin_9', 'texture_1', 'texture_3', 'texture_6', 'texture_8', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'rel_length', 'hu_moment_4', 'hu_moment_5'],
# Accuracy: 0.7276166456494325,
# Recall: 0.7456359102244389
#
# Reward: 0.7456359102244389
#
# Epoch 101
# Feature set: ['gradient', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_4', 'color_bin_5', 'color_bin_6', 'color_bin_8', 'color_bin_9', 'rough', 'texture_1', 'texture_3', 'texture_6', 'texture_8', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'rel_length', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5'],
# Accuracy: 0.7313997477931904,
# Recall: 0.770573566084788
#
# Reward: 0.770573566084788
#
# Epoch 102
# Feature set: ['gradient', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_4', 'color_bin_5', 'color_bin_6', 'color_bin_8', 'color_bin_9', 'texture_1', 'texture_3', 'texture_6', 'texture_8', 'texture_9', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'rel_length', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5'],
# Accuracy: 0.7326607818411097,
# Recall: 0.770573566084788
#
# Reward: 0.770573566084788
#
# Epoch 103
# Feature set: ['darker', 'gradient', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_4', 'color_bin_5', 'color_bin_6', 'color_bin_8', 'color_bin_9', 'texture_1', 'texture_3', 'texture_6', 'texture_8', 'texture_9', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'rel_length', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5'],
# Accuracy: 0.733921815889029,
# Recall: 0.7680798004987531
#
# Reward: 0.7680798004987531
#
# Epoch 104
# Feature set: ['darker', 'gradient', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_4', 'color_bin_5', 'color_bin_8', 'color_bin_9', 'texture_1', 'texture_3', 'texture_5', 'texture_6', 'texture_7', 'texture_8', 'texture_9', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'rel_length', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5'],
# Accuracy: 0.7389659520807061,
# Recall: 0.7581047381546134
#
# Reward: 0.7581047381546134
#
# Epoch 105
# Feature set: ['darker', 'gradient', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_4', 'color_bin_5', 'color_bin_6', 'color_bin_8', 'color_bin_9', 'texture_1', 'texture_3', 'texture_5', 'texture_6', 'texture_7', 'texture_8', 'texture_9', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'rel_length', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5'],
# Accuracy: 0.7313997477931904,
# Recall: 0.7630922693266833
#
# Reward: 0.7630922693266833
#
# Epoch 106
# Feature set: ['darker', 'gradient', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_4', 'color_bin_5', 'color_bin_6', 'color_bin_8', 'color_bin_9', 'texture_1', 'texture_3', 'texture_5', 'texture_6', 'texture_7', 'texture_8', 'texture_9', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'rel_length', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.7200504413619168,
# Recall: 0.7456359102244389
#
# Reward: 0.7456359102244389
#
# Epoch 107
# Feature set: ['darker', 'gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_4', 'color_bin_5', 'color_bin_6', 'color_bin_8', 'color_bin_9', 'texture_1', 'texture_3', 'texture_5', 'texture_6', 'texture_7', 'texture_8', 'texture_9', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'rel_length', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.7326607818411097,
# Recall: 0.7531172069825436
#
# Reward: 0.7531172069825436
#
# Epoch 108
# ...
# Feature set: ['darker', 'reddish', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_4', 'color_bin_8', 'color_bin_9', 'color_entropy', 'texture_0', 'texture_5', 'texture_8', 'lengthy_aspect_ratio', 'rel_length', 'in_shape', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5', 'hu_moment_7'],
# Accuracy: 0.7213114754098361,
# Recall: 0.7605985037406484
#
# Repitition 461
# Feature set: ['gradient', 'metallic', 'black', 'black_thin', 'dominating_color', 'color_bin_2', 'color_bin_4', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'rough', 'texture_0', 'texture_1', 'texture_2', 'texture_3', 'texture_4', 'texture_5', 'texture_7', 'lengthy_aspect_ratio', 'rel_length', 'roundness', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_6'],
# Accuracy: 0.7452711223203027,
# Recall: 0.7830423940149626
#
# Repitition 462
# Feature set: ['gradient', 'colorful', 'black', 'black_thin', 'color_bin_1', 'color_bin_3', 'color_bin_5', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'texture_0', 'texture_2', 'texture_3', 'texture_4', 'texture_8', 'lengthy', 'rel_length', 'hu_moment_2', 'hu_moment_6'],
# Accuracy: 0.7402269861286255,
# Recall: 0.7855361596009975
#
# Repitition 463
# Feature set: ['darker', 'metallic', 'colorful', 'color_bin_1', 'color_bin_4', 'color_bin_6', 'color_bin_8', 'color_bin_9', 'rough', 'texture_2', 'texture_4', 'texture_5', 'texture_6', 'rough_entropy', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7313997477931904,
# Recall: 0.7805486284289277
#
# Repitition 464
# Feature set: ['darker', 'metallic', 'black', 'dominating_color', 'color_bin_2', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_entropy', 'rough', 'texture_0', 'texture_1', 'texture_2', 'texture_4', 'texture_8', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_2', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7503152585119798,
# Recall: 0.8029925187032418
#
# Repitition 465
# Feature set: ['darker', 'reddish', 'colorful', 'black', 'dominating_color', 'color_bin_3', 'color_bin_5', 'color_bin_8', 'rough', 'dominating_texture', 'texture_1', 'texture_2', 'texture_4', 'texture_7', 'texture_8', 'texture_9', 'lengthy', 'rel_length', 'roundness', 'hu_moment_1', 'hu_moment_2', 'hu_moment_7'],
# Accuracy: 0.742749054224464,
# Recall: 0.7855361596009975
#
# Repitition 466
# Feature set: ['darker', 'gradient', 'reddish', 'colorful', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_7', 'color_bin_8', 'rough', 'dominating_texture', 'texture_2', 'texture_3', 'texture_4', 'texture_6', 'texture_7', 'rough_entropy', 'number_lengthy_objects', 'rel_length', 'in_shape', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_5'],
# Accuracy: 0.733921815889029,
# Recall: 0.7805486284289277
#
# Repitition 467
# Feature set: ['black', 'dominating_color', 'color_bin_3', 'color_bin_5', 'color_bin_7', 'color_entropy', 'texture_7', 'rough_entropy', 'lengthy', 'in_shape', 'hu_moment_4', 'hu_moment_7'],
# Accuracy: 0.7187894073139974,
# Recall: 0.7655860349127181
#
# Repitition 468
# Feature set: ['black', 'color_bin_2', 'color_bin_3', 'color_bin_4', 'color_bin_6', 'color_bin_9', 'dominating_texture', 'texture_0', 'texture_1', 'texture_2', 'texture_3', 'texture_7', 'texture_8', 'lengthy', 'roundness', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5'],
# Accuracy: 0.7377049180327869,
# Recall: 0.7655860349127181
#
# Repitition 469
# Feature set: ['colorful', 'black', 'black_thin', 'color_bin_1', 'color_bin_3', 'color_bin_4', 'texture_2', 'texture_5', 'texture_8', 'texture_9', 'rough_entropy', 'lengthy_aspect_ratio', 'in_shape', 'roundness', 'hu_moment_1', 'hu_moment_4', 'hu_moment_6'],
# Accuracy: 0.7364438839848676,
# Recall: 0.7581047381546134
#
# Repitition 470
# Feature set: ['darker', 'gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_8', 'color_entropy', 'texture_0', 'texture_1', 'texture_5', 'texture_7', 'texture_9', 'lengthy', 'number_lengthy_objects', 'rel_length', 'roundness', 'hu_moment_2', 'hu_moment_7'],
# Accuracy: 0.7276166456494325,
# Recall: 0.743142144638404
#
# Repitition 471
# Feature set: ['reddish', 'colorful', 'black_thin', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_entropy', 'rough', 'dominating_texture', 'texture_0', 'texture_1', 'texture_3', 'texture_4', 'texture_6', 'texture_8', 'lengthy_aspect_ratio', 'rel_length', 'in_shape', 'hu_moment_3', 'hu_moment_5'],
# Accuracy: 0.7364438839848676,
# Recall: 0.7630922693266833
#
# Repitition 472
# Feature set: ['gradient', 'reddish', 'metallic', 'colorful', 'black', 'color_bin_1', 'color_bin_3', 'color_bin_4', 'color_bin_7', 'color_entropy', 'rough', 'texture_0', 'texture_2', 'texture_3', 'texture_4', 'texture_5', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'rel_length', 'hu_moment_3', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7503152585119798,
# Recall: 0.7855361596009975
#
# Repitition 473
# Feature set: ['gradient', 'reddish', 'black', 'black_thin', 'color_bin_2', 'color_bin_3', 'color_bin_4', 'color_bin_9', 'rough', 'dominating_texture', 'texture_0', 'texture_1', 'texture_2', 'texture_3', 'texture_4', 'texture_6', 'texture_7', 'rough_entropy', 'number_lengthy_objects', 'rel_length', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7414880201765448,
# Recall: 0.773067331670823
#
# Repitition 474
# Feature set: ['gradient', 'metallic', 'colorful', 'dominating_color', 'color_bin_2', 'color_bin_3', 'color_bin_6', 'texture_3', 'texture_6', 'texture_8', 'texture_9', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'in_shape', 'roundness', 'hu_moment_3', 'hu_moment_6'],
# Accuracy: 0.7301387137452712,
# Recall: 0.7531172069825436
#
# Repitition 475
# Feature set: ['darker', 'gradient', 'metallic', 'black', 'dominating_color', 'color_bin_3', 'color_bin_6', 'color_bin_7', 'dominating_texture', 'texture_3', 'texture_4', 'texture_6', 'texture_7', 'texture_8', 'texture_9', 'rough_entropy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'rel_length', 'roundness', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.7364438839848676,
# Recall: 0.7880299251870324
#
# Repitition 476
# Feature set: ['gradient', 'colorful', 'black', 'color_bin_1', 'color_bin_2', 'color_bin_5', 'texture_0', 'texture_1', 'texture_2', 'texture_3', 'texture_4', 'texture_5', 'texture_6', 'texture_7', 'rough_entropy', 'number_lengthy_objects', 'in_shape', 'hu_moment_1'],
# Accuracy: 0.7276166456494325,
# Recall: 0.7755610972568578
#
# Repitition 477
# Feature set: ['gradient', 'colorful', 'black', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_7', 'color_entropy', 'rough', 'dominating_texture', 'texture_1', 'texture_2', 'texture_3', 'texture_4', 'texture_5', 'texture_7', 'lengthy', 'lengthy_aspect_ratio', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_2', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7377049180327869,
# Recall: 0.7630922693266833
#
# Repitition 478
# Feature set: ['darker', 'gradient', 'metallic', 'colorful', 'black_thin', 'color_bin_3', 'color_bin_5', 'color_bin_8', 'texture_0', 'texture_1', 'texture_2', 'texture_4', 'texture_7', 'texture_8', 'texture_9', 'lengthy', 'lengthy_aspect_ratio', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7364438839848676,
# Recall: 0.7655860349127181
#
# Repitition 479
# Feature set: ['reddish', 'metallic', 'colorful', 'dominating_color', 'color_bin_1', 'color_bin_3', 'color_bin_5', 'color_bin_9', 'color_entropy', 'rough', 'dominating_texture', 'texture_5', 'texture_7', 'texture_9', 'number_lengthy_objects', 'rel_length', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_5', 'hu_moment_7'],
# Accuracy: 0.7137452711223203,
# Recall: 0.7331670822942643
#
# Repitition 480
# Feature set: ['darker', 'reddish', 'metallic', 'dominating_color', 'color_bin_1', 'color_bin_5', 'color_bin_7', 'color_entropy', 'rough', 'dominating_texture', 'texture_0', 'texture_1', 'texture_4', 'texture_9', 'number_lengthy_objects', 'rel_length', 'roundness', 'hu_moment_1', 'hu_moment_2', 'hu_moment_4', 'hu_moment_7'],
# Accuracy: 0.7187894073139974,
# Recall: 0.7605985037406484
#
# Repitition 481
# Feature set: ['darker', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'color_entropy', 'dominating_texture', 'texture_1', 'texture_2', 'texture_3', 'texture_8', 'number_lengthy_objects', 'rel_length', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_7'],
# Accuracy: 0.7326607818411097,
# Recall: 0.770573566084788
#
# Repitition 482
# Feature set: ['gradient', 'black_thin', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'rough', 'texture_0', 'texture_3', 'texture_4', 'texture_9', 'rough_entropy', 'number_lengthy_objects', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_7'],
# Accuracy: 0.725094577553594,
# Recall: 0.7406483790523691
#
# Repitition 483
# Feature set: ['darker', 'reddish', 'colorful', 'black', 'color_bin_1', 'color_bin_3', 'color_bin_5', 'color_bin_9', 'dominating_texture', 'texture_0', 'texture_1', 'texture_2', 'texture_3', 'texture_4', 'texture_7', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'rel_length', 'hu_moment_2', 'hu_moment_7'],
# Accuracy: 0.742749054224464,
# Recall: 0.7830423940149626
#
# Repitition 484
# Feature set: ['gradient', 'metallic', 'colorful', 'color_bin_3', 'dominating_texture', 'texture_0', 'texture_1', 'texture_3', 'texture_5', 'texture_6', 'texture_8', 'rough_entropy', 'lengthy', 'lengthy_aspect_ratio', 'rel_length', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7061790668348046,
# Recall: 0.7306733167082294
#
# Repitition 485
# Feature set: ['darker', 'black', 'dominating_color', 'color_bin_1', 'color_bin_3', 'color_bin_6', 'color_bin_9', 'dominating_texture', 'texture_0', 'texture_3', 'texture_4', 'texture_7', 'texture_8', 'rough_entropy', 'number_lengthy_objects', 'roundness', 'hu_moment_1', 'hu_moment_4', 'hu_moment_5'],
# Accuracy: 0.7326607818411097,
# Recall: 0.7980049875311721
#
# Repitition 486
# Feature set: ['metallic', 'black', 'dominating_color', 'color_bin_8', 'color_bin_9', 'dominating_texture', 'texture_1', 'texture_2', 'texture_8', 'rough_entropy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'rel_length', 'in_shape', 'roundness', 'hu_moment_1', 'hu_moment_4', 'hu_moment_5'],
# Accuracy: 0.7351828499369483,
# Recall: 0.7780548628428927
#
# Repitition 487
# Feature set: ['darker', 'reddish', 'metallic', 'colorful', 'color_bin_1', 'color_bin_3', 'color_bin_5', 'color_bin_7', 'color_entropy', 'dominating_texture', 'texture_0', 'texture_2', 'texture_3', 'texture_5', 'texture_8', 'texture_9', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'rel_length', 'roundness', 'hu_moment_1', 'hu_moment_2', 'hu_moment_7'],
# Accuracy: 0.7351828499369483,
# Recall: 0.770573566084788
#
# Repitition 488
# Feature set: ['darker', 'reddish', 'colorful', 'black', 'dominating_color', 'color_bin_3', 'color_bin_5', 'color_bin_7', 'color_bin_8', 'color_entropy', 'dominating_texture', 'texture_1', 'texture_2', 'texture_4', 'texture_5', 'texture_6', 'texture_8', 'lengthy', 'lengthy_aspect_ratio', 'rel_length', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7313997477931904,
# Recall: 0.773067331670823
#
# Repitition 489
# Feature set: ['darker', 'gradient', 'reddish', 'dominating_color', 'color_bin_2', 'color_bin_3', 'color_bin_4', 'color_bin_5', 'color_bin_8', 'color_entropy', 'texture_0', 'texture_2', 'texture_8', 'rough_entropy', 'lengthy_aspect_ratio', 'rel_length', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.7087011349306431,
# Recall: 0.7356608478802993
#
# Repitition 490
# Feature set: ['colorful', 'black', 'dominating_color', 'color_bin_1', 'color_bin_3', 'color_bin_4', 'color_bin_8', 'rough', 'dominating_texture', 'texture_0', 'texture_1', 'texture_2', 'texture_3', 'texture_6', 'texture_7', 'texture_9', 'lengthy', 'number_lengthy_objects', 'rel_length', 'in_shape', 'roundness', 'hu_moment_2', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7414880201765448,
# Recall: 0.7980049875311721
#
# Repitition 491
# Feature set: ['reddish', 'metallic', 'black', 'color_bin_1', 'color_bin_2', 'color_bin_5', 'color_bin_9', 'texture_0', 'texture_2', 'texture_3', 'texture_5', 'rough_entropy', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_5'],
# Accuracy: 0.742749054224464,
# Recall: 0.7805486284289277
#
# Repitition 492
# Feature set: ['colorful', 'black', 'dominating_color', 'color_bin_5', 'color_bin_6', 'rough', 'texture_1', 'texture_5', 'texture_9', 'rough_entropy', 'lengthy_aspect_ratio', 'rel_length', 'roundness', 'hu_moment_1', 'hu_moment_2', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7301387137452712,
# Recall: 0.7581047381546134
#
# Repitition 493
# Feature set: ['gradient', 'colorful', 'color_bin_1', 'color_bin_4', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_entropy', 'dominating_texture', 'texture_0', 'texture_3', 'texture_5', 'texture_6', 'texture_7', 'texture_9', 'rough_entropy', 'rel_length', 'roundness', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_5', 'hu_moment_7'],
# Accuracy: 0.7036569987389659,
# Recall: 0.7281795511221946
#
# Repitition 494
# Feature set: ['darker', 'colorful', 'black_thin', 'color_bin_1', 'color_bin_2', 'color_bin_4', 'color_bin_5', 'color_bin_6', 'color_bin_8', 'dominating_texture', 'texture_1', 'texture_2', 'texture_4', 'texture_5', 'texture_9', 'lengthy_aspect_ratio', 'rel_length', 'in_shape', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_4', 'hu_moment_7'],
# Accuracy: 0.7414880201765448,
# Recall: 0.7805486284289277
#
# Repitition 495
# Feature set: ['darker', 'reddish', 'black', 'color_bin_4', 'color_bin_6', 'color_bin_8', 'dominating_texture', 'texture_3', 'texture_4', 'texture_5', 'texture_8', 'texture_9', 'rel_length', 'roundness', 'hu_moment_1', 'hu_moment_2', 'hu_moment_5', 'hu_moment_7'],
# Accuracy: 0.7313997477931904,
# Recall: 0.7930174563591023
#
# Repitition 496
# Feature set: ['darker', 'reddish', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_4', 'color_bin_6', 'color_entropy', 'texture_2', 'texture_4', 'texture_6', 'texture_8', 'lengthy', 'number_lengthy_objects', 'rel_length', 'hu_moment_3', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7276166456494325,
# Recall: 0.7755610972568578
#
# Repitition 497
# Feature set: ['metallic', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_8', 'texture_0', 'texture_3', 'texture_4', 'texture_5', 'texture_6', 'texture_7', 'texture_8', 'lengthy', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.712484237074401,
# Recall: 0.7381546134663342
#
# Repitition 498
# Feature set: ['gradient', 'black', 'color_bin_1', 'color_bin_4', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'texture_1', 'texture_4', 'texture_5', 'texture_6', 'texture_9', 'rough_entropy', 'number_lengthy_objects', 'in_shape', 'hu_moment_4', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7301387137452712,
# Recall: 0.7755610972568578
#
# Repitition 499
# Feature set: ['reddish', 'metallic', 'colorful', 'dominating_color', 'color_bin_2', 'color_bin_5', 'color_bin_7', 'color_entropy', 'rough', 'dominating_texture', 'texture_0', 'texture_3', 'texture_7', 'texture_8', 'lengthy_aspect_ratio', 'roundness', 'hu_moment_1', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7313997477931904,
# Recall: 0.7655860349127181
# Best Feature set: ('darker', 'reddish', 'colorful', 'black', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_9', 'texture_0', 'texture_3', 'texture_4', 'texture_7', 'texture_9', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'in_shape', 'hu_moment_2', 'hu_moment_4', 'hu_moment_6', 'hu_moment_7')
# Reward: 0.8204488778054863

# %% [markdown]
# **Analysis Wetspot**

# %%
# Create a classifier for wetspot:

wetspot_classifier = ClassificationModel("Wetspot")

# %%
# Run classification on hypothesized features:

hypothesized_features_wetspot = ["hu_moment_1", "hu_moment_2", "hu_moment_3", "hu_moment_4", "hu_moment_5", "hu_moment_6", "hu_moment_7", 
                                 "darker", "gradient"] ## Insert hypothesized most relevant features here

wetspot_classifier.run(hypothesized_features_wetspot)
# Out:
# Feature set: ['hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7', 'darker', 'gradient'],
# Accuracy: 0.6990740740740741,
# Recall: 0.7242152466367713
# 0.7242152466367713

# %%
# Apply meta-learning and compare with random choices:

train_agent(wetspot_classifier, initial_features=hypothesized_features_wetspot, epochs=500)
random_monkey(wetspot_classifier, repetitions=500)
# Out:
# Epoch 0
# Feature set: ['darker', 'gradient', 'colorful', 'color_bin_7', 'texture_9', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7268518518518519,
# Recall: 0.7376681614349776
#
# Reward: 0.7376681614349776
#
# Epoch 1
# Feature set: ['darker', 'gradient', 'colorful', 'color_bin_7', 'texture_9', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7222222222222222,
# Recall: 0.7556053811659192
#
# Reward: 0.7556053811659192
#
# Epoch 2
# Feature set: ['darker', 'gradient', 'colorful', 'color_bin_7', 'rough', 'texture_8', 'texture_9', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.75,
# Recall: 0.7623318385650224
#
# Reward: 0.7623318385650224
#
# Epoch 3
# Feature set: ['darker', 'gradient', 'metallic', 'colorful', 'color_bin_7', 'rough', 'texture_8', 'texture_9', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7453703703703703,
# Recall: 0.7556053811659192
#
# Reward: 0.7556053811659192
#
# Epoch 4
# Feature set: ['darker', 'gradient', 'metallic', 'colorful', 'color_bin_7', 'rough', 'texture_8', 'in_shape', 'hu_moment_1', 'hu_moment_3', 'hu_moment_4', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7534722222222222,
# Recall: 0.7556053811659192
#
# Reward: 0.7556053811659192
#
# Epoch 5
# Feature set: ['darker', 'gradient', 'metallic', 'colorful', 'dominating_color', 'color_bin_7', 'rough', 'texture_8', 'in_shape', 'hu_moment_1', 'hu_moment_3', 'hu_moment_4', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7650462962962963,
# Recall: 0.7713004484304933
#
# Reward: 0.7713004484304933
#
# Epoch 6
# Feature set: ['darker', 'gradient', 'metallic', 'colorful', 'dominating_color', 'color_bin_7', 'rough', 'texture_8', 'number_lengthy_objects', 'in_shape', 'hu_moment_1', 'hu_moment_3', 'hu_moment_4', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7638888888888888,
# Recall: 0.7869955156950673
#
# Reward: 0.7869955156950673
#
# Epoch 7
# Feature set: ['darker', 'gradient', 'metallic', 'colorful', 'dominating_color', 'color_bin_7', 'rough', 'texture_4', 'texture_8', 'number_lengthy_objects', 'in_shape', 'hu_moment_1', 'hu_moment_3', 'hu_moment_4', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7650462962962963,
# Recall: 0.7713004484304933
#
# Reward: 0.7713004484304933
#
# Epoch 8
# Feature set: ['darker', 'gradient', 'metallic', 'colorful', 'dominating_color', 'color_bin_7', 'color_entropy', 'rough', 'texture_4', 'texture_8', 'number_lengthy_objects', 'in_shape', 'hu_moment_1', 'hu_moment_3', 'hu_moment_4', 'hu_moment_6'],
# Accuracy: 0.7627314814814815,
# Recall: 0.7802690582959642
#
# Reward: 0.7802690582959642
#
# Epoch 9
# Feature set: ['darker', 'gradient', 'metallic', 'colorful', 'dominating_color', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_2', 'texture_4', 'texture_8', 'lengthy', 'number_lengthy_objects', 'in_shape', 'hu_moment_1', 'hu_moment_3', 'hu_moment_4', 'hu_moment_6'],
# Accuracy: 0.7731481481481481,
# Recall: 0.7937219730941704
#
# Reward: 0.7937219730941704
#
# Epoch 10
# Feature set: ['darker', 'gradient', 'metallic', 'colorful', 'dominating_color', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_2', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'in_shape', 'hu_moment_1', 'hu_moment_3', 'hu_moment_4', 'hu_moment_6'],
# Accuracy: 0.7766203703703703,
# Recall: 0.7914798206278026
#
# Reward: 0.7914798206278026
#
# Epoch 11
# Feature set: ['darker', 'gradient', 'metallic', 'dominating_color', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_2', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_3', 'hu_moment_4', 'hu_moment_6'],
# Accuracy: 0.7685185185185185,
# Recall: 0.7892376681614349
#
# Reward: 0.7892376681614349
#
# Epoch 12
# Feature set: ['darker', 'gradient', 'metallic', 'dominating_color', 'color_bin_1', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_2', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_3', 'hu_moment_4', 'hu_moment_6'],
# Accuracy: 0.7789351851851852,
# Recall: 0.8004484304932735
#
# Reward: 0.8004484304932735
#
# Epoch 13
# Feature set: ['darker', 'gradient', 'metallic', 'dominating_color', 'color_bin_1', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_2', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'rel_length', 'in_shape', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_4', 'hu_moment_6'],
# Accuracy: 0.7777777777777778,
# Recall: 0.7982062780269058
#
# Reward: 0.7982062780269058
#
# Epoch 14
# Feature set: ['darker', 'gradient', 'metallic', 'dominating_color', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_2', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'lengthy_aspect_ratio', 'rel_length', 'in_shape', 'roundness', 'hu_moment_1', 'hu_moment_4', 'hu_moment_6'],
# Accuracy: 0.7719907407407407,
# Recall: 0.7869955156950673
#
# Reward: 0.7869955156950673
#
# Epoch 15
# Feature set: ['darker', 'gradient', 'metallic', 'dominating_color', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'rel_length', 'in_shape', 'roundness', 'hu_moment_1', 'hu_moment_4', 'hu_moment_6'],
# Accuracy: 0.7777777777777778,
# Recall: 0.7869955156950673
#
# Reward: 0.7869955156950673
#
# Epoch 16
# Feature set: ['darker', 'gradient', 'metallic', 'dominating_color', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_2', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'rel_length', 'in_shape', 'roundness', 'hu_moment_1', 'hu_moment_4', 'hu_moment_6'],
# Accuracy: 0.7708333333333334,
# Recall: 0.7892376681614349
#
# Reward: 0.7892376681614349
#
# Epoch 17
# Feature set: ['darker', 'gradient', 'metallic', 'dominating_color', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'rel_length', 'in_shape', 'roundness', 'hu_moment_1', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.7777777777777778,
# Recall: 0.7937219730941704
#
# Reward: 0.7937219730941704
#
# Epoch 18
# Feature set: ['darker', 'gradient', 'metallic', 'dominating_color', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_2', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'rel_length', 'in_shape', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.7731481481481481,
# Recall: 0.7847533632286996
#
# Reward: 0.7847533632286996
#
# Epoch 19
# Feature set: ['gradient', 'metallic', 'dominating_color', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_2', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'rel_length', 'in_shape', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7627314814814815,
# Recall: 0.773542600896861
#
# Reward: 0.773542600896861
#
# Epoch 20
# Feature set: ['gradient', 'metallic', 'dominating_color', 'color_bin_2', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_2', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'rel_length', 'in_shape', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7719907407407407,
# Recall: 0.7847533632286996
#
# Reward: 0.7847533632286996
#
# Epoch 21
# Feature set: ['gradient', 'metallic', 'dominating_color', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_2', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'rel_length', 'in_shape', 'roundness', 'hu_moment_1', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7824074074074074,
# Recall: 0.7892376681614349
#
# Reward: 0.7892376681614349
#
# Epoch 22
# Feature set: ['gradient', 'metallic', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_2', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'rel_length', 'in_shape', 'roundness', 'hu_moment_1', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7789351851851852,
# Recall: 0.7959641255605381
#
# Reward: 0.7959641255605381
#
# Epoch 23
# Feature set: ['gradient', 'metallic', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_2', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'in_shape', 'roundness', 'hu_moment_1', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.78125,
# Recall: 0.804932735426009
#
# Reward: 0.804932735426009
#
# Epoch 24
# Feature set: ['gradient', 'metallic', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7743055555555556,
# Recall: 0.7914798206278026
#
# Reward: 0.7914798206278026
#
# Epoch 25
# Feature set: ['darker', 'gradient', 'metallic', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_2', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7824074074074074,
# Recall: 0.7825112107623319
#
# Reward: 0.7825112107623319
#
# Epoch 26
# Feature set: ['gradient', 'metallic', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_2', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_4', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7754629629629629,
# Recall: 0.8071748878923767
#
# Reward: 0.8071748878923767
#
# Epoch 27
# Feature set: ['gradient', 'metallic', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_4', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7766203703703703,
# Recall: 0.8004484304932735
#
# Reward: 0.8004484304932735
#
# Epoch 28
# Feature set: ['gradient', 'metallic', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_4', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7766203703703703,
# Recall: 0.7892376681614349
#
# Reward: 0.7892376681614349
#
# Epoch 29
# Feature set: ['darker', 'gradient', 'metallic', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_3', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_4', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7696759259259259,
# Recall: 0.7780269058295964
#
# Reward: 0.7780269058295964
#
# Epoch 30
# Feature set: ['darker', 'gradient', 'metallic', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_2', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_4', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7824074074074074,
# Recall: 0.7982062780269058
#
# Reward: 0.7982062780269058
#
# Epoch 31
# Feature set: ['darker', 'gradient', 'metallic', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_2', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7731481481481481,
# Recall: 0.7869955156950673
#
# Reward: 0.7869955156950673
#
# Epoch 32
# Feature set: ['gradient', 'metallic', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_2', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'in_shape', 'roundness', 'hu_moment_1', 'hu_moment_4', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7777777777777778,
# Recall: 0.8161434977578476
#
# Reward: 0.8161434977578476
#
# Epoch 33
# Feature set: ['gradient', 'metallic', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7743055555555556,
# Recall: 0.7914798206278026
#
# Reward: 0.7914798206278026
#
# Epoch 34
# Feature set: ['darker', 'gradient', 'metallic', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_2', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7824074074074074,
# Recall: 0.7825112107623319
#
# Reward: 0.7825112107623319
#
# Epoch 35
# Feature set: ['gradient', 'metallic', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_2', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7800925925925926,
# Recall: 0.8026905829596412
#
# Reward: 0.8026905829596412
#
# Epoch 36
# Feature set: ['gradient', 'metallic', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7685185185185185,
# Recall: 0.7937219730941704
#
# Reward: 0.7937219730941704
#
# Epoch 37
# Feature set: ['metallic', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7673611111111112,
# Recall: 0.7757847533632287
#
# Reward: 0.7757847533632287
#
# Epoch 38
# Feature set: ['gradient', 'metallic', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_7', 'color_entropy', 'rough', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7754629629629629,
# Recall: 0.8004484304932735
#
# Reward: 0.8004484304932735
#
# Epoch 39
# Feature set: ['gradient', 'metallic', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_5', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7777777777777778,
# Recall: 0.7869955156950673
#
# Reward: 0.7869955156950673
#
# Epoch 40
# Feature set: ['gradient', 'metallic', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'in_shape', 'roundness', 'hu_moment_1', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7708333333333334,
# Recall: 0.7780269058295964
#
# Reward: 0.7780269058295964
#
# Epoch 41
# Feature set: ['gradient', 'metallic', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7847222222222222,
# Recall: 0.8071748878923767
#
# Reward: 0.8071748878923767
#
# Epoch 42
# Feature set: ['gradient', 'metallic', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7835648148148148,
# Recall: 0.7914798206278026
#
# Reward: 0.7914798206278026
#
# Epoch 43
# Feature set: ['metallic', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7673611111111112,
# Recall: 0.7757847533632287
#
# Reward: 0.7757847533632287
#
# Epoch 44
# Feature set: ['gradient', 'metallic', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_4', 'texture_5', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7719907407407407,
# Recall: 0.804932735426009
#
# Reward: 0.804932735426009
#
# Epoch 45
# Feature set: ['gradient', 'reddish', 'metallic', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_4', 'texture_5', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7847222222222222,
# Recall: 0.7982062780269058
#
# Reward: 0.7982062780269058
#
# Epoch 46
# Feature set: ['gradient', 'reddish', 'metallic', 'colorful', 'black', 'black_thin', 'color_bin_1', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7800925925925926,
# Recall: 0.7892376681614349
#
# Reward: 0.7892376681614349
#
# Epoch 47
# Feature set: ['metallic', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7673611111111112,
# Recall: 0.7757847533632287
#
# Reward: 0.7757847533632287
#
# Epoch 48
# Feature set: ['metallic', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_7', 'color_bin_9', 'color_entropy', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7511574074074074,
# Recall: 0.7937219730941704
#
# Reward: 0.7937219730941704
#
# Epoch 49
# Feature set: ['gradient', 'metallic', 'colorful', 'black', 'dominating_color', 'color_bin_1', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7754629629629629,
# Recall: 0.7892376681614349
#
# Reward: 0.7892376681614349
#
# Epoch 50
# Feature set: ['metallic', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7673611111111112,
# Recall: 0.7757847533632287
#
# Reward: 0.7757847533632287
#
# Epoch 51
# Feature set: ['darker', 'gradient', 'metallic', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7696759259259259,
# Recall: 0.7825112107623319
#
# Reward: 0.7825112107623319
#
# Epoch 52
# Feature set: ['darker', 'gradient', 'metallic', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_4', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7754629629629629,
# Recall: 0.7937219730941704
#
# Reward: 0.7937219730941704
#
# Epoch 53
# Feature set: ['darker', 'gradient', 'metallic', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7731481481481481,
# Recall: 0.7802690582959642
#
# Reward: 0.7802690582959642
#
# Epoch 54
# Feature set: ['darker', 'metallic', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_4', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7673611111111112,
# Recall: 0.7937219730941704
#
# Reward: 0.7937219730941704
#
# Epoch 55
# Feature set: ['darker', 'gradient', 'metallic', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7731481481481481,
# Recall: 0.7802690582959642
#
# Reward: 0.7802690582959642
#
# Epoch 56
# Feature set: ['darker', 'metallic', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7743055555555556,
# Recall: 0.804932735426009
#
# Reward: 0.804932735426009
#
# Epoch 57
# Feature set: ['gradient', 'metallic', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_4', 'texture_8', 'lengthy', 'number_lengthy_objects', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7731481481481481,
# Recall: 0.7825112107623319
#
# Reward: 0.7825112107623319
#
# Epoch 58
# Feature set: ['gradient', 'metallic', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7835648148148148,
# Recall: 0.7914798206278026
#
# Reward: 0.7914798206278026
#
# Epoch 59
# Feature set: ['metallic', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7673611111111112,
# Recall: 0.7757847533632287
#
# Reward: 0.7757847533632287
#
# Epoch 60
# Feature set: ['darker', 'gradient', 'metallic', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7696759259259259,
# Recall: 0.7825112107623319
#
# Reward: 0.7825112107623319
#
# Epoch 61
# Feature set: ['darker', 'gradient', 'metallic', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_7', 'color_bin_9', 'rough', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_4', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.78125,
# Recall: 0.7959641255605381
#
# Reward: 0.7959641255605381
#
# Epoch 62
# Feature set: ['darker', 'gradient', 'metallic', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_4', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7754629629629629,
# Recall: 0.7937219730941704
#
# Reward: 0.7937219730941704
#
# Epoch 63
# Feature set: ['gradient', 'metallic', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7835648148148148,
# Recall: 0.7914798206278026
#
# Reward: 0.7914798206278026
#
# Epoch 64
# Feature set: ['gradient', 'metallic', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_2', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_3', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7881944444444444,
# Recall: 0.8116591928251121
#
# Reward: 0.8116591928251121
#
# Epoch 65
# Feature set: ['gradient', 'metallic', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_2', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7858796296296297,
# Recall: 0.8116591928251121
#
# Reward: 0.8116591928251121
#
# Epoch 66
# Feature set: ['gradient', 'metallic', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_4', 'texture_8', 'texture_9', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7696759259259259,
# Recall: 0.7847533632286996
#
# Reward: 0.7847533632286996
#
# Epoch 67
# Feature set: ['darker', 'gradient', 'metallic', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7731481481481481,
# Recall: 0.7802690582959642
#
# Reward: 0.7802690582959642
#
# Epoch 68
# Feature set: ['metallic', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_4', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7743055555555556,
# Recall: 0.7825112107623319
#
# Reward: 0.7825112107623319
#
# Epoch 69
# Feature set: ['metallic', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7673611111111112,
# Recall: 0.7757847533632287
#
# Reward: 0.7757847533632287
#
# Epoch 70
# Feature set: ['darker', 'gradient', 'metallic', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7696759259259259,
# Recall: 0.7825112107623319
#
# Reward: 0.7825112107623319
#
# Epoch 71
# Feature set: ['darker', 'gradient', 'metallic', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7731481481481481,
# Recall: 0.7802690582959642
#
# Reward: 0.7802690582959642
#
# Epoch 72
# Feature set: ['metallic', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_4', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7743055555555556,
# Recall: 0.7825112107623319
#
# Reward: 0.7825112107623319
#
# Epoch 73
# Feature set: ['darker', 'gradient', 'metallic', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7731481481481481,
# Recall: 0.7802690582959642
#
# Reward: 0.7802690582959642
#
# Epoch 74
# Feature set: ['darker', 'metallic', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7743055555555556,
# Recall: 0.804932735426009
#
# Reward: 0.804932735426009
#
# Epoch 75
# Feature set: ['reddish', 'metallic', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_2', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7708333333333334,
# Recall: 0.7892376681614349
#
# Reward: 0.7892376681614349
#
# Epoch 76
# Feature set: ['metallic', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_2', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7754629629629629,
# Recall: 0.7982062780269058
#
# Reward: 0.7982062780269058
#
# Epoch 77
# Feature set: ['metallic', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'in_shape', 'roundness', 'hu_moment_1', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7766203703703703,
# Recall: 0.8004484304932735
#
# Reward: 0.8004484304932735
#
# Epoch 78
# Feature set: ['metallic', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7754629629629629,
# Recall: 0.7892376681614349
#
# Reward: 0.7892376681614349
#
# Epoch 79
# Feature set: ['darker', 'gradient', 'metallic', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7731481481481481,
# Recall: 0.7802690582959642
#
# Reward: 0.7802690582959642
#
# Epoch 80
# Feature set: ['metallic', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7673611111111112,
# Recall: 0.7757847533632287
#
# Reward: 0.7757847533632287
#
# Epoch 81
# Feature set: ['darker', 'gradient', 'metallic', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7731481481481481,
# Recall: 0.7802690582959642
#
# Reward: 0.7802690582959642
#
# Epoch 82
# Feature set: ['gradient', 'metallic', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7743055555555556,
# Recall: 0.7914798206278026
#
# Reward: 0.7914798206278026
#
# Epoch 83
# Feature set: ['gradient', 'metallic', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_4', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7939814814814815,
# Recall: 0.8228699551569507
#
# Reward: 0.8228699551569507
#
# Epoch 84
# Feature set: ['darker', 'gradient', 'metallic', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7800925925925926,
# Recall: 0.8004484304932735
#
# Reward: 0.8004484304932735
#
# Epoch 85
# Feature set: ['darker', 'metallic', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7719907407407407,
# Recall: 0.7825112107623319
#
# Reward: 0.7825112107623319
#
# Epoch 86
# Feature set: ['darker', 'gradient', 'metallic', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7708333333333334,
# Recall: 0.7892376681614349
#
# Reward: 0.7892376681614349
#
# Epoch 87
# Feature set: ['darker', 'metallic', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7743055555555556,
# Recall: 0.804932735426009
#
# Reward: 0.804932735426009
#
# Epoch 88
# Feature set: ['gradient', 'metallic', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_2', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7858796296296297,
# Recall: 0.8116591928251121
#
# Reward: 0.8116591928251121
#
# Epoch 89
# Feature set: ['gradient', 'metallic', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7835648148148148,
# Recall: 0.7914798206278026
#
# Reward: 0.7914798206278026
#
# Epoch 90
# Feature set: ['darker', 'metallic', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7743055555555556,
# Recall: 0.804932735426009
#
# Reward: 0.804932735426009
#
# Epoch 91
# Feature set: ['gradient', 'metallic', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7835648148148148,
# Recall: 0.7914798206278026
#
# Reward: 0.7914798206278026
#
# Epoch 92
# Feature set: ['gradient', 'metallic', 'black', 'dominating_color', 'color_bin_1', 'color_bin_3', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7766203703703703,
# Recall: 0.7937219730941704
#
# Reward: 0.7937219730941704
#
# Epoch 93
# Feature set: ['gradient', 'metallic', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7824074074074074,
# Recall: 0.7937219730941704
#
# Reward: 0.7937219730941704
#
# Epoch 94
# Feature set: ['darker', 'gradient', 'metallic', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_9', 'color_entropy', 'rough', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7731481481481481,
# Recall: 0.7847533632286996
#
# Reward: 0.7847533632286996
#
# Epoch 95
# Feature set: ['darker', 'metallic', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_9', 'color_entropy', 'rough', 'dominating_texture', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7696759259259259,
# Recall: 0.7825112107623319
#
# Reward: 0.7825112107623319
#
# Epoch 96
# Feature set: ['darker', 'metallic', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_9', 'color_entropy', 'rough', 'texture_3', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'in_shape', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7696759259259259,
# Recall: 0.7982062780269058
#
# Reward: 0.7982062780269058
#
# Epoch 97
# Feature set: ['darker', 'metallic', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_9', 'color_entropy', 'rough', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7696759259259259,
# Recall: 0.7959641255605381
#
# Reward: 0.7959641255605381
#
# Epoch 98
# Feature set: ['darker', 'gradient', 'metallic', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7731481481481481,
# Recall: 0.7802690582959642
#
# Reward: 0.7802690582959642
#
# Epoch 99
# Feature set: ['darker', 'metallic', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7743055555555556,
# Recall: 0.804932735426009
#
# Reward: 0.804932735426009
#
# Epoch 100
# Feature set: ['metallic', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7673611111111112,
# Recall: 0.7757847533632287
#
# Reward: 0.7757847533632287
#
# Epoch 101
# Feature set: ['darker', 'metallic', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_1', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7789351851851852,
# Recall: 0.7982062780269058
#
# Reward: 0.7982062780269058
#
# Epoch 102
# Feature set: ['darker', 'metallic', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'in_shape', 'hu_moment_1', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7696759259259259,
# Recall: 0.7892376681614349
#
# Reward: 0.7892376681614349
#
# Epoch 103
# Feature set: ['darker', 'metallic', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_1', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7685185185185185,
# Recall: 0.7825112107623319
#
# Reward: 0.7825112107623319
#
# Epoch 104
# Feature set: ['darker', 'metallic', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_4', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_1', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7569444444444444,
# Recall: 0.7892376681614349
#
# Reward: 0.7892376681614349
#
# Epoch 105
# Feature set: ['darker', 'metallic', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_4', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7777777777777778,
# Recall: 0.7914798206278026
#
# Reward: 0.7914798206278026
#
# Epoch 106
# Feature set: ['darker', 'metallic', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7743055555555556,
# Recall: 0.804932735426009
#
# Reward: 0.804932735426009
#
# Epoch 107
# Feature set: ['gradient', 'metallic', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7835648148148148,
# Recall: 0.7914798206278026
#
# Reward: 0.7914798206278026
#
# Epoch 108
# Feature set: ['metallic', 'black', 'dominating_color', 'color_bin_1', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7685185185185185,
# Recall: 0.7892376681614349
#
# Reward: 0.7892376681614349
#
# Epoch 109
# Feature set: ['metallic', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7754629629629629,
# Recall: 0.7892376681614349
#
# Reward: 0.7892376681614349
#
# Epoch 110
# Feature set: ['gradient', 'metallic', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7835648148148148,
# Recall: 0.7914798206278026
#
# Reward: 0.7914798206278026
#
# Epoch 111
# Feature set: ['metallic', 'black', 'dominating_color', 'color_bin_1', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7685185185185185,
# Recall: 0.7892376681614349
#
# Reward: 0.7892376681614349
#
# Epoch 112
# Feature set: ['metallic', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_3', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7708333333333334,
# Recall: 0.7825112107623319
#
# Reward: 0.7825112107623319
#
# Epoch 113
# Feature set: ['metallic', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7673611111111112,
# Recall: 0.7757847533632287
#
# Reward: 0.7757847533632287
#
# Epoch 114
# Feature set: ['darker', 'metallic', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'rough', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7800925925925926,
# Recall: 0.8026905829596412
#
# Reward: 0.8026905829596412
#
# Epoch 115
# Feature set: ['darker', 'metallic', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'rough', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'in_shape', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.78125,
# Recall: 0.8026905829596412
#
# Reward: 0.8026905829596412
#
# Epoch 116
# Feature set: ['darker', 'metallic', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'rough', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7719907407407407,
# Recall: 0.7825112107623319
#
# Reward: 0.7825112107623319
#
# Epoch 117
# Feature set: ['darker', 'gradient', 'metallic', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7696759259259259,
# Recall: 0.7825112107623319
#
# Reward: 0.7825112107623319
#
# Epoch 118
# ...
# Accuracy: 0.7731481481481481,
# Recall: 0.8071748878923767
#
# Repitition 463
# Feature set: ['darker', 'gradient', 'reddish', 'black', 'color_bin_4', 'color_bin_6', 'color_bin_9', 'color_entropy', 'rough', 'texture_0', 'texture_3', 'texture_4', 'texture_7', 'lengthy', 'lengthy_aspect_ratio', 'roundness', 'hu_moment_3', 'hu_moment_4', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7731481481481481,
# Recall: 0.7802690582959642
#
# Repitition 464
# Feature set: ['darker', 'metallic', 'black', 'black_thin', 'color_bin_1', 'color_bin_3', 'color_bin_4', 'color_bin_5', 'color_bin_6', 'color_bin_9', 'rough', 'dominating_texture', 'texture_0', 'texture_3', 'texture_4', 'texture_8', 'texture_9', 'rough_entropy', 'lengthy', 'lengthy_aspect_ratio', 'rel_length', 'hu_moment_1', 'hu_moment_3', 'hu_moment_4', 'hu_moment_7'],
# Accuracy: 0.7604166666666666,
# Recall: 0.7757847533632287
#
# Repitition 465
# Feature set: ['gradient', 'metallic', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_5', 'texture_2', 'texture_4', 'texture_8', 'rough_entropy', 'rel_length', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7442129629629629,
# Recall: 0.7892376681614349
#
# Repitition 466
# Feature set: ['darker', 'gradient', 'reddish', 'metallic', 'dominating_color', 'color_bin_2', 'color_bin_3', 'color_bin_4', 'color_bin_5', 'color_bin_8', 'color_bin_9', 'dominating_texture', 'texture_1', 'texture_2', 'texture_5', 'texture_6', 'texture_8', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'rel_length', 'roundness', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5'],
# Accuracy: 0.7638888888888888,
# Recall: 0.7914798206278026
#
# Repitition 467
# Feature set: ['metallic', 'colorful', 'dominating_color', 'color_bin_1', 'color_bin_3', 'color_bin_5', 'color_bin_7', 'color_bin_9', 'color_entropy', 'texture_0', 'texture_1', 'texture_2', 'texture_4', 'texture_5', 'texture_6', 'texture_8', 'lengthy', 'in_shape', 'roundness', 'hu_moment_3', 'hu_moment_7'],
# Accuracy: 0.7488425925925926,
# Recall: 0.7937219730941704
#
# Repitition 468
# Feature set: ['dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_4', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'dominating_texture', 'texture_1', 'texture_2', 'texture_4', 'texture_7', 'texture_9', 'lengthy_aspect_ratio', 'hu_moment_2', 'hu_moment_4'],
# Accuracy: 0.7488425925925926,
# Recall: 0.8183856502242153
#
# Repitition 469
# Feature set: ['darker', 'metallic', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_7', 'color_bin_8', 'dominating_texture', 'texture_0', 'texture_2', 'texture_6', 'texture_7', 'texture_9', 'lengthy', 'in_shape', 'roundness', 'hu_moment_4', 'hu_moment_7'],
# Accuracy: 0.7546296296296297,
# Recall: 0.773542600896861
#
# Repitition 470
# Feature set: ['darker', 'black_thin', 'color_bin_2', 'color_bin_6', 'color_bin_9', 'texture_0', 'texture_1', 'texture_2', 'texture_3', 'texture_5', 'texture_6', 'texture_7', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'hu_moment_4'],
# Accuracy: 0.7835648148148148,
# Recall: 0.8183856502242153
#
# Repitition 471
# Feature set: ['colorful', 'black', 'dominating_color', 'color_bin_2', 'color_bin_4', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'rough', 'dominating_texture', 'texture_1', 'texture_2', 'texture_6', 'texture_8', 'texture_9', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'in_shape', 'hu_moment_4'],
# Accuracy: 0.7719907407407407,
# Recall: 0.7959641255605381
#
# Repitition 472
# Feature set: ['darker', 'gradient', 'metallic', 'black_thin', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_8', 'color_bin_9', 'color_entropy', 'texture_0', 'texture_1', 'texture_5', 'texture_8', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'hu_moment_3', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.7662037037037037,
# Recall: 0.7869955156950673
#
# Repitition 473
# Feature set: ['darker', 'reddish', 'color_bin_2', 'color_bin_4', 'color_bin_5', 'color_bin_9', 'color_entropy', 'rough', 'dominating_texture', 'texture_0', 'texture_3', 'texture_4', 'texture_5', 'texture_6', 'texture_7', 'lengthy_aspect_ratio', 'rel_length', 'in_shape', 'roundness', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_6'],
# Accuracy: 0.7638888888888888,
# Recall: 0.7959641255605381
#
# Repitition 474
# Feature set: ['darker', 'gradient', 'colorful', 'black_thin', 'color_bin_2', 'color_bin_3', 'color_bin_4', 'color_bin_5', 'color_bin_6', 'color_bin_8', 'color_entropy', 'dominating_texture', 'texture_0', 'texture_1', 'texture_2', 'texture_3', 'texture_5', 'texture_6', 'texture_9', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_7'],
# Accuracy: 0.7604166666666666,
# Recall: 0.7914798206278026
#
# Repitition 475
# Feature set: ['gradient', 'metallic', 'black', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_6', 'color_bin_7', 'color_entropy', 'texture_0', 'texture_2', 'texture_3', 'texture_4', 'texture_5', 'texture_6', 'texture_8', 'texture_9', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'rel_length', 'in_shape', 'roundness', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7685185185185185,
# Recall: 0.804932735426009
#
# Repitition 476
# Feature set: ['darker', 'reddish', 'metallic', 'colorful', 'dominating_color', 'color_bin_2', 'color_bin_3', 'color_bin_4', 'color_bin_8', 'color_bin_9', 'color_entropy', 'rough', 'texture_1', 'texture_3', 'texture_6', 'texture_8', 'texture_9', 'rel_length', 'roundness', 'hu_moment_1', 'hu_moment_2', 'hu_moment_4'],
# Accuracy: 0.7627314814814815,
# Recall: 0.7780269058295964
#
# Repitition 477
# Feature set: ['darker', 'gradient', 'metallic', 'dominating_color', 'color_bin_3', 'color_bin_6', 'color_bin_9', 'rough', 'texture_0', 'texture_1', 'texture_6', 'texture_9', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'rel_length', 'roundness', 'hu_moment_3', 'hu_moment_5'],
# Accuracy: 0.7650462962962963,
# Recall: 0.7959641255605381
#
# Repitition 478
# Feature set: ['gradient', 'reddish', 'metallic', 'black', 'black_thin', 'color_bin_1', 'color_bin_3', 'color_bin_4', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'rough', 'dominating_texture', 'texture_3', 'texture_4', 'texture_5', 'rough_entropy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'in_shape', 'roundness', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.7824074074074074,
# Recall: 0.8004484304932735
#
# Repitition 479
# Feature set: ['metallic', 'black', 'color_bin_1', 'color_bin_3', 'color_bin_4', 'color_bin_5', 'color_bin_6', 'color_bin_8', 'color_bin_9', 'texture_0', 'texture_3', 'texture_7', 'texture_8', 'texture_9', 'lengthy', 'number_lengthy_objects', 'hu_moment_2', 'hu_moment_4'],
# Accuracy: 0.7546296296296297,
# Recall: 0.8071748878923767
#
# Repitition 480
# Feature set: ['gradient', 'reddish', 'color_bin_1', 'color_bin_2', 'color_bin_4', 'color_bin_9', 'rough', 'dominating_texture', 'texture_0', 'texture_1', 'texture_2', 'texture_3', 'texture_4', 'texture_5', 'texture_6', 'texture_8', 'rel_length', 'in_shape', 'roundness', 'hu_moment_1', 'hu_moment_4', 'hu_moment_6'],
# Accuracy: 0.7905092592592593,
# Recall: 0.8251121076233184
#
# Repitition 481
# Feature set: ['gradient', 'metallic', 'colorful', 'color_bin_1', 'color_bin_3', 'color_bin_4', 'color_bin_7', 'color_entropy', 'rough', 'texture_0', 'texture_1', 'texture_3', 'texture_4', 'texture_6', 'texture_8', 'rough_entropy', 'number_lengthy_objects', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_2', 'hu_moment_7'],
# Accuracy: 0.7719907407407407,
# Recall: 0.8071748878923767
#
# Repitition 482
# Feature set: ['darker', 'metallic', 'colorful', 'black', 'black_thin', 'color_bin_1', 'color_bin_4', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'color_entropy', 'texture_1', 'texture_3', 'texture_4', 'texture_5', 'texture_7', 'rel_length', 'roundness', 'hu_moment_1', 'hu_moment_5', 'hu_moment_7'],
# Accuracy: 0.7453703703703703,
# Recall: 0.7690582959641256
#
# Repitition 483
# Feature set: ['gradient', 'metallic', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_4', 'color_bin_6', 'color_bin_7', 'rough', 'texture_0', 'texture_4', 'texture_8', 'lengthy', 'lengthy_aspect_ratio', 'in_shape', 'roundness', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_7'],
# Accuracy: 0.78125,
# Recall: 0.8116591928251121
#
# Repitition 484
# Feature set: ['darker', 'gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'dominating_texture', 'texture_0', 'texture_4', 'texture_6', 'texture_7', 'rough_entropy', 'lengthy', 'lengthy_aspect_ratio', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7858796296296297,
# Recall: 0.8004484304932735
#
# Repitition 485
# Feature set: ['gradient', 'reddish', 'colorful', 'black', 'black_thin', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'rough', 'dominating_texture', 'texture_0', 'texture_2', 'texture_3', 'texture_8', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_1', 'hu_moment_2', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7731481481481481,
# Recall: 0.7982062780269058
#
# Repitition 486
# Feature set: ['darker', 'gradient', 'reddish', 'metallic', 'colorful', 'black', 'black_thin', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_9', 'color_entropy', 'rough', 'dominating_texture', 'texture_0', 'texture_1', 'texture_2', 'texture_3', 'texture_7', 'texture_9', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'rel_length', 'in_shape', 'roundness', 'hu_moment_1', 'hu_moment_2', 'hu_moment_4'],
# Accuracy: 0.7905092592592593,
# Recall: 0.804932735426009
#
# Repitition 487
# Feature set: ['darker', 'gradient', 'black', 'dominating_color', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'rough', 'dominating_texture', 'texture_0', 'texture_2', 'texture_3', 'texture_6', 'texture_7', 'texture_8', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_1', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.7766203703703703,
# Recall: 0.7937219730941704
#
# Repitition 488
# Feature set: ['metallic', 'black', 'black_thin', 'color_bin_2', 'color_bin_9', 'rough', 'texture_3', 'texture_4', 'texture_5', 'texture_8', 'texture_9', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'rel_length', 'roundness', 'hu_moment_1', 'hu_moment_2', 'hu_moment_5', 'hu_moment_7'],
# Accuracy: 0.7708333333333334,
# Recall: 0.7914798206278026
#
# Repitition 489
# Feature set: ['gradient', 'metallic', 'black', 'black_thin', 'color_bin_1', 'color_bin_3', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'texture_0', 'texture_1', 'texture_7', 'texture_9', 'rough_entropy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'rel_length', 'in_shape', 'hu_moment_5'],
# Accuracy: 0.7696759259259259,
# Recall: 0.7892376681614349
#
# Repitition 490
# Feature set: ['reddish', 'metallic', 'colorful', 'black', 'black_thin', 'color_bin_2', 'color_bin_3', 'color_bin_6', 'color_bin_7', 'color_entropy', 'rough', 'texture_2', 'texture_3', 'texture_4', 'texture_7', 'texture_9', 'rough_entropy', 'number_lengthy_objects', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7685185185185185,
# Recall: 0.7982062780269058
#
# Repitition 491
# Feature set: ['darker', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'texture_0', 'texture_4', 'texture_7', 'rough_entropy', 'rel_length', 'roundness', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_7'],
# Accuracy: 0.7534722222222222,
# Recall: 0.7757847533632287
#
# Repitition 492
# Feature set: ['reddish', 'metallic', 'black', 'black_thin', 'dominating_color', 'color_bin_3', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'rough', 'texture_3', 'texture_5', 'texture_9', 'rough_entropy', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_5', 'hu_moment_7'],
# Accuracy: 0.7604166666666666,
# Recall: 0.7690582959641256
#
# Repitition 493
# Feature set: ['darker', 'reddish', 'metallic', 'black_thin', 'color_bin_7', 'dominating_texture', 'texture_2', 'texture_4', 'texture_6', 'texture_7', 'rough_entropy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'rel_length', 'in_shape', 'hu_moment_3', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.7592592592592593,
# Recall: 0.7959641255605381
#
# Repitition 494
# Feature set: ['gradient', 'reddish', 'metallic', 'colorful', 'black', 'black_thin', 'color_bin_2', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_0', 'texture_1', 'texture_2', 'texture_3', 'texture_6', 'texture_9', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'roundness', 'hu_moment_2', 'hu_moment_4', 'hu_moment_7'],
# Accuracy: 0.7893518518518519,
# Recall: 0.8183856502242153
#
# Repitition 495
# Feature set: ['darker', 'reddish', 'metallic', 'colorful', 'black', 'black_thin', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_9', 'dominating_texture', 'texture_0', 'texture_2', 'texture_4', 'texture_7', 'texture_8', 'texture_9', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'rel_length', 'in_shape', 'roundness', 'hu_moment_2', 'hu_moment_6'],
# Accuracy: 0.7754629629629629,
# Recall: 0.7825112107623319
#
# Repitition 496
# Feature set: ['darker', 'gradient', 'reddish', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_2', 'color_bin_4', 'color_bin_5', 'color_bin_9', 'rough', 'dominating_texture', 'texture_0', 'texture_3', 'texture_6', 'texture_8', 'lengthy', 'lengthy_aspect_ratio', 'in_shape', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_5', 'hu_moment_7'],
# Accuracy: 0.7708333333333334,
# Recall: 0.7713004484304933
#
# Repitition 497
# Feature set: ['gradient', 'colorful', 'black', 'color_bin_1', 'color_bin_2', 'color_bin_4', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'texture_0', 'texture_3', 'texture_4', 'texture_7', 'texture_8', 'texture_9', 'rough_entropy', 'number_lengthy_objects', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7569444444444444,
# Recall: 0.7959641255605381
#
# Repitition 498
# Feature set: ['reddish', 'metallic', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_3', 'color_bin_6', 'color_bin_9', 'color_entropy', 'rough', 'dominating_texture', 'texture_2', 'texture_3', 'texture_5', 'texture_6', 'texture_8', 'texture_9', 'lengthy_aspect_ratio', 'roundness', 'hu_moment_2', 'hu_moment_3', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.7789351851851852,
# Recall: 0.8094170403587444
#
# Repitition 499
# Feature set: ['darker', 'metallic', 'colorful', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_5', 'color_bin_7', 'color_bin_9', 'rough', 'texture_2', 'texture_3', 'texture_4', 'texture_6', 'texture_7', 'rough_entropy', 'number_lengthy_objects', 'rel_length', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_7'],
# Accuracy: 0.7743055555555556,
# Recall: 0.7802690582959642
# Best Feature set: ('gradient', 'reddish', 'metallic', 'black_thin', 'dominating_color', 'color_bin_3', 'color_bin_4', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'dominating_texture', 'texture_1', 'texture_2', 'texture_3', 'texture_6', 'texture_7', 'texture_8', 'texture_9', 'number_lengthy_objects', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_3', 'hu_moment_6')
# Reward: 0.8340807174887892

# %%
wetspot_classifier.run(['darker', 'gradient', 'metallic', 'colorful', 'black_thin', 'color_bin_1', 'color_bin_2', 'color_bin_4', 'color_bin_6', 
                        'color_bin_7', 'color_bin_8', 'texture_0', 'texture_1', 'texture_3', 'texture_4', 'texture_5', 'texture_7', 'texture_8', 
                        'texture_9', 'rough_entropy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'rel_length', 'hu_moment_1', 'hu_moment_2', 
                        'hu_moment_4', 'hu_moment_6', 'hu_moment_7'])
# Out:
# Feature set: ['darker', 'gradient', 'metallic', 'colorful', 'black_thin', 'color_bin_1', 'color_bin_2', 'color_bin_4', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'texture_0', 'texture_1', 'texture_3', 'texture_4', 'texture_5', 'texture_7', 'texture_8', 'texture_9', 'rough_entropy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'rel_length', 'hu_moment_1', 'hu_moment_2', 'hu_moment_4', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7557870370370371,
# Recall: 0.8139013452914798
# 0.8139013452914798
