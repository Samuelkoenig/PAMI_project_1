# %% [markdown]
# # Meta-learning classification features: Model

# %% [markdown]
# **Imports**

# %%
# imports

import numpy as np
import pandas as pd
import torch
import torch.nn as nn

import random
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, recall_score, f1_score

# %% [markdown]
# **Classification model**

# %%
class ClassificationModel():

    def __init__(self, target_label):

        self.all_features = ["darker", "gradient", "reddish", "metallic", "colorful", "black", "black_thin", "dominating_color", "color_bin_1", 
                             "color_bin_2", "color_bin_3", "color_bin_4", "color_bin_5", "color_bin_6", "color_bin_7", "color_bin_8", "color_bin_9", 
                             "color_entropy", "rough", "dominating_texture", "texture_0", "texture_1", "texture_2", "texture_3", "texture_4", 
                             "texture_5", "texture_6", "texture_7", "texture_8", "texture_9", "rough_entropy", "lengthy", "number_lengthy_objects", 
                             "lengthy_aspect_ratio", "rel_length", "in_shape", "roundness", "hu_moment_1", "hu_moment_2", "hu_moment_3", 
                             "hu_moment_4", "hu_moment_5", "hu_moment_6", "hu_moment_7"]

        self.target_label = target_label
        self.dataset = self.load_dataset()
        self.x_train, self.x_test, self.y_train, self.y_test = self.create_train_test_data()
        self.measures = {}

    def load_dataset(self):

        dataset = pd.read_csv("samples_0_6935_all_defects.csv", sep = ",")
        dataset.drop(columns = ["Unnamed: 0", "image_number", "defect_number"], inplace = True)
        dataset.dropna(inplace = True)

        return dataset
    
    def create_train_test_data(self):

        # Create rust labels:
        target_class_df = self.dataset.copy()
        target_class_df["target_label"] = target_class_df["label"].apply(lambda x: 1 if x == self.target_label else 0)

        # Apply train test split:
        target_class_df = target_class_df.sort_values(by = "target_label", ascending = False)
        number_of_defects = target_class_df["target_label"].sum()
        target_class_df_1 = target_class_df.iloc[:number_of_defects, :]
        negative_samples = random.sample(range(number_of_defects, len(target_class_df)), number_of_defects)
        target_class_df_0 = target_class_df.iloc[negative_samples, :]
        df = pd.concat([target_class_df_1, target_class_df_0], ignore_index=True)
        x = df.loc[:, self.all_features]
        y = df.loc[:, "target_label"]
        x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

        return x_train, x_test, y_train, y_test

    def select_features(self, features):

        x_train = self.x_train.loc[:, features]
        x_test = self.x_test.loc[:, features]

        return x_train, x_test
    
    def evaluate(self, y_pred):

        accuracy = accuracy_score(self.y_test, y_pred)
        recall = recall_score(self.y_test, y_pred, average=None)[1]
        f1 = f1_score(self.y_test, y_pred, average=None)[1]

        return accuracy, recall, f1
    
    def run(self, features, number_of_forests=1):

        # Check whether feature combination already exists in measures dictionary:
        feature_combination = ", ".join(sorted(features))
        if feature_combination in self.measures:
            accuracy, recall, f1 = self.measures[feature_combination]
        else:

            # Generate train dataset with selected features: 
            x_train, x_test = self.select_features(features)

            # Perform the random forest classifier: 
            for i in range(number_of_forests):
                clf = RandomForestClassifier(n_estimators=50, criterion= "entropy", random_state=i, max_depth=10)
                clf.fit(x_train, self.y_train)
                y_pred = clf.predict(x_test)
                if i == 0:
                    y_pred_final = y_pred
                else:
                    y_pred_final = np.array([1 if y_pred[i] == 1 or y_pred_final[i] == 1 else 0 for i in range(len(y_pred))])

            # Evaluate and store results:
            accuracy, recall, f1 = self.evaluate(y_pred_final)
            current_feature_importances = clf.feature_importances_
            self.measures[feature_combination] = (accuracy, recall, f1)

        print(f"Feature set: {features}, \nAccuracy: {accuracy}, \nRecall: {recall},\nF1: {f1}\n")
        return f1

# %% [markdown]
# **Environment**

# %%
class State():

    def __init__(self, state, action=None):

        if not action == None:
            state = self.bitflip(state, action)

        self.binary = state.float()

    def bitflip(self, state, action):

        adjusted_state = state.binary.clone()

        for index in action:
            if state.binary[index] == 0:
                adjusted_state[index] = 1
            else:
                adjusted_state[index] = 0

        return adjusted_state


class Dacl10kEnvironment():

    def __init__(self, classifier, initial_state=None):

        self.all_features = ["darker", "gradient", "reddish", "metallic", "colorful", "black", "black_thin", "dominating_color", "color_bin_1", 
                             "color_bin_2", "color_bin_3", "color_bin_4", "color_bin_5", "color_bin_6", "color_bin_7", "color_bin_8", "color_bin_9", 
                             "color_entropy", "rough", "dominating_texture", "texture_0", "texture_1", "texture_2", "texture_3", "texture_4", 
                             "texture_5", "texture_6", "texture_7", "texture_8", "texture_9", "rough_entropy", "lengthy", "number_lengthy_objects", 
                             "lengthy_aspect_ratio", "rel_length", "in_shape", "roundness", "hu_moment_1", "hu_moment_2", "hu_moment_3", 
                             "hu_moment_4", "hu_moment_5", "hu_moment_6", "hu_moment_7"]
        
        self.classifier = classifier
        self.features_dict = {i: feature for i, feature in enumerate(self.all_features)}
        self.statesize = len(self.all_features)

        self.initial_state = State(torch.FloatTensor([i % 2 for i in range(len(self.all_features))])) if initial_state == None else initial_state
        self.state = self.initial_state

        self.table = {}

    def step(self, action):

        next_state = State(self.state, action)
        self.state = next_state

        features_indices = [i for i, value in enumerate(self.state.binary.numpy()) if value == 1]
        features = [self.features_dict[i] for i in features_indices]
        reward = self.classifier.run(features)
        self.table[tuple([self.features_dict[i] for i, binary in enumerate(tuple(self.state.binary.detach().numpy())) if binary == 1])] = reward

        return next_state, reward

# %% [markdown]
# **Reinforcement Agent**

# %%
class FeedforwardNet(nn.Module):

    def __init__(self, env, device, hidden_size):

        super(FeedforwardNet, self).__init__()
        
        self.device = device
        self.statesize = env.statesize
        self.hidden_size = hidden_size
        
        self.hidden_layer = nn.Linear(self.statesize, self.hidden_size).to(self.device)
        self.output_layer = nn.Linear(self.hidden_size, self.statesize).to(self.device)
        self.sigmoid = nn.Sigmoid().to(self.device)

    def forward(self, input):

        x = self.hidden_layer(input)
        x = torch.relu(x)
        x = self.output_layer(x)
        x = self.sigmoid(x)

        return x


class ReinforcementAgent():

    def __init__(self, env):

        self.device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
        self.net = FeedforwardNet(env, self.device, 50)

        self.optimizer = torch.optim.Adam(self.net.parameters(),lr=0.01)

        self.exploration_chance = 0.05
        self.statesize = env.statesize

    def step(self, state):

        probabilities = self.net.forward(state.binary)
        #print(probabilities)
        probability_differences = torch.abs(state.binary - probabilities)
        _, action = torch.topk(probability_differences, random.randint(5, 15))
        action = action.tolist()

        """
        # Exploration adjustments:
        for i, _ in enumerate(action):
            if random.random() < self.exploration_chance:
                action[i] = random.randint(0, self.statesize - 1)
        """

        # Exploration adjustements:
        for i in range(self.statesize):
            if random.random() < self.exploration_chance and i not in action:
                action.append(i)

        # If no feature remaining in action, include highest likelihood features
        if torch.sum(State(state, action).binary).item() < 1:
            action = None

        return action

    def update(self, reward):

        reward = torch.tensor(reward, dtype=torch.float32, requires_grad=True)
        #loss = -torch.log(reward)
        loss = torch.sqrt(1 - reward)
        #print(f"Loss: {loss}")

        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

# %% [markdown]
# **Train the reinforcement agent**

# %%
def plot_rewards(rewards):

    x = list(range(len(rewards)))

    moving_average_rewards = []
    window_size = 50
    for i in range(len(rewards)):
        start_index = max(0, i - window_size + 1)
        window = rewards[start_index:i + 1]
        moving_average_rewards.append(sum(window) / len(window))

    plt.figure(figsize=(10, 5))
    plt.plot(x, rewards, marker="o", linestyle="-", color="b")
    plt.plot(x, moving_average_rewards, linestyle="-", color="r")

    plt.title("Rewards")
    plt.xlabel("Epoch")
    plt.ylabel("Reward")
    plt.grid(True)

    plt.show()

def train_agent(classifier, initial_features=None, epochs=500):

    # Initialize variables:
    env = Dacl10kEnvironment(classifier)
    agent = ReinforcementAgent(env)

    state = env.initial_state
    rewards = []

    # Prepare initial state:
    if not initial_features == None:
        initial_state = State(torch.FloatTensor([feature in initial_features for feature in env.all_features]))
        env = Dacl10kEnvironment(classifier, initial_state=initial_state)

    # Run epochs:
    for i in range(epochs): 

        print(f"Epoch {i}")
        
        action = agent.step(state)
        #print(action)
        next_state, reward = env.step(action)
        agent.update(reward)
        state = next_state

        print(f"Reward: {reward}\n")
        rewards.append(reward)

    # Evaluate results:
    plot_rewards(rewards)
    best_feature_set = max(env.table, key=lambda k: env.table[k])
    print(f"Best Feature set: {best_feature_set}\nReward: {env.table[best_feature_set]}\n")

def random_monkey(classifier, repetitions=500):

    # Initialize variables:
    env = Dacl10kEnvironment(classifier)
    rewards = []

    # Run repetitions:
    for i in range(repetitions):

        print(f"Repitition {i}")
        
        random_binary = random.choices([0, 1], k=44)
        features_indices = [i for i, value in enumerate(random_binary) if value == 1]
        features = [env.features_dict[i] for i in features_indices]
        reward = classifier.run(features)
        rewards.append(reward)
        env.table[tuple([env.features_dict[i] for i, binary in enumerate(random_binary) if binary == 1])] = reward
    
    # Evaluate results:
    plot_rewards(rewards)
    best_feature_set = max(env.table, key=lambda k: env.table[k])
    print(f"Best Feature set: {best_feature_set}\nReward: {env.table[best_feature_set]}\n")

# %% [markdown]
# # Meta-learning classification features: Analysis

# %% [markdown]
# **Analysis Drainage**

# %%
# Create a classifier for drainage:

wetspot_classifier = ClassificationModel("Wetspot")

# %%
# Run classification on hypothesized features:

hypothesized_features_wetspot = ["darker", "black", "color_bin_1", "color_bin_2", "color_bin_3", "color_bin_4", "color_bin_5", "color_bin_6", 
                                  "color_bin_7", "color_bin_8", "color_bin_9", "color_entropy", "rough", "texture_0", "texture_1", "texture_2", 
                                  "texture_3", "texture_4", "texture_5", "texture_6", "texture_7", "texture_8", "texture_9", "rough_entropy",
                                  "lengthy", "number_lengthy_objects", "lengthy_aspect_ratio", "rel_length", "hu_moment_1", "hu_moment_2",
                                  "hu_moment_3", "hu_moment_4", "hu_moment_5", "hu_moment_6", "hu_moment_7"] ## Insert hypothesized most relevant features here

wetspot_classifier.run(hypothesized_features_wetspot)
# Out:
# Feature set: ['darker', 'black', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_4', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'rough', 'texture_0', 'texture_1', 'texture_2', 'texture_3', 'texture_4', 'texture_5', 'texture_6', 'texture_7', 'texture_8', 'texture_9', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'rel_length', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7407407407407407,
# Recall: 0.7847533632286996,
# F1: 0.7575757575757576
# 0.7575757575757576

# %%
# Apply meta-learning and compare with random choices:

train_agent(drainage_classifier, initial_features=hypothesized_features_drainage, epochs=250)
# Out:
# Epoch 0
# Feature set: ['darker', 'gradient', 'metallic', 'black', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_0', 'texture_1', 'texture_2', 'texture_3', 'texture_4', 'texture_5', 'texture_6', 'texture_7', 'texture_9', 'rough_entropy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'rel_length', 'hu_moment_1', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.7477931904161412,
# Recall: 0.7755610972568578,
# F1: 0.7566909975669099
#
# Reward: 0.7566909975669099
#
# Epoch 1
# Feature set: ['gradient', 'reddish', 'metallic', 'dominating_color', 'color_bin_1', 'color_bin_6', 'color_bin_7', 'color_entropy', 'dominating_texture', 'texture_0', 'texture_1', 'texture_3', 'texture_5', 'texture_6', 'texture_7', 'rough_entropy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.7175283732660782,
# Recall: 0.7331670822942643,
# F1: 0.7241379310344828
#
# Reward: 0.7241379310344828
#
# Epoch 2
# Feature set: ['reddish', 'color_bin_1', 'color_bin_2', 'color_bin_5', 'color_bin_6', 'color_entropy', 'dominating_texture', 'texture_1', 'texture_3', 'texture_5', 'texture_7', 'rough_entropy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.7074401008827238,
# Recall: 0.713216957605985,
# F1: 0.7114427860696517
#
# Reward: 0.7114427860696517
#
# Epoch 3
# Feature set: ['reddish', 'metallic', 'dominating_color', 'color_bin_5', 'dominating_texture', 'texture_0', 'texture_1', 'texture_7', 'texture_9', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_1', 'hu_moment_2', 'hu_moment_4'],
# Accuracy: 0.6923076923076923,
# Recall: 0.7107231920199502,
# F1: 0.7002457002457002
#
# Reward: 0.7002457002457002
#
# Epoch 4
# Feature set: ['reddish', 'metallic', 'dominating_color', 'color_bin_3', 'color_bin_6', 'color_bin_8', 'color_entropy', 'texture_1', 'texture_2', 'texture_3', 'texture_7', 'lengthy_aspect_ratio', 'hu_moment_2', 'hu_moment_3', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.7175283732660782,
# Recall: 0.7082294264339152,
# F1: 0.7171717171717171
#
# Reward: 0.7171717171717171
#
# Epoch 5
# Feature set: ['reddish', 'metallic', 'color_bin_5', 'color_bin_8', 'texture_1', 'texture_7', 'rough_entropy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_3', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.7238335435056746,
# Recall: 0.7281795511221946,
# F1: 0.7272727272727273
#
# Reward: 0.7272727272727273
#
# Epoch 6
# Feature set: ['metallic', 'dominating_color', 'color_bin_5', 'color_bin_8', 'color_bin_9', 'color_entropy', 'rough', 'texture_0', 'texture_1', 'texture_3', 'texture_7', 'texture_9', 'rough_entropy', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.7137452711223203,
# Recall: 0.7356608478802993,
# F1: 0.7221542227662179
#
# Reward: 0.7221542227662179
#
# Epoch 7
# Feature set: ['metallic', 'dominating_color', 'color_bin_5', 'color_bin_6', 'color_bin_9', 'color_entropy', 'dominating_texture', 'texture_1', 'texture_2', 'texture_3', 'texture_7', 'texture_9', 'rough_entropy', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.7377049180327869,
# Recall: 0.7581047381546134,
# F1: 0.7450980392156863
#
# Reward: 0.7450980392156863
#
# Epoch 8
# Feature set: ['reddish', 'dominating_color', 'color_bin_3', 'color_bin_6', 'color_bin_8', 'color_entropy', 'dominating_texture', 'texture_1', 'texture_5', 'texture_6', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5'],
# Accuracy: 0.6960907944514502,
# Recall: 0.7206982543640897,
# F1: 0.7057387057387058
#
# Reward: 0.7057387057387058
#
# Epoch 9
# Feature set: ['reddish', 'colorful', 'dominating_color', 'color_bin_5', 'color_bin_6', 'color_bin_8', 'color_bin_9', 'texture_1', 'texture_3', 'texture_9', 'lengthy_aspect_ratio', 'rel_length', 'in_shape', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5'],
# Accuracy: 0.7087011349306431,
# Recall: 0.7231920199501247,
# F1: 0.7151664611590629
#
# Reward: 0.7151664611590629
#
# Epoch 10
# Feature set: ['reddish', 'metallic', 'dominating_color', 'color_bin_3', 'color_bin_6', 'color_bin_8', 'color_entropy', 'texture_3', 'texture_7', 'texture_8', 'texture_9', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_1', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.7162673392181589,
# Recall: 0.7306733167082294,
# F1: 0.7225647348951911
#
# Reward: 0.7225647348951911
#
# Epoch 11
# Feature set: ['reddish', 'metallic', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_5', 'color_bin_6', 'color_bin_8', 'color_bin_9', 'dominating_texture', 'texture_1', 'texture_3', 'texture_7', 'texture_9', 'lengthy_aspect_ratio', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5'],
# Accuracy: 0.7364438839848676,
# Recall: 0.7630922693266833,
# F1: 0.7454323995127893
#
# Reward: 0.7454323995127893
#
# Epoch 12
# Feature set: ['reddish', 'metallic', 'black', 'dominating_color', 'color_bin_1', 'color_bin_5', 'color_bin_6', 'color_entropy', 'texture_3', 'texture_4', 'texture_8', 'texture_9', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_1', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5'],
# Accuracy: 0.7452711223203027,
# Recall: 0.7680798004987531,
# F1: 0.7530562347188264
#
# Reward: 0.7530562347188264
#
# Epoch 13
# Feature set: ['reddish', 'metallic', 'colorful', 'black', 'dominating_color', 'color_bin_1', 'color_bin_5', 'color_bin_6', 'color_entropy', 'dominating_texture', 'texture_0', 'texture_3', 'texture_9', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_1', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5'],
# Accuracy: 0.742749054224464,
# Recall: 0.7805486284289277,
# F1: 0.7542168674698795
#
# Reward: 0.7542168674698795
#
# Epoch 14
# Feature set: ['reddish', 'metallic', 'colorful', 'black', 'dominating_color', 'color_bin_1', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_8', 'color_bin_9', 'color_entropy', 'rough', 'dominating_texture', 'texture_1', 'texture_7', 'texture_8', 'texture_9', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.7389659520807061,
# Recall: 0.7655860349127181,
# F1: 0.7478684531059683
#
# Reward: 0.7478684531059683
#
# Epoch 15
# Feature set: ['metallic', 'colorful', 'dominating_color', 'color_bin_1', 'color_bin_5', 'color_bin_6', 'color_bin_9', 'dominating_texture', 'texture_1', 'texture_2', 'texture_3', 'texture_7', 'texture_9', 'lengthy_aspect_ratio', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.7288776796973518,
# Recall: 0.7630922693266833,
# F1: 0.7400241837968561
#
# Reward: 0.7400241837968561
#
# Epoch 16
# Feature set: ['reddish', 'metallic', 'dominating_color', 'color_bin_1', 'color_bin_6', 'color_bin_7', 'color_entropy', 'dominating_texture', 'texture_1', 'texture_3', 'texture_5', 'texture_6', 'texture_7', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.7175283732660782,
# Recall: 0.7331670822942643,
# F1: 0.7241379310344828
#
# Reward: 0.7241379310344828
#
# Epoch 17
# Feature set: ['reddish', 'metallic', 'dominating_color', 'color_bin_1', 'color_bin_5', 'color_bin_6', 'color_bin_9', 'color_entropy', 'texture_1', 'texture_3', 'texture_7', 'texture_9', 'rough_entropy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.7175283732660782,
# Recall: 0.7481296758104738,
# F1: 0.7281553398058253
#
# Reward: 0.7281553398058253
#
# Epoch 18
# Feature set: ['reddish', 'metallic', 'colorful', 'dominating_color', 'color_bin_1', 'color_bin_3', 'color_bin_4', 'color_bin_6', 'color_bin_8', 'dominating_texture', 'texture_0', 'texture_1', 'texture_2', 'texture_7', 'in_shape', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5'],
# Accuracy: 0.7301387137452712,
# Recall: 0.7506234413965087,
# F1: 0.7377450980392157
#
# Reward: 0.7377450980392157
#
# Epoch 19
# Feature set: ['darker', 'reddish', 'metallic', 'colorful', 'dominating_color', 'color_bin_1', 'color_bin_3', 'color_bin_4', 'color_bin_5', 'color_bin_8', 'texture_1', 'texture_3', 'texture_7', 'texture_8', 'in_shape', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5'],
# Accuracy: 0.7162673392181589,
# Recall: 0.7581047381546134,
# F1: 0.7298919567827131
#
# Reward: 0.7298919567827131
#
# Epoch 20
# Feature set: ['reddish', 'metallic', 'colorful', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_5', 'color_bin_8', 'color_bin_9', 'color_entropy', 'dominating_texture', 'texture_1', 'texture_3', 'texture_7', 'texture_9', 'lengthy', 'lengthy_aspect_ratio', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.7276166456494325,
# Recall: 0.7556109725685786,
# F1: 0.7372262773722628
#
# Reward: 0.7372262773722628
#
# Epoch 21
# Feature set: ['reddish', 'metallic', 'black_thin', 'dominating_color', 'color_bin_6', 'color_bin_8', 'color_entropy', 'dominating_texture', 'texture_1', 'texture_2', 'texture_3', 'texture_7', 'texture_9', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_1', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.733921815889029,
# Recall: 0.7406483790523691,
# F1: 0.737888198757764
#
# Reward: 0.737888198757764
#
# Epoch 22
# Feature set: ['reddish', 'metallic', 'dominating_color', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_8', 'color_entropy', 'dominating_texture', 'texture_1', 'texture_3', 'texture_4', 'texture_8', 'texture_9', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_1', 'hu_moment_2', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.7351828499369483,
# Recall: 0.7655860349127181,
# F1: 0.7451456310679612
#
# Reward: 0.7451456310679612
#
# Epoch 23
# Feature set: ['reddish', 'metallic', 'colorful', 'dominating_color', 'color_bin_6', 'color_bin_8', 'color_bin_9', 'texture_7', 'texture_9', 'lengthy_aspect_ratio', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.7049180327868853,
# Recall: 0.7306733167082294,
# F1: 0.7146341463414634
#
# Reward: 0.7146341463414634
#
# Epoch 24
# Feature set: ['darker', 'gradient', 'reddish', 'metallic', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_3', 'color_bin_6', 'color_entropy', 'dominating_texture', 'texture_1', 'texture_3', 'texture_6', 'texture_7', 'rough_entropy', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5'],
# Accuracy: 0.7654476670870114,
# Recall: 0.7780548628428927,
# F1: 0.7703703703703704
#
# Reward: 0.7703703703703704
#
# Epoch 25
# Feature set: ['reddish', 'metallic', 'colorful', 'dominating_color', 'color_bin_1', 'color_bin_5', 'color_bin_6', 'color_entropy', 'dominating_texture', 'texture_1', 'texture_3', 'texture_7', 'texture_9', 'rough_entropy', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5'],
# Accuracy: 0.7263556116015133,
# Recall: 0.7605985037406484,
# F1: 0.7376058041112454
#
# Reward: 0.7376058041112454
#
# Epoch 26
# Feature set: ['reddish', 'metallic', 'colorful', 'black_thin', 'dominating_color', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_8', 'color_entropy', 'rough', 'texture_0', 'texture_3', 'texture_8', 'texture_9', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_1', 'hu_moment_2', 'hu_moment_4'],
# Accuracy: 0.7326607818411097,
# Recall: 0.7630922693266833,
# F1: 0.7427184466019418
#
# Reward: 0.7427184466019418
#
# Epoch 27
# Feature set: ['reddish', 'metallic', 'colorful', 'black', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_5', 'color_bin_6', 'color_bin_8', 'color_bin_9', 'dominating_texture', 'texture_1', 'texture_3', 'texture_7', 'texture_9', 'lengthy_aspect_ratio', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_2', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.733921815889029,
# Recall: 0.7630922693266833,
# F1: 0.7436208991494532
#
# Reward: 0.7436208991494532
#
# Epoch 28
# Feature set: ['reddish', 'metallic', 'colorful', 'dominating_color', 'color_bin_1', 'color_entropy', 'rough', 'texture_1', 'texture_3', 'texture_8', 'lengthy_aspect_ratio', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.7326607818411097,
# Recall: 0.7406483790523691,
# F1: 0.7369727047146402
#
# Reward: 0.7369727047146402
#
# Epoch 29
# Feature set: ['reddish', 'metallic', 'colorful', 'dominating_color', 'color_bin_1', 'color_bin_5', 'color_bin_6', 'color_bin_9', 'color_entropy', 'texture_1', 'texture_2', 'texture_3', 'texture_6', 'lengthy_aspect_ratio', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.7187894073139974,
# Recall: 0.7356608478802993,
# F1: 0.7257072570725708
#
# Reward: 0.7257072570725708
#
# Epoch 30
# Feature set: ['reddish', 'metallic', 'dominating_color', 'color_bin_3', 'color_bin_4', 'color_bin_6', 'color_entropy', 'dominating_texture', 'texture_1', 'texture_3', 'texture_5', 'texture_7', 'texture_9', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5'],
# Accuracy: 0.712484237074401,
# Recall: 0.7381546134663342,
# F1: 0.7219512195121951
#
# Reward: 0.7219512195121951
#
# Epoch 31
# Feature set: ['reddish', 'metallic', 'colorful', 'dominating_color', 'color_bin_5', 'color_bin_6', 'color_bin_8', 'color_bin_9', 'dominating_texture', 'texture_1', 'texture_3', 'texture_9', 'in_shape', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5'],
# Accuracy: 0.7225725094577553,
# Recall: 0.7306733167082294,
# F1: 0.7270471464019851
#
# Reward: 0.7270471464019851
#
# Epoch 32
# Feature set: ['darker', 'reddish', 'metallic', 'dominating_color', 'color_bin_3', 'color_bin_6', 'color_bin_8', 'color_entropy', 'texture_1', 'texture_3', 'texture_8', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_1', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.7225725094577553,
# Recall: 0.7680798004987531,
# F1: 0.7368421052631579
#
# Reward: 0.7368421052631579
#
# Epoch 33
# Feature set: ['reddish', 'metallic', 'colorful', 'dominating_color', 'color_bin_2', 'color_bin_5', 'color_bin_6', 'color_bin_9', 'dominating_texture', 'texture_1', 'texture_3', 'texture_6', 'texture_7', 'texture_9', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_1', 'hu_moment_2', 'hu_moment_4', 'hu_moment_6'],
# Accuracy: 0.7276166456494325,
# Recall: 0.7356608478802993,
# F1: 0.7320099255583127
#
# Reward: 0.7320099255583127
#
# Epoch 34
# Feature set: ['reddish', 'metallic', 'colorful', 'dominating_color', 'color_bin_5', 'color_bin_6', 'color_entropy', 'dominating_texture', 'texture_1', 'texture_3', 'texture_5', 'texture_6', 'texture_7', 'texture_9', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.7200504413619168,
# Recall: 0.7331670822942643,
# F1: 0.725925925925926
#
# Reward: 0.725925925925926
#
# Epoch 35
# Feature set: ['reddish', 'metallic', 'dominating_color', 'color_bin_1', 'color_bin_5', 'color_bin_8', 'color_entropy', 'rough', 'texture_1', 'texture_2', 'texture_3', 'texture_4', 'texture_5', 'texture_9', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.725094577553594,
# Recall: 0.7406483790523691,
# F1: 0.7315270935960592
#
# Reward: 0.7315270935960592
#
# Epoch 36
# Feature set: ['reddish', 'dominating_color', 'color_bin_1', 'color_bin_5', 'color_bin_6', 'color_bin_8', 'color_bin_9', 'color_entropy', 'texture_1', 'texture_3', 'texture_9', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.6721311475409836,
# Recall: 0.6982543640897756,
# F1: 0.6829268292682927
#
# Reward: 0.6829268292682927
#
# Epoch 37
# Feature set: ['reddish', 'metallic', 'dominating_color', 'color_bin_1', 'color_bin_3', 'color_bin_6', 'color_entropy', 'dominating_texture', 'texture_0', 'texture_1', 'texture_3', 'texture_7', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_1', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5'],
# Accuracy: 0.7162673392181589,
# Recall: 0.7356608478802993,
# F1: 0.7239263803680982
#
# Reward: 0.7239263803680982
#
# Epoch 38
# Feature set: ['reddish', 'metallic', 'colorful', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_5', 'color_bin_8', 'color_bin_9', 'texture_1', 'texture_3', 'texture_8', 'texture_9', 'lengthy_aspect_ratio', 'rel_length', 'in_shape', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5'],
# Accuracy: 0.7351828499369483,
# Recall: 0.7680798004987531,
# F1: 0.7457627118644068
#
# Reward: 0.7457627118644068
#
# Epoch 39
# Feature set: ['gradient', 'metallic', 'colorful', 'dominating_color', 'color_bin_4', 'color_bin_6', 'color_bin_9', 'color_entropy', 'texture_1', 'texture_3', 'texture_9', 'in_shape', 'roundness', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.7213114754098361,
# Recall: 0.7381546134663342,
# F1: 0.7281672816728167
#
# Reward: 0.7281672816728167
#
# Epoch 40
# Feature set: ['reddish', 'metallic', 'colorful', 'dominating_color', 'color_bin_5', 'color_bin_6', 'color_bin_8', 'color_bin_9', 'color_entropy', 'texture_1', 'texture_6', 'texture_9', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.7137452711223203,
# Recall: 0.7356608478802993,
# F1: 0.7221542227662179
#
# Reward: 0.7221542227662179
#
# Epoch 41
# Feature set: ['reddish', 'metallic', 'colorful', 'dominating_color', 'color_bin_3', 'color_bin_6', 'color_entropy', 'dominating_texture', 'texture_1', 'texture_3', 'texture_4', 'texture_5', 'texture_7', 'texture_9', 'rough_entropy', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5'],
# Accuracy: 0.7137452711223203,
# Recall: 0.743142144638404,
# F1: 0.724179829890644
#
# Reward: 0.724179829890644
#
# Epoch 42
# Feature set: ['reddish', 'colorful', 'dominating_color', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_8', 'dominating_texture', 'texture_3', 'texture_8', 'texture_9', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_1', 'hu_moment_2'],
# Accuracy: 0.7074401008827238,
# Recall: 0.7082294264339152,
# F1: 0.71
#
# Reward: 0.71
#
# Epoch 43
# Feature set: ['darker', 'reddish', 'metallic', 'colorful', 'black', 'dominating_color', 'color_bin_4', 'color_bin_5', 'color_bin_8', 'texture_1', 'texture_3', 'texture_7', 'texture_8', 'texture_9', 'lengthy_aspect_ratio', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_2', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.742749054224464,
# Recall: 0.773067331670823,
# F1: 0.7524271844660194
#
# Reward: 0.7524271844660194
#
# Epoch 44
# Feature set: ['reddish', 'metallic', 'colorful', 'dominating_color', 'color_bin_6', 'color_bin_8', 'rough', 'texture_1', 'texture_3', 'texture_7', 'texture_8', 'texture_9', 'lengthy_aspect_ratio', 'rel_length', 'in_shape', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.7061790668348046,
# Recall: 0.713216957605985,
# F1: 0.7105590062111802
#
# Reward: 0.7105590062111802
#
# Epoch 45
# Feature set: ['reddish', 'dominating_color', 'color_bin_1', 'color_bin_5', 'color_bin_6', 'color_bin_8', 'color_bin_9', 'color_entropy', 'texture_1', 'texture_3', 'texture_9', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_1', 'hu_moment_2', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.6834804539722572,
# Recall: 0.6907730673316709,
# F1: 0.6881987577639752
#
# Reward: 0.6881987577639752
#
# Epoch 46
# Feature set: ['reddish', 'metallic', 'black', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_6', 'color_entropy', 'dominating_texture', 'texture_0', 'texture_1', 'texture_7', 'lengthy_aspect_ratio', 'in_shape', 'roundness', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5'],
# Accuracy: 0.7364438839848676,
# Recall: 0.7506234413965087,
# F1: 0.7422934648581998
#
# Reward: 0.7422934648581998
#
# Epoch 47
# Feature set: ['reddish', 'metallic', 'colorful', 'dominating_color', 'color_bin_1', 'color_bin_3', 'color_bin_4', 'dominating_texture', 'texture_0', 'texture_1', 'texture_7', 'texture_9', 'rough_entropy', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5'],
# Accuracy: 0.7200504413619168,
# Recall: 0.773067331670823,
# F1: 0.7363420427553444
#
# Reward: 0.7363420427553444
#
# Epoch 48
# Feature set: ['reddish', 'colorful', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_entropy', 'texture_3', 'texture_7', 'texture_9', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.6872635561160151,
# Recall: 0.6882793017456359,
# F1: 0.69
#
# Reward: 0.69
#
# Epoch 49
# Feature set: ['reddish', 'metallic', 'colorful', 'dominating_color', 'color_bin_1', 'color_bin_3', 'color_bin_5', 'color_bin_8', 'color_entropy', 'dominating_texture', 'texture_1', 'texture_3', 'texture_7', 'texture_9', 'lengthy_aspect_ratio', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.7150063051702396,
# Recall: 0.7306733167082294,
# F1: 0.7216748768472906
#
# Reward: 0.7216748768472906
#
# Epoch 50
# Feature set: ['reddish', 'metallic', 'colorful', 'black', 'dominating_color', 'color_bin_6', 'color_bin_8', 'color_bin_9', 'color_entropy', 'rough', 'texture_1', 'texture_3', 'texture_8', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_1', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.7477931904161412,
# Recall: 0.7830423940149626,
# F1: 0.7584541062801933
#
# Reward: 0.7584541062801933
#
# Epoch 51
# Feature set: ['reddish', 'metallic', 'colorful', 'dominating_color', 'color_bin_1', 'color_bin_4', 'color_bin_5', 'color_bin_9', 'dominating_texture', 'texture_1', 'texture_7', 'texture_9', 'lengthy_aspect_ratio', 'rel_length', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.6973518284993695,
# Recall: 0.7082294264339152,
# F1: 0.7029702970297029
#
# Reward: 0.7029702970297029
#
# Epoch 52
# Feature set: ['reddish', 'metallic', 'dominating_color', 'color_bin_6', 'color_entropy', 'texture_1', 'texture_2', 'texture_3', 'texture_6', 'texture_7', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.7263556116015133,
# Recall: 0.7356608478802993,
# F1: 0.7311028500619579
#
# Reward: 0.7311028500619579
#
# Epoch 53
# Feature set: ['reddish', 'metallic', 'color_bin_1', 'color_bin_5', 'color_bin_8', 'color_bin_9', 'color_entropy', 'dominating_texture', 'texture_1', 'texture_3', 'texture_5', 'texture_7', 'texture_9', 'rough_entropy', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5'],
# Accuracy: 0.7225725094577553,
# Recall: 0.743142144638404,
# F1: 0.7303921568627451
#
# Reward: 0.7303921568627451
#
# Epoch 54
# Feature set: ['reddish', 'black', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_5', 'color_bin_6', 'color_bin_9', 'color_entropy', 'texture_1', 'texture_3', 'texture_9', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_2', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.7238335435056746,
# Recall: 0.7581047381546134,
# F1: 0.7351874244256348
#
# Reward: 0.7351874244256348
#
# Epoch 55
# Feature set: ['reddish', 'metallic', 'dominating_color', 'color_bin_1', 'color_bin_9', 'color_entropy', 'dominating_texture', 'texture_0', 'texture_1', 'texture_7', 'texture_9', 'lengthy_aspect_ratio', 'rel_length', 'in_shape', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.6847414880201765,
# Recall: 0.7007481296758105,
# F1: 0.6921182266009852
#
# Reward: 0.6921182266009852
#
# Epoch 56
# Feature set: ['reddish', 'metallic', 'dominating_color', 'color_bin_1', 'color_bin_3', 'color_bin_6', 'color_entropy', 'texture_1', 'texture_3', 'texture_9', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.694829760403531,
# Recall: 0.7057356608478803,
# F1: 0.7004950495049505
#
# Reward: 0.7004950495049505
#
# Epoch 57
# Feature set: ['reddish', 'metallic', 'colorful', 'dominating_color', 'color_bin_1', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_8', 'color_bin_9', 'dominating_texture', 'texture_1', 'texture_7', 'texture_9', 'lengthy_aspect_ratio', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5'],
# Accuracy: 0.7162673392181589,
# Recall: 0.7356608478802993,
# F1: 0.7239263803680982
#
# Reward: 0.7239263803680982
#
# Epoch 58
# Feature set: ['metallic', 'colorful', 'dominating_color', 'color_bin_2', 'color_bin_6', 'color_entropy', 'texture_3', 'texture_8', 'lengthy_aspect_ratio', 'rel_length', 'in_shape', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5'],
# Accuracy: 0.7187894073139974,
# Recall: 0.7556109725685786,
# F1: 0.7310012062726177
#
# Reward: 0.7310012062726177
#
# Epoch 59
# Feature set: ['reddish', 'metallic', 'colorful', 'black', 'dominating_color', 'color_bin_5', 'color_bin_6', 'color_bin_8', 'dominating_texture', 'texture_1', 'texture_3', 'texture_7', 'texture_8', 'texture_9', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5'],
# Accuracy: 0.733921815889029,
# Recall: 0.7605985037406484,
# F1: 0.7429963459196103
#
# Reward: 0.7429963459196103
#
# Epoch 60
# Feature set: ['reddish', 'metallic', 'colorful', 'dominating_color', 'color_bin_1', 'color_bin_5', 'color_bin_6', 'color_bin_8', 'color_entropy', 'texture_1', 'texture_3', 'texture_8', 'texture_9', 'lengthy', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.7351828499369483,
# Recall: 0.7531172069825436,
# F1: 0.742014742014742
#
# Reward: 0.742014742014742
#
# Epoch 61
# Feature set: ['reddish', 'metallic', 'colorful', 'black', 'dominating_color', 'color_bin_5', 'color_bin_6', 'color_bin_8', 'color_bin_9', 'color_entropy', 'dominating_texture', 'texture_1', 'texture_3', 'texture_7', 'texture_8', 'texture_9', 'lengthy_aspect_ratio', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5'],
# Accuracy: 0.7414880201765448,
# Recall: 0.7630922693266833,
# F1: 0.7490820073439413
#
# Reward: 0.7490820073439413
#
# Epoch 62
# Feature set: ['reddish', 'metallic', 'colorful', 'dominating_color', 'color_bin_1', 'color_bin_6', 'color_bin_8', 'dominating_texture', 'texture_0', 'texture_1', 'texture_3', 'texture_9', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_1', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.7175283732660782,
# Recall: 0.7356608478802993,
# F1: 0.7248157248157249
#
# Reward: 0.7248157248157249
#
# Epoch 63
# Feature set: ['reddish', 'metallic', 'black', 'dominating_color', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_entropy', 'texture_1', 'texture_2', 'texture_3', 'texture_8', 'texture_9', 'lengthy_aspect_ratio', 'in_shape', 'roundness', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.733921815889029,
# Recall: 0.7680798004987531,
# F1: 0.7448609431680774
#
# Reward: 0.7448609431680774
#
# Epoch 64
# Feature set: ['reddish', 'metallic', 'colorful', 'dominating_color', 'color_bin_1', 'color_bin_5', 'color_bin_8', 'color_bin_9', 'dominating_texture', 'texture_1', 'texture_6', 'texture_7', 'texture_9', 'rough_entropy', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.7301387137452712,
# Recall: 0.7581047381546134,
# F1: 0.7396593673965937
#
# Reward: 0.7396593673965937
#
# Epoch 65
# Feature set: ['reddish', 'metallic', 'dominating_color', 'color_bin_3', 'color_bin_6', 'color_entropy', 'texture_1', 'texture_2', 'texture_3', 'texture_7', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5'],
# Accuracy: 0.7099621689785625,
# Recall: 0.7007481296758105,
# F1: 0.7095959595959596
#
# Reward: 0.7095959595959596
#
# Epoch 66
# Feature set: ['reddish', 'colorful', 'dominating_color', 'color_bin_3', 'color_bin_5', 'color_bin_8', 'color_bin_9', 'texture_1', 'texture_3', 'texture_7', 'texture_9', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_2', 'hu_moment_5'],
# Accuracy: 0.7099621689785625,
# Recall: 0.7182044887780549,
# F1: 0.7146401985111662
#
# Reward: 0.7146401985111662
#
# Epoch 67
# Feature set: ['reddish', 'metallic', 'colorful', 'color_bin_1', 'color_bin_6', 'color_bin_8', 'color_entropy', 'texture_1', 'texture_3', 'texture_7', 'texture_8', 'texture_9', 'rough_entropy', 'lengthy_aspect_ratio', 'rel_length', 'in_shape', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.7301387137452712,
# Recall: 0.7481296758104738,
# F1: 0.7371007371007371
#
# Reward: 0.7371007371007371
#
# Epoch 68
# Feature set: ['gradient', 'reddish', 'colorful', 'dominating_color', 'color_bin_1', 'color_bin_5', 'color_bin_6', 'color_bin_8', 'color_bin_9', 'texture_3', 'texture_9', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_1', 'hu_moment_2', 'hu_moment_5'],
# Accuracy: 0.6897856242118537,
# Recall: 0.6932668329177057,
# F1: 0.6932668329177057
#
# Reward: 0.6932668329177057
#
# Epoch 69
# Feature set: ['darker', 'reddish', 'metallic', 'dominating_color', 'color_bin_5', 'color_bin_6', 'color_entropy', 'texture_0', 'texture_3', 'texture_7', 'texture_8', 'texture_9', 'lengthy', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_1', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.7263556116015133,
# Recall: 0.7880299251870324,
# F1: 0.7444051825677267
#
# Reward: 0.7444051825677267
#
# Epoch 70
# Feature set: ['reddish', 'metallic', 'dominating_color', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_8', 'dominating_texture', 'texture_1', 'texture_3', 'texture_5', 'texture_6', 'texture_7', 'texture_9', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.7162673392181589,
# Recall: 0.713216957605985,
# F1: 0.7176913425345044
#
# Reward: 0.7176913425345044
#
# Epoch 71
# Feature set: ['gradient', 'reddish', 'metallic', 'dominating_color', 'color_bin_1', 'color_bin_4', 'color_bin_5', 'color_bin_6', 'color_bin_8', 'color_bin_9', 'dominating_texture', 'texture_1', 'texture_3', 'texture_5', 'texture_7', 'texture_9', 'rough_entropy', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.7213114754098361,
# Recall: 0.7256857855361596,
# F1: 0.7247820672478207
#
# Reward: 0.7247820672478207
#
# Epoch 72
# Feature set: ['reddish', 'metallic', 'dominating_color', 'color_bin_1', 'color_bin_6', 'color_bin_9', 'color_entropy', 'texture_1', 'texture_2', 'texture_3', 'texture_7', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7389659520807061,
# Recall: 0.7406483790523691,
# F1: 0.7415730337078652
#
# Reward: 0.7415730337078652
#
# Epoch 73
# Feature set: ['reddish', 'metallic', 'dominating_color', 'color_bin_1', 'color_bin_3', 'color_bin_5', 'color_bin_9', 'color_entropy', 'dominating_texture', 'texture_1', 'texture_3', 'texture_7', 'rough_entropy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_1', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5'],
# Accuracy: 0.725094577553594,
# Recall: 0.7556109725685786,
# F1: 0.7354368932038835
#
# Reward: 0.7354368932038835
#
# Epoch 74
# Feature set: ['reddish', 'metallic', 'dominating_color', 'color_bin_1', 'color_bin_4', 'color_bin_6', 'color_entropy', 'texture_1', 'texture_2', 'texture_7', 'lengthy_aspect_ratio', 'rel_length', 'in_shape', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5'],
# Accuracy: 0.7238335435056746,
# Recall: 0.71571072319202,
# F1: 0.7238335435056746
#
# Reward: 0.7238335435056746
#
# Epoch 75
# Feature set: ['reddish', 'metallic', 'colorful', 'black', 'dominating_color', 'color_bin_1', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_entropy', 'texture_0', 'texture_3', 'texture_7', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4'],
# Accuracy: 0.7414880201765448,
# Recall: 0.7680798004987531,
# F1: 0.7503045066991474
#
# Reward: 0.7503045066991474
#
# Epoch 76
# Feature set: ['reddish', 'metallic', 'colorful', 'dominating_color', 'color_bin_1', 'color_bin_4', 'color_entropy', 'dominating_texture', 'texture_1', 'texture_3', 'texture_7', 'texture_8', 'texture_9', 'rel_length', 'in_shape', 'hu_moment_2', 'hu_moment_3', 'hu_moment_5'],
# Accuracy: 0.712484237074401,
# Recall: 0.7406483790523691,
# F1: 0.7226277372262774
#
# Reward: 0.7226277372262774
#
# Epoch 77
# Feature set: ['darker', 'reddish', 'metallic', 'colorful', 'black', 'dominating_color', 'color_bin_1', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'dominating_texture', 'texture_0', 'texture_1', 'texture_3', 'texture_8', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.7440100882723834,
# Recall: 0.7905236907730673,
# F1: 0.7574671445639187
#
# Reward: 0.7574671445639187
#
# Epoch 78
# Feature set: ['gradient', 'reddish', 'metallic', 'dominating_color', 'color_bin_1', 'color_bin_6', 'color_bin_8', 'dominating_texture', 'texture_0', 'texture_1', 'texture_3', 'texture_7', 'texture_8', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.7213114754098361,
# Recall: 0.7381546134663342,
# F1: 0.7281672816728167
#
# Reward: 0.7281672816728167
#
# Epoch 79
# Feature set: ['reddish', 'metallic', 'dominating_color', 'color_bin_1', 'color_bin_5', 'color_bin_8', 'texture_1', 'texture_3', 'texture_5', 'texture_7', 'texture_9', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.7023959646910467,
# Recall: 0.7082294264339152,
# F1: 0.7064676616915423
#
# Reward: 0.7064676616915423
#
# Epoch 80
# Feature set: ['reddish', 'metallic', 'color_bin_1', 'color_bin_5', 'color_bin_6', 'color_bin_9', 'color_entropy', 'texture_1', 'texture_2', 'texture_3', 'texture_7', 'texture_9', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_2', 'hu_moment_3', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.725094577553594,
# Recall: 0.7381546134663342,
# F1: 0.7308641975308642
#
# Reward: 0.7308641975308642
#
# Epoch 81
# Feature set: ['reddish', 'metallic', 'dominating_color', 'color_bin_1', 'color_bin_3', 'color_bin_8', 'color_bin_9', 'color_entropy', 'dominating_texture', 'texture_0', 'texture_1', 'texture_3', 'texture_6', 'texture_7', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.7023959646910467,
# Recall: 0.71571072319202,
# F1: 0.7086419753086419
#
# Reward: 0.7086419753086419
#
# Epoch 82
# Feature set: ['reddish', 'metallic', 'colorful', 'dominating_color', 'color_bin_1', 'color_bin_5', 'color_bin_9', 'texture_1', 'texture_2', 'texture_3', 'texture_9', 'rough_entropy', 'lengthy_aspect_ratio', 'rel_length', 'in_shape', 'roundness', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5'],
# Accuracy: 0.733921815889029,
# Recall: 0.7531172069825436,
# F1: 0.7411042944785277
#
# Reward: 0.7411042944785277
#
# Epoch 83
# Feature set: ['reddish', 'metallic', 'dominating_color', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_8', 'color_entropy', 'texture_1', 'texture_3', 'texture_6', 'texture_9', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5'],
# Accuracy: 0.7175283732660782,
# Recall: 0.7206982543640897,
# F1: 0.7206982543640897
#
# Reward: 0.7206982543640897
#
# Epoch 84
# Feature set: ['reddish', 'metallic', 'colorful', 'dominating_color', 'color_bin_5', 'color_bin_6', 'color_bin_8', 'color_bin_9', 'color_entropy', 'texture_1', 'texture_3', 'texture_7', 'texture_9', 'rough_entropy', 'lengthy_aspect_ratio', 'rel_length', 'in_shape', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5'],
# Accuracy: 0.7288776796973518,
# Recall: 0.743142144638404,
# F1: 0.7348951911220715
#
# Reward: 0.7348951911220715
#
# Epoch 85
# Feature set: ['reddish', 'metallic', 'colorful', 'black', 'dominating_color', 'color_bin_5', 'color_bin_6', 'color_bin_8', 'color_entropy', 'rough', 'texture_1', 'texture_3', 'texture_7', 'texture_8', 'texture_9', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5'],
# Accuracy: 0.7452711223203027,
# Recall: 0.7680798004987531,
# F1: 0.7530562347188264
#
# Reward: 0.7530562347188264
#
# Epoch 86
# Feature set: ['darker', 'reddish', 'metallic', 'colorful', 'dominating_color', 'color_bin_1', 'color_bin_6', 'color_bin_9', 'color_entropy', 'texture_1', 'texture_3', 'texture_7', 'texture_8', 'texture_9', 'lengthy_aspect_ratio', 'rel_length', 'in_shape', 'roundness', 'hu_moment_2', 'hu_moment_4', 'hu_moment_6'],
# Accuracy: 0.725094577553594,
# Recall: 0.7855361596009975,
# F1: 0.7429245283018868
#
# Reward: 0.7429245283018868
#
# Epoch 87
# Feature set: ['reddish', 'metallic', 'dominating_color', 'color_bin_1', 'color_bin_6', 'color_bin_9', 'color_entropy', 'dominating_texture', 'texture_1', 'texture_3', 'texture_7', 'texture_8', 'texture_9', 'rough_entropy', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.7276166456494325,
# Recall: 0.7481296758104738,
# F1: 0.7352941176470589
#
# Reward: 0.7352941176470589
#
# Epoch 88
# Feature set: ['reddish', 'dominating_color', 'color_bin_1', 'color_bin_3', 'color_bin_5', 'texture_0', 'texture_3', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_1', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5'],
# Accuracy: 0.7112232030264817,
# Recall: 0.7231920199501247,
# F1: 0.7169344870210136
#
# Reward: 0.7169344870210136
#
# Epoch 89
# Feature set: ['darker', 'reddish', 'metallic', 'colorful', 'dominating_color', 'color_bin_3', 'color_bin_4', 'color_bin_5', 'color_bin_8', 'color_bin_9', 'color_entropy', 'dominating_texture', 'texture_1', 'texture_3', 'texture_7', 'texture_9', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.7238335435056746,
# Recall: 0.7905236907730673,
# F1: 0.7432590855803048
#
# Reward: 0.7432590855803048
#
# Epoch 90
# Feature set: ['reddish', 'metallic', 'dominating_color', 'color_bin_6', 'color_bin_8', 'color_entropy', 'dominating_texture', 'texture_1', 'texture_2', 'texture_3', 'texture_7', 'texture_9', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_7'],
# Accuracy: 0.725094577553594,
# Recall: 0.7356608478802993,
# F1: 0.7301980198019802
#
# Reward: 0.7301980198019802
#
# Epoch 91
# Feature set: ['reddish', 'colorful', 'black', 'dominating_color', 'color_bin_5', 'color_bin_6', 'color_bin_8', 'dominating_texture', 'texture_3', 'texture_8', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_5'],
# Accuracy: 0.725094577553594,
# Recall: 0.7556109725685786,
# F1: 0.7354368932038835
#
# Reward: 0.7354368932038835
#
# Epoch 92
# Feature set: ['reddish', 'metallic', 'colorful', 'dominating_color', 'color_bin_1', 'color_bin_5', 'color_bin_8', 'dominating_texture', 'texture_0', 'texture_1', 'texture_3', 'texture_7', 'texture_8', 'texture_9', 'lengthy_aspect_ratio', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5'],
# Accuracy: 0.7238335435056746,
# Recall: 0.7556109725685786,
# F1: 0.7345454545454545
#
# Reward: 0.7345454545454545
#
# Epoch 93
# Feature set: ['reddish', 'colorful', 'black', 'dominating_color', 'color_bin_3', 'color_bin_6', 'color_entropy', 'texture_1', 'texture_3', 'texture_8', 'texture_9', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_1', 'hu_moment_2', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.7238335435056746,
# Recall: 0.7581047381546134,
# F1: 0.7351874244256348
#
# Reward: 0.7351874244256348
#
# Epoch 94
# Feature set: ['reddish', 'metallic', 'colorful', 'dominating_color', 'color_bin_5', 'color_entropy', 'texture_1', 'texture_9', 'lengthy_aspect_ratio', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_2', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.6973518284993695,
# Recall: 0.7032418952618454,
# F1: 0.7014925373134329
#
# Reward: 0.7014925373134329
#
# Epoch 95
# Feature set: ['reddish', 'metallic', 'colorful', 'black', 'dominating_color', 'color_bin_4', 'color_bin_6', 'color_entropy', 'dominating_texture', 'texture_1', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_1', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.7364438839848676,
# Recall: 0.7556109725685786,
# F1: 0.743558282208589
#
# Reward: 0.743558282208589
#
# Epoch 96
# Feature set: ['reddish', 'metallic', 'colorful', 'dominating_color', 'color_bin_3', 'color_bin_6', 'color_bin_8', 'dominating_texture', 'texture_0', 'texture_1', 'texture_3', 'texture_7', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5'],
# Accuracy: 0.7175283732660782,
# Recall: 0.743142144638404,
# F1: 0.7268292682926829
#
# Reward: 0.7268292682926829
#
# Epoch 97
# Feature set: ['reddish', 'metallic', 'colorful', 'black_thin', 'dominating_color', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_8', 'texture_1', 'texture_3', 'texture_7', 'texture_8', 'texture_9', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5'],
# Accuracy: 0.7351828499369483,
# Recall: 0.7605985037406484,
# F1: 0.7439024390243902
#
# Reward: 0.7439024390243902
#
# Epoch 98
# Feature set: ['reddish', 'colorful', 'dominating_color', 'color_bin_1', 'color_bin_5', 'color_bin_8', 'color_bin_9', 'color_entropy', 'texture_1', 'texture_3', 'texture_8', 'texture_9', 'lengthy_aspect_ratio', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.7225725094577553,
# Recall: 0.7481296758104738,
# F1: 0.7317073170731707
#
# Reward: 0.7317073170731707
#
# Epoch 99
# Feature set: ['reddish', 'metallic', 'black', 'dominating_color', 'color_bin_1', 'color_bin_6', 'color_entropy', 'dominating_texture', 'texture_0', 'texture_1', 'texture_3', 'texture_5', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_1', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.7465321563682219,
# Recall: 0.7655860349127181,
# F1: 0.7533742331288343
#
# Reward: 0.7533742331288343
#
# Epoch 100
# Feature set: ['reddish', 'metallic', 'dominating_color', 'color_bin_1', 'color_bin_5', 'color_bin_9', 'color_entropy', 'dominating_texture', 'texture_1', 'texture_2', 'texture_7', 'texture_9', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.7301387137452712,
# Recall: 0.7356608478802993,
# F1: 0.7338308457711443
#
# Reward: 0.7338308457711443
#
# Epoch 101
# Feature set: ['darker', 'reddish', 'metallic', 'dominating_color', 'color_bin_3', 'color_bin_6', 'color_bin_7', 'color_entropy', 'dominating_texture', 'texture_3', 'texture_7', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.699873896595208,
# Recall: 0.7655860349127181,
# F1: 0.7206572769953051
#
# Reward: 0.7206572769953051
#
# Epoch 102
# Feature set: ['reddish', 'metallic', 'dominating_color', 'color_bin_1', 'color_bin_5', 'color_bin_8', 'color_bin_9', 'dominating_texture', 'texture_1', 'texture_2', 'texture_3', 'texture_6', 'texture_7', 'texture_9', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5'],
# Accuracy: 0.7326607818411097,
# Recall: 0.7481296758104738,
# F1: 0.7389162561576355
#
# Reward: 0.7389162561576355
#
# Epoch 103
# Feature set: ['reddish', 'dominating_color', 'color_bin_1', 'color_bin_6', 'color_entropy', 'texture_3', 'texture_5', 'texture_9', 'rough_entropy', 'lengthy_aspect_ratio', 'rel_length', 'hu_moment_2', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.6721311475409836,
# Recall: 0.6683291770573566,
# F1: 0.6733668341708543
#
# Reward: 0.6733668341708543
#
# Epoch 104
# Feature set: ['reddish', 'metallic', 'black', 'color_bin_5', 'color_bin_6', 'color_bin_9', 'color_entropy', 'dominating_texture', 'texture_0', 'texture_1', 'texture_3', 'texture_7', 'texture_9', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.755359394703657,
# Recall: 0.7955112219451371,
# F1: 0.7668269230769231
#
# Reward: 0.7668269230769231
#
# Epoch 105
# Feature set: ['gradient', 'reddish', 'metallic', 'dominating_color', 'color_bin_1', 'color_bin_6', 'color_bin_8', 'color_bin_9', 'color_entropy', 'texture_0', 'texture_1', 'texture_7', 'texture_9', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.7087011349306431,
# Recall: 0.7032418952618454,
# F1: 0.7094339622641509
#
# Reward: 0.7094339622641509
#
# Epoch 106
# Feature set: ['reddish', 'metallic', 'black', 'dominating_color', 'color_bin_1', 'color_bin_3', 'color_bin_6', 'color_entropy', 'dominating_texture', 'texture_2', 'texture_3', 'texture_5', 'texture_6', 'texture_7', 'texture_9', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.733921815889029,
# Recall: 0.7506234413965087,
# F1: 0.7404674046740467
#
# Reward: 0.7404674046740467
#
# Epoch 107
# Feature set: ['reddish', 'metallic', 'colorful', 'dominating_color', 'color_bin_1', 'color_bin_5', 'color_bin_8', 'color_bin_9', 'color_entropy', 'dominating_texture', 'texture_1', 'texture_3', 'texture_7', 'texture_8', 'texture_9', 'lengthy_aspect_ratio', 'rel_length', 'in_shape', 'hu_moment_2', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.7087011349306431,
# Recall: 0.7381546134663342,
# F1: 0.7193195625759417
#
# Reward: 0.7193195625759417
#
# Epoch 108
# Feature set: ['reddish', 'metallic', 'black', 'dominating_color', 'color_bin_1', 'color_bin_6', 'color_entropy', 'texture_1', 'texture_3', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.7313997477931904,
# Recall: 0.7356608478802993,
# F1: 0.7347447073474471
#
# Reward: 0.7347447073474471
#
# Epoch 109
# Feature set: ['reddish', 'metallic', 'colorful', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_9', 'color_entropy', 'dominating_texture', 'texture_0', 'texture_1', 'texture_7', 'in_shape', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5'],
# Accuracy: 0.7225725094577553,
# Recall: 0.7655860349127181,
# F1: 0.7362110311750599
#
# Reward: 0.7362110311750599
#
# Epoch 110
# Feature set: ['reddish', 'metallic', 'dominating_color', 'color_bin_1', 'color_bin_3', 'color_bin_5', 'texture_1', 'texture_2', 'texture_3', 'texture_7', 'texture_8', 'texture_9', 'rel_length', 'in_shape', 'hu_moment_2', 'hu_moment_4', 'hu_moment_6'],
# Accuracy: 0.7238335435056746,
# Recall: 0.7256857855361596,
# F1: 0.7265917602996255
#
# Reward: 0.7265917602996255
#
# Epoch 111
# Feature set: ['reddish', 'metallic', 'color_bin_1', 'color_bin_5', 'color_bin_6', 'color_bin_8', 'color_entropy', 'dominating_texture', 'texture_1', 'texture_3', 'texture_7', 'texture_9', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.7175283732660782,
# Recall: 0.743142144638404,
# F1: 0.7268292682926829
#
# Reward: 0.7268292682926829
#
# Epoch 112
# Feature set: ['reddish', 'dominating_color', 'color_bin_3', 'color_bin_9', 'color_entropy', 'texture_3', 'lengthy_aspect_ratio', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5'],
# Accuracy: 0.605296343001261,
# Recall: 0.628428927680798,
# F1: 0.616891064871481
#
# Reward: 0.616891064871481
#
# Epoch 113
# Feature set: ['reddish', 'metallic', 'colorful', 'black', 'color_bin_1', 'color_bin_3', 'color_bin_5', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'dominating_texture', 'texture_0', 'texture_1', 'texture_3', 'texture_7', 'texture_9', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_4', 'hu_moment_5'],
# Accuracy: 0.7377049180327869,
# Recall: 0.7755610972568578,
# F1: 0.7493975903614458
#
# Reward: 0.7493975903614458
#
# Epoch 114
# Feature set: ['darker', 'reddish', 'metallic', 'colorful', 'color_bin_1', 'color_bin_3', 'color_bin_5', 'color_bin_8', 'color_bin_9', 'texture_1', 'texture_3', 'texture_9', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_4', 'hu_moment_5'],
# Accuracy: 0.7087011349306431,
# Recall: 0.773067331670823,
# F1: 0.7285546415981199
#
# Reward: 0.7285546415981199
#
# Epoch 115
# ...
# Accuracy: 0.712484237074401,
# Recall: 0.7356608478802993,
# F1: 0.7212713936430318
#
# Reward: 0.7212713936430318
#
# Epoch 213
# Feature set: ['reddish', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_5', 'color_bin_6', 'color_bin_9', 'texture_3', 'texture_4', 'texture_9', 'rough_entropy', 'lengthy', 'in_shape', 'hu_moment_6'],
# Accuracy: 0.7263556116015133,
# Recall: 0.7581047381546134,
# F1: 0.7369696969696969
#
# Reward: 0.7369696969696969
#
# Epoch 214
# Feature set: ['reddish', 'colorful', 'black_thin', 'dominating_color', 'color_bin_5', 'color_bin_6', 'color_bin_9', 'color_entropy', 'texture_3', 'texture_8', 'texture_9', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.725094577553594,
# Recall: 0.7456359102244389,
# F1: 0.7328431372549019
#
# Reward: 0.7328431372549019
#
# Epoch 215
# Feature set: ['gradient', 'reddish', 'metallic', 'colorful', 'black_thin', 'color_bin_4', 'color_bin_5', 'color_bin_6', 'color_bin_8', 'color_bin_9', 'color_entropy', 'texture_1', 'texture_3', 'texture_8', 'texture_9', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.7162673392181589,
# Recall: 0.743142144638404,
# F1: 0.7259439707673568
#
# Reward: 0.7259439707673568
#
# Epoch 216
# Feature set: ['reddish', 'metallic', 'colorful', 'black_thin', 'dominating_color', 'color_bin_5', 'color_bin_6', 'color_bin_8', 'color_entropy', 'texture_1', 'texture_8', 'texture_9', 'lengthy', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.7364438839848676,
# Recall: 0.7531172069825436,
# F1: 0.7429274292742928
#
# Reward: 0.7429274292742928
#
# Epoch 217
# Feature set: ['darker', 'reddish', 'colorful', 'black', 'dominating_color', 'color_bin_3', 'color_bin_4', 'color_bin_5', 'color_bin_6', 'color_bin_9', 'color_entropy', 'dominating_texture', 'texture_1', 'texture_3', 'texture_7', 'texture_9', 'rough_entropy', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_1', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5'],
# Accuracy: 0.7402269861286255,
# Recall: 0.7805486284289277,
# F1: 0.7524038461538461
#
# Reward: 0.7524038461538461
#
# Epoch 218
# Feature set: ['reddish', 'metallic', 'dominating_color', 'color_bin_1', 'color_bin_3', 'color_bin_6', 'color_entropy', 'rough', 'dominating_texture', 'texture_1', 'texture_3', 'texture_6', 'texture_7', 'texture_9', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_2', 'hu_moment_4', 'hu_moment_6'],
# Accuracy: 0.7061790668348046,
# Recall: 0.6982543640897756,
# F1: 0.7061790668348046
#
# Reward: 0.7061790668348046
#
# Epoch 219
# Feature set: ['reddish', 'metallic', 'colorful', 'dominating_color', 'color_bin_1', 'color_bin_5', 'color_bin_6', 'color_bin_9', 'color_entropy', 'texture_0', 'texture_1', 'texture_2', 'texture_3', 'texture_7', 'texture_9', 'lengthy_aspect_ratio', 'rel_length', 'in_shape', 'hu_moment_2', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.7200504413619168,
# Recall: 0.7381546134663342,
# F1: 0.7272727272727273
#
# Reward: 0.7272727272727273
#
# Epoch 220
# Feature set: ['reddish', 'metallic', 'colorful', 'dominating_color', 'color_bin_1', 'color_bin_6', 'color_bin_8', 'color_entropy', 'dominating_texture', 'texture_1', 'texture_3', 'texture_4', 'texture_7', 'texture_9', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.7175283732660782,
# Recall: 0.7481296758104738,
# F1: 0.7281553398058253
#
# Reward: 0.7281553398058253
#
# Epoch 221
# Feature set: ['reddish', 'metallic', 'colorful', 'dominating_color', 'color_bin_1', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_8', 'color_entropy', 'texture_1', 'texture_9', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_1', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.699873896595208,
# Recall: 0.7057356608478803,
# F1: 0.7039800995024875
#
# Reward: 0.7039800995024875
#
# Epoch 222
# Feature set: ['reddish', 'metallic', 'colorful', 'black', 'dominating_color', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_9', 'color_entropy', 'dominating_texture', 'texture_0', 'texture_1', 'texture_3', 'texture_7', 'texture_8', 'texture_9', 'lengthy_aspect_ratio', 'rel_length', 'in_shape', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5'],
# Accuracy: 0.7389659520807061,
# Recall: 0.7930174563591023,
# F1: 0.7544483985765125
#
# Reward: 0.7544483985765125
#
# Epoch 223
# Feature set: ['reddish', 'metallic', 'colorful', 'dominating_color', 'color_bin_6', 'color_bin_8', 'color_entropy', 'rough', 'dominating_texture', 'texture_0', 'texture_1', 'texture_3', 'texture_8', 'texture_9', 'lengthy_aspect_ratio', 'rel_length', 'in_shape', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.7389659520807061,
# Recall: 0.7605985037406484,
# F1: 0.7466340269277846
#
# Reward: 0.7466340269277846
#
# Epoch 224
# Feature set: ['reddish', 'metallic', 'dominating_color', 'color_bin_1', 'color_bin_5', 'color_bin_8', 'color_bin_9', 'texture_1', 'texture_5', 'texture_8', 'texture_9', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_1', 'hu_moment_2', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.7074401008827238,
# Recall: 0.7306733167082294,
# F1: 0.7163814180929096
#
# Reward: 0.7163814180929096
#
# Epoch 225
# Feature set: ['reddish', 'metallic', 'color_bin_1', 'color_bin_6', 'color_bin_9', 'color_entropy', 'dominating_texture', 'texture_1', 'texture_7', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.712484237074401,
# Recall: 0.7331670822942643,
# F1: 0.7205882352941176
#
# Reward: 0.7205882352941176
#
# Epoch 226
# Feature set: ['reddish', 'metallic', 'dominating_color', 'color_bin_3', 'color_entropy', 'dominating_texture', 'texture_1', 'texture_3', 'texture_6', 'texture_7', 'in_shape', 'hu_moment_2', 'hu_moment_4'],
# Accuracy: 0.699873896595208,
# Recall: 0.7057356608478803,
# F1: 0.7039800995024875
#
# Reward: 0.7039800995024875
#
# Epoch 227
# Feature set: ['reddish', 'colorful', 'color_bin_5', 'color_bin_9', 'color_entropy', 'texture_1', 'texture_3', 'texture_7', 'texture_8', 'rough_entropy', 'rel_length', 'in_shape', 'hu_moment_2', 'hu_moment_3'],
# Accuracy: 0.7364438839848676,
# Recall: 0.7481296758104738,
# F1: 0.7416563658838071
#
# Reward: 0.7416563658838071
#
# Epoch 228
# Feature set: ['reddish', 'metallic', 'dominating_color', 'color_bin_5', 'color_bin_8', 'color_entropy', 'texture_0', 'texture_3', 'texture_7', 'texture_8', 'texture_9', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'rel_length', 'in_shape', 'hu_moment_2'],
# Accuracy: 0.7112232030264817,
# Recall: 0.743142144638404,
# F1: 0.7224242424242424
#
# Reward: 0.7224242424242424
#
# Epoch 229
# Feature set: ['gradient', 'reddish', 'metallic', 'colorful', 'black', 'dominating_color', 'color_bin_5', 'color_bin_6', 'color_bin_8', 'color_entropy', 'texture_0', 'texture_3', 'texture_7', 'texture_8', 'texture_9', 'lengthy_aspect_ratio', 'rel_length', 'in_shape', 'roundness', 'hu_moment_2', 'hu_moment_6'],
# Accuracy: 0.742749054224464,
# Recall: 0.770573566084788,
# F1: 0.7518248175182481
#
# Reward: 0.7518248175182481
#
# Epoch 230
# Feature set: ['reddish', 'metallic', 'colorful', 'dominating_color', 'color_bin_4', 'color_bin_6', 'color_bin_8', 'color_entropy', 'texture_1', 'texture_6', 'texture_7', 'texture_8', 'texture_9', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.7313997477931904,
# Recall: 0.7456359102244389,
# F1: 0.7373612823674476
#
# Reward: 0.7373612823674476
#
# Epoch 231
# Feature set: ['reddish', 'metallic', 'colorful', 'dominating_color', 'color_bin_1', 'color_bin_5', 'color_bin_6', 'color_bin_8', 'color_bin_9', 'color_entropy', 'dominating_texture', 'texture_1', 'texture_3', 'texture_9', 'lengthy', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7225725094577553,
# Recall: 0.7481296758104738,
# F1: 0.7317073170731707
#
# Reward: 0.7317073170731707
#
# Epoch 232
# Feature set: ['reddish', 'metallic', 'dominating_color', 'color_bin_6', 'color_bin_8', 'color_entropy', 'texture_1', 'texture_3', 'texture_7', 'texture_8', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_1', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.7074401008827238,
# Recall: 0.7281795511221946,
# F1: 0.7156862745098039
#
# Reward: 0.7156862745098039
#
# Epoch 233
# Feature set: ['reddish', 'metallic', 'colorful', 'dominating_color', 'color_bin_1', 'color_bin_4', 'color_bin_5', 'color_bin_6', 'color_bin_8', 'color_bin_9', 'texture_1', 'texture_3', 'texture_7', 'texture_9', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.7150063051702396,
# Recall: 0.7256857855361596,
# F1: 0.7202970297029703
#
# Reward: 0.7202970297029703
#
# Epoch 234
# Feature set: ['reddish', 'metallic', 'dominating_color', 'color_bin_6', 'color_entropy', 'dominating_texture', 'texture_1', 'texture_2', 'texture_3', 'texture_5', 'texture_7', 'texture_9', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.7150063051702396,
# Recall: 0.7306733167082294,
# F1: 0.7216748768472906
#
# Reward: 0.7216748768472906
#
# Epoch 235
# Feature set: ['reddish', 'metallic', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_5', 'color_bin_8', 'dominating_texture', 'texture_1', 'texture_3', 'texture_8', 'rough_entropy', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_1', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5'],
# Accuracy: 0.7238335435056746,
# Recall: 0.743142144638404,
# F1: 0.7312883435582822
#
# Reward: 0.7312883435582822
#
# Epoch 236
# Feature set: ['reddish', 'metallic', 'dominating_color', 'color_bin_1', 'color_bin_5', 'color_entropy', 'texture_1', 'texture_3', 'texture_7', 'texture_9', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5'],
# Accuracy: 0.7087011349306431,
# Recall: 0.7256857855361596,
# F1: 0.7158671586715867
#
# Reward: 0.7158671586715867
#
# Epoch 237
# Feature set: ['gradient', 'reddish', 'metallic', 'colorful', 'black', 'black_thin', 'color_bin_1', 'color_bin_5', 'color_bin_6', 'color_bin_9', 'color_entropy', 'dominating_texture', 'texture_1', 'texture_3', 'texture_7', 'texture_9', 'lengthy', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.7213114754098361,
# Recall: 0.743142144638404,
# F1: 0.7294981640146879
#
# Reward: 0.7294981640146879
#
# Epoch 238
# Feature set: ['reddish', 'metallic', 'dominating_color', 'color_bin_1', 'color_bin_5', 'color_bin_6', 'color_bin_9', 'color_entropy', 'dominating_texture', 'texture_1', 'texture_3', 'texture_7', 'texture_9', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.6986128625472888,
# Recall: 0.7182044887780549,
# F1: 0.7067484662576687
#
# Reward: 0.7067484662576687
#
# Epoch 239
# Feature set: ['reddish', 'metallic', 'dominating_color', 'color_bin_1', 'color_bin_3', 'color_bin_6', 'color_entropy', 'dominating_texture', 'texture_1', 'texture_2', 'texture_3', 'texture_5', 'texture_7', 'texture_8', 'texture_9', 'lengthy', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_1', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.7276166456494325,
# Recall: 0.7406483790523691,
# F1: 0.7333333333333333
#
# Reward: 0.7333333333333333
#
# Epoch 240
# Feature set: ['reddish', 'metallic', 'colorful', 'dominating_color', 'color_bin_5', 'color_bin_8', 'color_bin_9', 'color_entropy', 'texture_1', 'texture_3', 'texture_7', 'texture_8', 'texture_9', 'lengthy_aspect_ratio', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.7187894073139974,
# Recall: 0.7331670822942643,
# F1: 0.7250308261405672
#
# Reward: 0.7250308261405672
#
# Epoch 241
# Feature set: ['metallic', 'black', 'dominating_color', 'color_bin_1', 'color_bin_6', 'color_bin_8', 'dominating_texture', 'texture_1', 'texture_2', 'texture_5', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.7515762925598991,
# Recall: 0.770573566084788,
# F1: 0.758282208588957
#
# Reward: 0.758282208588957
#
# Epoch 242
# Feature set: ['darker', 'reddish', 'metallic', 'dominating_color', 'color_bin_5', 'color_bin_6', 'color_entropy', 'dominating_texture', 'texture_1', 'texture_2', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.7099621689785625,
# Recall: 0.7531172069825436,
# F1: 0.7242206235011991
#
# Reward: 0.7242206235011991
#
# Epoch 243
# Feature set: ['reddish', 'metallic', 'dominating_color', 'color_bin_3', 'color_entropy', 'dominating_texture', 'texture_1', 'texture_7', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.7162673392181589,
# Recall: 0.7306733167082294,
# F1: 0.7225647348951911
#
# Reward: 0.7225647348951911
#
# Epoch 244
# Feature set: ['gradient', 'reddish', 'metallic', 'colorful', 'dominating_color', 'color_bin_5', 'color_bin_8', 'color_entropy', 'dominating_texture', 'texture_1', 'texture_7', 'rough_entropy', 'lengthy_aspect_ratio', 'rel_length', 'in_shape', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.7452711223203027,
# Recall: 0.7655860349127181,
# F1: 0.7524509803921569
#
# Reward: 0.7524509803921569
#
# Epoch 245
# Feature set: ['reddish', 'metallic', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_4', 'color_bin_6', 'color_bin_8', 'color_entropy', 'texture_1', 'texture_3', 'texture_7', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.7137452711223203,
# Recall: 0.7256857855361596,
# F1: 0.7194066749072929
#
# Reward: 0.7194066749072929
#
# Epoch 246
# Feature set: ['reddish', 'metallic', 'colorful', 'dominating_color', 'color_bin_1', 'color_bin_5', 'color_bin_6', 'color_entropy', 'texture_3', 'texture_9', 'in_shape', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.7036569987389659,
# Recall: 0.7306733167082294,
# F1: 0.7137637028014616
#
# Reward: 0.7137637028014616
#
# Epoch 247
# Feature set: ['reddish', 'metallic', 'colorful', 'black', 'dominating_color', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_9', 'color_entropy', 'dominating_texture', 'texture_1', 'texture_2', 'texture_3', 'texture_7', 'texture_9', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.733921815889029,
# Recall: 0.7780548628428927,
# F1: 0.7473053892215569
#
# Reward: 0.7473053892215569
#
# Epoch 248
# Feature set: ['reddish', 'metallic', 'colorful', 'dominating_color', 'color_bin_4', 'color_bin_6', 'color_bin_8', 'color_entropy', 'dominating_texture', 'texture_1', 'texture_2', 'texture_3', 'texture_5', 'texture_7', 'texture_9', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_2', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.7313997477931904,
# Recall: 0.7481296758104738,
# F1: 0.7380073800738007
#
# Reward: 0.7380073800738007
#
# Epoch 249
# Feature set: ['reddish', 'black', 'dominating_color', 'color_bin_1', 'color_bin_5', 'color_bin_6', 'color_bin_8', 'color_entropy', 'texture_1', 'texture_3', 'texture_8', 'texture_9', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.7402269861286255,
# Recall: 0.7680798004987531,
# F1: 0.7493917274939172
#
# Reward: 0.7493917274939172
# Best Feature set: ('darker', 'gradient', 'reddish', 'metallic', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_3', 'color_bin_6', 'color_entropy', 'dominating_texture', 'texture_1', 'texture_3', 'texture_6', 'texture_7', 'rough_entropy', 'lengthy_aspect_ratio', 'in_shape', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5')
# Reward: 0.7703703703703704
