# %% [markdown]
# # Meta-learning classification features: Model

# %% [markdown]
# **Imports**

# %%
# imports

import numpy as np
import pandas as pd
import torch
import torch.nn as nn

import random
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, recall_score, f1_score

# %% [markdown]
# **Classification model**

# %%
class ClassificationModel():

    def __init__(self, target_label):

        self.all_features = ["darker", "gradient", "reddish", "metallic", "colorful", "black", "black_thin", "dominating_color", "color_bin_1", 
                             "color_bin_2", "color_bin_3", "color_bin_4", "color_bin_5", "color_bin_6", "color_bin_7", "color_bin_8", "color_bin_9", 
                             "color_entropy", "rough", "dominating_texture", "texture_0", "texture_1", "texture_2", "texture_3", "texture_4", 
                             "texture_5", "texture_6", "texture_7", "texture_8", "texture_9", "rough_entropy", "lengthy", "number_lengthy_objects", 
                             "lengthy_aspect_ratio", "rel_length", "in_shape", "roundness", "hu_moment_1", "hu_moment_2", "hu_moment_3", 
                             "hu_moment_4", "hu_moment_5", "hu_moment_6", "hu_moment_7"]

        self.target_label = target_label
        self.dataset = self.load_dataset()
        self.x_train, self.x_test, self.y_train, self.y_test = self.create_train_test_data()
        self.measures = {}
        self.feature_importances = pd.Series()
        self.run(self.all_features)

    def load_dataset(self):

        dataset = pd.read_csv("samples_0_6935_all_defects.csv", sep = ",")
        dataset.drop(columns = ["Unnamed: 0", "image_number", "defect_number"], inplace = True)
        dataset.dropna(inplace = True)

        return dataset
    
    def create_train_test_data(self):

        # Create rust labels:
        target_class_df = self.dataset.copy()
        target_class_df["target_label"] = target_class_df["label"].apply(lambda x: 1 if x == self.target_label else 0)

        # Apply train test split:
        target_class_df = target_class_df.sort_values(by = "target_label", ascending = False)
        number_of_defects = target_class_df["target_label"].sum()
        target_class_df_1 = target_class_df.iloc[:number_of_defects, :]
        negative_samples = random.sample(range(number_of_defects, len(target_class_df)), number_of_defects)
        target_class_df_0 = target_class_df.iloc[negative_samples, :]
        df = pd.concat([target_class_df_1, target_class_df_0], ignore_index=True)
        x = df.loc[:, self.all_features]
        y = df.loc[:, "target_label"]
        x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

        return x_train, x_test, y_train, y_test

    def select_features(self, features):

        x_train = self.x_train.loc[:, features]
        x_test = self.x_test.loc[:, features]

        return x_train, x_test
    
    def evaluate(self, y_pred):

        accuracy = accuracy_score(self.y_test, y_pred)
        recall = recall_score(self.y_test, y_pred, average=None)[1]
        f1 = f1_score(self.y_test, y_pred, average=None)[1]

        return accuracy, recall, f1
    
    def run(self, features, number_of_forests=1):

        # Check whether feature combination already exists in measures dictionary:
        feature_combination = ", ".join(sorted(features))
        if feature_combination in self.measures:
            accuracy, recall, f1 = self.measures[feature_combination]
            current_feature_importances = self.feature_importances
        else:

            # Generate train dataset with selected features: 
            x_train, x_test = self.select_features(features)

            # Perform the random forest classifier: 
            for i in range(number_of_forests):
                clf = RandomForestClassifier(n_estimators=50, criterion= "entropy", random_state=i, max_depth=10)
                clf.fit(x_train, self.y_train)
                y_pred = clf.predict(x_test)
                if i == 0:
                    y_pred_final = y_pred
                else:
                    y_pred_final = np.array([1 if y_pred[i] == 1 or y_pred_final[i] == 1 else 0 for i in range(len(y_pred))])

            # Evaluate and store results:
            accuracy, recall, f1 = self.evaluate(y_pred_final)
            current_feature_importances = clf.feature_importances_
            feature_names = x_train.columns
            current_feature_importances = pd.Series(current_feature_importances, index=feature_names)
            
            #print(type(current_feature_importances))
            #print(current_feature_importances)
            
            self.measures[feature_combination] = (accuracy, recall, f1)
            for feature in current_feature_importances.index:
                self.feature_importances.loc[feature] = current_feature_importances.loc[feature]

        print(f"Feature set: {features}, \nAccuracy: {accuracy}, \nRecall: {recall},\nF1: {f1}\n")
        return f1, current_feature_importances

# %% [markdown]
# **Environment**

# %%
class State():

    def __init__(self, state, action=None):

        if not action == None:
            state = self.bitflip(state, action)

        self.binary = state.float()

    def bitflip(self, state, action):

        adjusted_state = state.binary.clone()

        for index in action:
            if state.binary[index] == 0:
                adjusted_state[index] = 1
            else:
                adjusted_state[index] = 0

        return adjusted_state


class Dacl10kEnvironment():

    def __init__(self, classifier, initial_state=None):

        self.all_features = ["darker", "gradient", "reddish", "metallic", "colorful", "black", "black_thin", "dominating_color", "color_bin_1", 
                             "color_bin_2", "color_bin_3", "color_bin_4", "color_bin_5", "color_bin_6", "color_bin_7", "color_bin_8", "color_bin_9", 
                             "color_entropy", "rough", "dominating_texture", "texture_0", "texture_1", "texture_2", "texture_3", "texture_4", 
                             "texture_5", "texture_6", "texture_7", "texture_8", "texture_9", "rough_entropy", "lengthy", "number_lengthy_objects", 
                             "lengthy_aspect_ratio", "rel_length", "in_shape", "roundness", "hu_moment_1", "hu_moment_2", "hu_moment_3", 
                             "hu_moment_4", "hu_moment_5", "hu_moment_6", "hu_moment_7"]
        
        self.classifier = classifier
        self.features_dict = {i: feature for i, feature in enumerate(self.all_features)}
        self.statesize = len(self.all_features)

        _, current_feature_importances = self.classifier.run(self.all_features)
        self.feature_importances = current_feature_importances

        self.initial_state = State(torch.FloatTensor([i % 2 for i in range(len(self.all_features))])) if initial_state == None else initial_state
        self.state = self.initial_state

        self.table = {}

    def step(self, action):

        next_state = State(self.state, action)
        self.state = next_state

        features_indices = [i for i, value in enumerate(self.state.binary.numpy()) if value == 1]
        features = [self.features_dict[i] for i in features_indices]
        reward, current_feature_importances = self.classifier.run(features)
        self.table[tuple([self.features_dict[i] for i, binary in enumerate(tuple(self.state.binary.detach().numpy())) if binary == 1])] = reward
        for feature in current_feature_importances.index:
            self.feature_importances.loc[feature] = current_feature_importances.loc[feature]
        #print(self.feature_importances)

        return next_state, reward

# %% [markdown]
# **Reinforcement Agent**

# %%
class FeedforwardNet(nn.Module):

    def __init__(self, env, device, hidden_size):

        super(FeedforwardNet, self).__init__()
        
        self.device = device
        self.statesize = env.statesize
        self.hidden_size = hidden_size
        
        self.hidden_layer = nn.Linear(self.statesize, self.hidden_size).to(self.device)
        self.output_layer = nn.Linear(self.hidden_size, self.statesize).to(self.device)
        self.sigmoid = nn.Sigmoid().to(self.device)

    def forward(self, input):

        x = self.hidden_layer(input)
        x = torch.relu(x)
        x = self.output_layer(x)
        x = self.sigmoid(x)

        return x


class ReinforcementAgent():

    def __init__(self, env):

        self.device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
        self.net = FeedforwardNet(env, self.device, 50)

        self.optimizer = torch.optim.Adam(self.net.parameters(),lr=0.01)

        self.exploration_chance = 0.05
        self.statesize = env.statesize

    def step(self, state, feature_importances):

        probabilities = self.net.forward(feature_importances)
        #print(probabilities)
        probability_differences = torch.abs(state.binary - probabilities)
        _, action = torch.topk(probability_differences, random.randint(5, 15))
        action = action.tolist()

        """
        # Exploration adjustments:
        for i, _ in enumerate(action):
            if random.random() < self.exploration_chance:
                action[i] = random.randint(0, self.statesize - 1)
        """

        # Exploration adjustements:
        for i in range(self.statesize):
            if random.random() < self.exploration_chance and i not in action:
                action.append(i)

        # If no feature remaining in action, include highest likelihood features
        if torch.sum(State(state, action).binary).item() < 1:
            action = None

        return action

    def update(self, reward):

        reward = torch.tensor(reward, dtype=torch.float32, requires_grad=True)
        #loss = -torch.log(reward)
        loss = torch.sqrt(1 - reward)
        #print(f"Loss: {loss}")

        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

# %% [markdown]
# **Train the reinforcement agent**

# %%
def plot_rewards(rewards):

    x = list(range(len(rewards)))

    moving_average_rewards = []
    window_size = 50
    for i in range(len(rewards)):
        start_index = max(0, i - window_size + 1)
        window = rewards[start_index:i + 1]
        moving_average_rewards.append(sum(window) / len(window))

    plt.figure(figsize=(10, 5))
    plt.plot(x, rewards, marker="o", linestyle="-", color="b")
    plt.plot(x, moving_average_rewards, linestyle="-", color="r")

    plt.title("Rewards")
    plt.xlabel("Epoch")
    plt.ylabel("Reward")
    plt.grid(True)

    plt.show()

def train_agent(classifier, initial_features=None, epochs=500):

    # Initialize variables:
    env = Dacl10kEnvironment(classifier)
    agent = ReinforcementAgent(env)

    state = env.initial_state
    rewards = []

    # Prepare initial state:
    if not initial_features == None:
        initial_state = State(torch.FloatTensor([feature in initial_features for feature in env.all_features]))
        env = Dacl10kEnvironment(classifier, initial_state=initial_state)

    # Run epochs:
    for i in range(epochs): 

        print(f"Epoch {i}")
        
        action = agent.step(state, torch.FloatTensor(env.feature_importances.loc[:]))
        #print(action)
        next_state, reward = env.step(action)
        agent.update(reward)
        state = next_state

        print(f"Reward: {reward}\n")
        rewards.append(reward)

    # Evaluate results:
    plot_rewards(rewards)
    best_feature_set = max(env.table, key=lambda k: env.table[k])
    print(f"Best Feature set: {best_feature_set}\nReward: {env.table[best_feature_set]}\n")

def random_monkey(classifier, repetitions=500):

    # Initialize variables:
    env = Dacl10kEnvironment(classifier)
    rewards = []

    # Run repetitions:
    for i in range(repetitions):

        print(f"Repitition {i}")
        
        random_binary = random.choices([0, 1], k=44)
        features_indices = [i for i, value in enumerate(random_binary) if value == 1]
        features = [env.features_dict[i] for i in features_indices]
        reward = classifier.run(features)
        rewards.append(reward)
        env.table[tuple([env.features_dict[i] for i, binary in enumerate(random_binary) if binary == 1])] = reward
    
    # Evaluate results:
    plot_rewards(rewards)
    best_feature_set = max(env.table, key=lambda k: env.table[k])
    print(f"Best Feature set: {best_feature_set}\nReward: {env.table[best_feature_set]}\n")

# %% [markdown]
# # Meta-learning classification features: Analysis

# %% [markdown]
# **Analysis Drainage**

# %%
# Create a classifier for drainage:

wetspot_classifier = ClassificationModel("Wetspot")
# Out:
# Feature set: ['darker', 'gradient', 'reddish', 'metallic', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_4', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'rough', 'dominating_texture', 'texture_0', 'texture_1', 'texture_2', 'texture_3', 'texture_4', 'texture_5', 'texture_6', 'texture_7', 'texture_8', 'texture_9', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'rel_length', 'in_shape', 'roundness', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7766203703703703,
# Recall: 0.8026905829596412,
# F1: 0.7876787678767877

# %%
# Run classification on hypothesized features:

hypothesized_features_wetspot = ["darker", "black", "color_bin_1", "color_bin_2", "color_bin_3", "color_bin_4", "color_bin_5", "color_bin_6", 
                                  "color_bin_7", "color_bin_8", "color_bin_9", "color_entropy", "rough", "texture_0", "texture_1", "texture_2", 
                                  "texture_3", "texture_4", "texture_5", "texture_6", "texture_7", "texture_8", "texture_9", "rough_entropy",
                                  "lengthy", "number_lengthy_objects", "lengthy_aspect_ratio", "rel_length", "hu_moment_1", "hu_moment_2",
                                  "hu_moment_3", "hu_moment_4", "hu_moment_5", "hu_moment_6", "hu_moment_7"] ## Insert hypothesized most relevant features here

wetspot_classifier.run(hypothesized_features_wetspot)
# Out:
# Feature set: ['darker', 'black', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_4', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'rough', 'texture_0', 'texture_1', 'texture_2', 'texture_3', 'texture_4', 'texture_5', 'texture_6', 'texture_7', 'texture_8', 'texture_9', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'rel_length', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7488425925925926,
# Recall: 0.7668161434977578,
# F1: 0.7591564927857936
# (0.7591564927857936,
#  darker                    0.091195
#  black                     0.027727
#  color_bin_1               0.023115
#  color_bin_2               0.042258
#  color_bin_3               0.044703
#  color_bin_4               0.018487
#  color_bin_5               0.020441
#  color_bin_6               0.021057
#  color_bin_7               0.021745
#  color_bin_8               0.017558
#  color_bin_9               0.030122
#  color_entropy             0.027075
#  rough                     0.066547
#  texture_0                 0.024865
#  texture_1                 0.029610
#  texture_2                 0.035190
#  texture_3                 0.026157
#  texture_4                 0.029180
#  texture_5                 0.026879
#  texture_6                 0.032318
#  texture_7                 0.039969
#  texture_8                 0.037284
#  texture_9                 0.023913
#  rough_entropy             0.027124
#  lengthy                   0.022924
#  number_lengthy_objects    0.016048
#  lengthy_aspect_ratio      0.027542
#  rel_length                0.038855
#  hu_moment_1               0.020548
#  hu_moment_2               0.022698
#  hu_moment_3               0.021542
#  hu_moment_4               0.019257
#  hu_moment_5               0.008840
#  hu_moment_6               0.011041
#  hu_moment_7               0.006187
#  dtype: float64)

# %%
# Apply meta-learning and compare with random choices:

train_agent(wetspot_classifier, initial_features=hypothesized_features_wetspot, epochs=250)
# Out:
# Feature set: ['darker', 'gradient', 'reddish', 'metallic', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_4', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'rough', 'dominating_texture', 'texture_0', 'texture_1', 'texture_2', 'texture_3', 'texture_4', 'texture_5', 'texture_6', 'texture_7', 'texture_8', 'texture_9', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'rel_length', 'in_shape', 'roundness', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7766203703703703,
# Recall: 0.8026905829596412,
# F1: 0.7876787678767877
#
# Feature set: ['darker', 'gradient', 'reddish', 'metallic', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_4', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'rough', 'dominating_texture', 'texture_0', 'texture_1', 'texture_2', 'texture_3', 'texture_4', 'texture_5', 'texture_6', 'texture_7', 'texture_8', 'texture_9', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'rel_length', 'in_shape', 'roundness', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7766203703703703,
# Recall: 0.8026905829596412,
# F1: 0.7876787678767877
#
# Epoch 0
# Feature set: ['metallic', 'black_thin', 'color_bin_2', 'color_bin_3', 'color_bin_6', 'color_bin_8', 'color_bin_9', 'color_entropy', 'dominating_texture', 'texture_0', 'texture_1', 'texture_2', 'texture_3', 'texture_6', 'texture_7', 'texture_8', 'texture_9', 'lengthy', 'number_lengthy_objects', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7534722222222222,
# Recall: 0.8116591928251121,
# F1: 0.7726787620064034
#
# Reward: 0.7726787620064034
#
# Epoch 1
# Feature set: ['darker', 'reddish', 'black_thin', 'dominating_color', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'texture_0', 'texture_1', 'texture_2', 'texture_3', 'texture_4', 'texture_6', 'texture_7', 'texture_8', 'texture_9', 'rough_entropy', 'lengthy', 'in_shape', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7407407407407407,
# Recall: 0.7802690582959642,
# F1: 0.7565217391304349
#
# Reward: 0.7565217391304349
#
# Epoch 2
# Feature set: ['darker', 'gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'rough', 'texture_0', 'texture_1', 'texture_3', 'texture_4', 'texture_7', 'texture_8', 'texture_9', 'rough_entropy', 'lengthy', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7789351851851852,
# Recall: 0.8116591928251121,
# F1: 0.791256830601093
#
# Reward: 0.791256830601093
#
# Epoch 3
# Feature set: ['darker', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_4', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'rough', 'texture_1', 'rough_entropy', 'rel_length', 'in_shape', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_7'],
# Accuracy: 0.7488425925925926,
# Recall: 0.7847533632286996,
# F1: 0.763358778625954
#
# Reward: 0.763358778625954
#
# Epoch 4
# Feature set: ['darker', 'gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'rough', 'texture_1', 'texture_4', 'texture_8', 'texture_9', 'rough_entropy', 'lengthy', 'lengthy_aspect_ratio', 'rel_length', 'in_shape', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_7'],
# Accuracy: 0.7789351851851852,
# Recall: 0.8094170403587444,
# F1: 0.7907995618838993
#
# Reward: 0.7907995618838993
#
# Epoch 5
# Feature set: ['darker', 'gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'texture_0', 'texture_1', 'texture_2', 'texture_3', 'texture_4', 'texture_9', 'rough_entropy', 'lengthy', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7627314814814815,
# Recall: 0.7937219730941704,
# F1: 0.7754654983570646
#
# Reward: 0.7754654983570646
#
# Epoch 6
# Feature set: ['darker', 'gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'rough', 'texture_1', 'texture_3', 'texture_4', 'texture_8', 'texture_9', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'in_shape', 'roundness', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7696759259259259,
# Recall: 0.7869955156950673,
# F1: 0.7791342952275251
#
# Reward: 0.7791342952275251
#
# Epoch 7
# Feature set: ['darker', 'gradient', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'rough', 'texture_0', 'texture_1', 'texture_4', 'texture_7', 'texture_9', 'rough_entropy', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_3', 'hu_moment_5', 'hu_moment_7'],
# Accuracy: 0.7673611111111112,
# Recall: 0.7937219730941704,
# F1: 0.7788778877887789
#
# Reward: 0.7788778877887789
#
# Epoch 8
# Feature set: ['darker', 'gradient', 'reddish', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_0', 'texture_1', 'texture_3', 'texture_4', 'texture_8', 'texture_9', 'rough_entropy', 'lengthy', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_3', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7731481481481481,
# Recall: 0.8139013452914798,
# F1: 0.7874186550976138
#
# Reward: 0.7874186550976138
#
# Epoch 9
# Feature set: ['darker', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'rough', 'texture_0', 'texture_1', 'texture_3', 'texture_4', 'texture_8', 'texture_9', 'rough_entropy', 'lengthy', 'rel_length', 'in_shape', 'roundness', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.7615740740740741,
# Recall: 0.7937219730941704,
# F1: 0.774617067833698
#
# Reward: 0.774617067833698
#
# Epoch 10
# Feature set: ['darker', 'gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'rough', 'texture_1', 'texture_4', 'texture_9', 'rough_entropy', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_3', 'hu_moment_7'],
# Accuracy: 0.7673611111111112,
# Recall: 0.7802690582959642,
# F1: 0.7759197324414716
#
# Reward: 0.7759197324414716
#
# Epoch 11
# Feature set: ['darker', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'rough', 'texture_0', 'texture_1', 'texture_3', 'texture_7', 'texture_8', 'texture_9', 'rough_entropy', 'lengthy', 'rel_length', 'in_shape', 'roundness', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7627314814814815,
# Recall: 0.7982062780269058,
# F1: 0.776444929116685
#
# Reward: 0.776444929116685
#
# Epoch 12
# Feature set: ['darker', 'gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'rough', 'texture_1', 'texture_3', 'texture_4', 'texture_9', 'rough_entropy', 'lengthy', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7719907407407407,
# Recall: 0.8026905829596412,
# F1: 0.7842278203723988
#
# Reward: 0.7842278203723988
#
# Epoch 13
# Feature set: ['gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'rough', 'texture_0', 'texture_1', 'texture_3', 'texture_4', 'texture_8', 'texture_9', 'rough_entropy', 'lengthy', 'rel_length', 'in_shape', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7615740740740741,
# Recall: 0.7802690582959642,
# F1: 0.7716186252771619
#
# Reward: 0.7716186252771619
#
# Epoch 14
# Feature set: ['darker', 'gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_2', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'rough', 'texture_1', 'texture_4', 'texture_7', 'texture_9', 'rough_entropy', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_5', 'hu_moment_7'],
# Accuracy: 0.7743055555555556,
# Recall: 0.804932735426009,
# F1: 0.7864184008762322
#
# Reward: 0.7864184008762322
#
# Epoch 15
# Feature set: ['darker', 'gradient', 'colorful', 'black_thin', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'rough', 'texture_0', 'texture_1', 'texture_3', 'texture_4', 'texture_8', 'texture_9', 'rough_entropy', 'lengthy', 'rel_length', 'in_shape', 'roundness', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7696759259259259,
# Recall: 0.7937219730941704,
# F1: 0.7805953693495039
#
# Reward: 0.7805953693495039
#
# Epoch 16
# Feature set: ['darker', 'gradient', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'rough', 'texture_1', 'texture_4', 'texture_7', 'texture_9', 'rough_entropy', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_3', 'hu_moment_5', 'hu_moment_7'],
# Accuracy: 0.7627314814814815,
# Recall: 0.7892376681614349,
# F1: 0.7744774477447744
#
# Reward: 0.7744774477447744
#
# Epoch 17
# Feature set: ['darker', 'gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_entropy', 'rough', 'texture_0', 'texture_1', 'texture_3', 'texture_4', 'texture_8', 'texture_9', 'rough_entropy', 'lengthy', 'rel_length', 'in_shape', 'roundness', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7719907407407407,
# Recall: 0.8094170403587444,
# F1: 0.7856365614798694
#
# Reward: 0.7856365614798694
#
# Epoch 18
# Feature set: ['darker', 'gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_8', 'color_bin_9', 'rough', 'dominating_texture', 'texture_1', 'texture_3', 'texture_4', 'texture_9', 'rough_entropy', 'lengthy', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_3', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7615740740740741,
# Recall: 0.7825112107623319,
# F1: 0.7721238938053098
#
# Reward: 0.7721238938053098
#
# Epoch 19
# Feature set: ['gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_0', 'texture_1', 'texture_3', 'texture_4', 'texture_8', 'texture_9', 'rough_entropy', 'lengthy', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_7'],
# Accuracy: 0.7662037037037037,
# Recall: 0.7937219730941704,
# F1: 0.7780219780219779
#
# Reward: 0.7780219780219779
#
# Epoch 20
# Feature set: ['darker', 'gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'rough', 'texture_4', 'texture_7', 'texture_9', 'rough_entropy', 'rel_length', 'in_shape', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7592592592592593,
# Recall: 0.7959641255605381,
# F1: 0.7734204793028321
#
# Reward: 0.7734204793028321
#
# Epoch 21
# Feature set: ['darker', 'gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_entropy', 'rough', 'dominating_texture', 'texture_0', 'texture_1', 'texture_3', 'texture_4', 'texture_8', 'texture_9', 'lengthy', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7743055555555556,
# Recall: 0.8004484304932735,
# F1: 0.7854785478547854
#
# Reward: 0.7854785478547854
#
# Epoch 22
# Feature set: ['darker', 'gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'rough', 'texture_1', 'texture_4', 'texture_9', 'rough_entropy', 'lengthy', 'rel_length', 'in_shape', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_7'],
# Accuracy: 0.7592592592592593,
# Recall: 0.7892376681614349,
# F1: 0.7719298245614035
#
# Reward: 0.7719298245614035
#
# Epoch 23
# Feature set: ['darker', 'gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'rough', 'texture_0', 'texture_1', 'texture_3', 'texture_4', 'texture_9', 'rough_entropy', 'lengthy', 'rel_length', 'in_shape', 'roundness', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7604166666666666,
# Recall: 0.8026905829596412,
# F1: 0.7757313109425785
#
# Reward: 0.7757313109425785
#
# Epoch 24
# Feature set: ['darker', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_entropy', 'rough', 'dominating_texture', 'texture_1', 'texture_4', 'texture_7', 'texture_8', 'texture_9', 'rough_entropy', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_3', 'hu_moment_7'],
# Accuracy: 0.7627314814814815,
# Recall: 0.7982062780269058,
# F1: 0.776444929116685
#
# Reward: 0.776444929116685
#
# Epoch 25
# Feature set: ['gradient', 'reddish', 'metallic', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_entropy', 'rough', 'texture_1', 'texture_3', 'texture_4', 'texture_8', 'texture_9', 'lengthy', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_7'],
# Accuracy: 0.7743055555555556,
# Recall: 0.8004484304932735,
# F1: 0.7854785478547854
#
# Reward: 0.7854785478547854
#
# Epoch 26
# Feature set: ['darker', 'gradient', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'rough', 'texture_0', 'texture_3', 'texture_4', 'texture_9', 'rough_entropy', 'lengthy', 'rel_length', 'in_shape', 'roundness', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7592592592592593,
# Recall: 0.7959641255605381,
# F1: 0.7734204793028321
#
# Reward: 0.7734204793028321
#
# Epoch 27
# Feature set: ['darker', 'gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_entropy', 'rough', 'dominating_texture', 'texture_1', 'texture_3', 'texture_4', 'texture_7', 'texture_8', 'texture_9', 'rough_entropy', 'lengthy', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_3', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7731481481481481,
# Recall: 0.8026905829596412,
# F1: 0.7850877192982456
#
# Reward: 0.7850877192982456
#
# Epoch 28
# Feature set: ['darker', 'gradient', 'reddish', 'metallic', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'rough', 'texture_0', 'texture_3', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'rel_length', 'in_shape', 'roundness', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7673611111111112,
# Recall: 0.804932735426009,
# F1: 0.7812840043525572
#
# Reward: 0.7812840043525572
#
# Epoch 29
# Feature set: ['darker', 'gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_entropy', 'rough', 'texture_0', 'texture_1', 'texture_3', 'texture_4', 'texture_9', 'rough_entropy', 'lengthy', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_3', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7581018518518519,
# Recall: 0.7847533632286996,
# F1: 0.77007700770077
#
# Reward: 0.77007700770077
#
# Epoch 30
# Feature set: ['gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'rough', 'texture_0', 'texture_1', 'texture_3', 'texture_4', 'texture_5', 'texture_7', 'texture_8', 'texture_9', 'rough_entropy', 'lengthy', 'lengthy_aspect_ratio', 'rel_length', 'in_shape', 'roundness', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7696759259259259,
# Recall: 0.7959641255605381,
# F1: 0.781078107810781
#
# Reward: 0.781078107810781
#
# Epoch 31
# Feature set: ['darker', 'gradient', 'reddish', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_entropy', 'rough', 'texture_1', 'texture_3', 'texture_4', 'texture_9', 'rough_entropy', 'lengthy', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_3', 'hu_moment_7'],
# Accuracy: 0.7743055555555556,
# Recall: 0.7914798206278026,
# F1: 0.7835738068812429
#
# Reward: 0.7835738068812429
#
# Epoch 32
# Feature set: ['darker', 'gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_entropy', 'rough', 'texture_0', 'texture_1', 'texture_3', 'texture_4', 'texture_8', 'texture_9', 'rough_entropy', 'lengthy', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7615740740740741,
# Recall: 0.8004484304932735,
# F1: 0.7760869565217392
#
# Reward: 0.7760869565217392
#
# Epoch 33
# Feature set: ['darker', 'gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_2', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'rough', 'texture_1', 'texture_4', 'texture_7', 'texture_9', 'rough_entropy', 'rel_length', 'in_shape', 'roundness', 'hu_moment_1', 'hu_moment_5', 'hu_moment_7'],
# Accuracy: 0.7638888888888888,
# Recall: 0.7914798206278026,
# F1: 0.7758241758241757
#
# Reward: 0.7758241758241757
#
# Epoch 34
# Feature set: ['darker', 'gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'rough', 'texture_1', 'texture_4', 'texture_9', 'rough_entropy', 'lengthy', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7546296296296297,
# Recall: 0.7892376681614349,
# F1: 0.7685589519650656
#
# Reward: 0.7685589519650656
#
# Epoch 35
# Feature set: ['darker', 'gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_entropy', 'rough', 'texture_0', 'texture_1', 'texture_3', 'texture_4', 'texture_8', 'texture_9', 'rough_entropy', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_7'],
# Accuracy: 0.7592592592592593,
# Recall: 0.7982062780269058,
# F1: 0.7739130434782608
#
# Reward: 0.7739130434782608
#
# Epoch 36
# Feature set: ['darker', 'gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_5', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'rough', 'texture_1', 'texture_4', 'texture_6', 'texture_9', 'rough_entropy', 'lengthy', 'rel_length', 'in_shape', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7650462962962963,
# Recall: 0.8004484304932735,
# F1: 0.7786259541984734
#
# Reward: 0.7786259541984734
#
# Epoch 37
# Feature set: ['darker', 'gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'rough', 'texture_0', 'texture_1', 'texture_3', 'texture_4', 'texture_9', 'rough_entropy', 'lengthy', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_3', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7673611111111112,
# Recall: 0.804932735426009,
# F1: 0.7812840043525572
#
# Reward: 0.7812840043525572
#
# Epoch 38
# Feature set: ['darker', 'gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_entropy', 'rough', 'texture_4', 'texture_6', 'texture_7', 'texture_8', 'texture_9', 'rough_entropy', 'lengthy_aspect_ratio', 'rel_length', 'in_shape', 'roundness', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_7'],
# Accuracy: 0.7638888888888888,
# Recall: 0.7892376681614349,
# F1: 0.7753303964757708
#
# Reward: 0.7753303964757708
#
# Epoch 39
# Feature set: ['darker', 'gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_entropy', 'rough', 'texture_1', 'texture_3', 'texture_4', 'texture_8', 'texture_9', 'rough_entropy', 'lengthy', 'rel_length', 'in_shape', 'roundness', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_5'],
# Accuracy: 0.7685185185185185,
# Recall: 0.804932735426009,
# F1: 0.7821350762527232
#
# Reward: 0.7821350762527232
#
# Epoch 40
# Feature set: ['darker', 'gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_0', 'texture_1', 'texture_3', 'texture_4', 'texture_8', 'texture_9', 'rough_entropy', 'lengthy', 'lengthy_aspect_ratio', 'rel_length', 'in_shape', 'hu_moment_2', 'hu_moment_3', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7731481481481481,
# Recall: 0.8004484304932735,
# F1: 0.7846153846153846
#
# Reward: 0.7846153846153846
#
# Epoch 41
# Feature set: ['darker', 'gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'rough', 'texture_1', 'texture_3', 'texture_4', 'texture_9', 'rough_entropy', 'lengthy', 'rel_length', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_7'],
# Accuracy: 0.7581018518518519,
# Recall: 0.7937219730941704,
# F1: 0.7720828789531079
#
# Reward: 0.7720828789531079
#
# Epoch 42
# Feature set: ['darker', 'gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_5', 'color_bin_6', 'color_bin_9', 'color_entropy', 'dominating_texture', 'texture_0', 'texture_1', 'texture_2', 'texture_4', 'texture_8', 'texture_9', 'lengthy', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7627314814814815,
# Recall: 0.7982062780269058,
# F1: 0.776444929116685
#
# Reward: 0.776444929116685
#
# Epoch 43
# Feature set: ['darker', 'gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'rough', 'texture_0', 'texture_1', 'texture_3', 'texture_4', 'rough_entropy', 'lengthy', 'lengthy_aspect_ratio', 'rel_length', 'in_shape', 'roundness', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7685185185185185,
# Recall: 0.8139013452914798,
# F1: 0.7840172786177105
#
# Reward: 0.7840172786177105
#
# Epoch 44
# Feature set: ['darker', 'gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'rough', 'texture_1', 'texture_2', 'texture_3', 'texture_4', 'texture_8', 'texture_9', 'rough_entropy', 'lengthy', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_3', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7719907407407407,
# Recall: 0.804932735426009,
# F1: 0.7846994535519125
#
# Reward: 0.7846994535519125
#
# Epoch 45
# Feature set: ['darker', 'gradient', 'metallic', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_entropy', 'texture_0', 'texture_3', 'texture_4', 'texture_8', 'texture_9', 'rough_entropy', 'lengthy', 'rel_length', 'in_shape', 'roundness', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7685185185185185,
# Recall: 0.7914798206278026,
# F1: 0.7792494481236202
#
# Reward: 0.7792494481236202
#
# Epoch 46
# Feature set: ['darker', 'gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'rough', 'texture_1', 'texture_3', 'texture_9', 'rough_entropy', 'lengthy', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_3', 'hu_moment_4', 'hu_moment_7'],
# Accuracy: 0.7592592592592593,
# Recall: 0.8026905829596412,
# F1: 0.7748917748917749
#
# Reward: 0.7748917748917749
#
# Epoch 47
# Feature set: ['darker', 'gradient', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_0', 'texture_1', 'texture_3', 'texture_4', 'texture_8', 'texture_9', 'rough_entropy', 'lengthy', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7650462962962963,
# Recall: 0.7982062780269058,
# F1: 0.7781420765027321
#
# Reward: 0.7781420765027321
#
# Epoch 48
# Feature set: ['darker', 'gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'rough', 'texture_0', 'texture_1', 'texture_3', 'texture_4', 'texture_9', 'rough_entropy', 'lengthy', 'rel_length', 'in_shape', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7592592592592593,
# Recall: 0.7959641255605381,
# F1: 0.7734204793028321
#
# Reward: 0.7734204793028321
#
# Epoch 49
# Feature set: ['darker', 'gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'rough', 'texture_1', 'texture_4', 'texture_5', 'texture_8', 'texture_9', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'in_shape', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_7'],
# Accuracy: 0.7650462962962963,
# Recall: 0.7937219730941704,
# F1: 0.7771679473106478
#
# Reward: 0.7771679473106478
#
# Epoch 50
# Feature set: ['darker', 'gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'rough', 'texture_0', 'texture_1', 'texture_3', 'texture_4', 'texture_7', 'texture_9', 'rough_entropy', 'rel_length', 'in_shape', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7673611111111112,
# Recall: 0.7982062780269058,
# F1: 0.7798466593647316
#
# Reward: 0.7798466593647316
#
# Epoch 51
# Feature set: ['darker', 'gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'rough', 'texture_1', 'texture_4', 'texture_8', 'texture_9', 'rough_entropy', 'lengthy', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_5', 'hu_moment_7'],
# Accuracy: 0.7650462962962963,
# Recall: 0.7802690582959642,
# F1: 0.7741935483870968
#
# Reward: 0.7741935483870968
#
# Epoch 52
# Feature set: ['darker', 'gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_3', 'color_bin_4', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_1', 'texture_3', 'texture_4', 'texture_8', 'texture_9', 'rough_entropy', 'lengthy', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7627314814814815,
# Recall: 0.8004484304932735,
# F1: 0.7769314472252448
#
# Reward: 0.7769314472252448
#
# Epoch 53
# Feature set: ['darker', 'gradient', 'colorful', 'black_thin', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'rough', 'texture_0', 'texture_1', 'texture_4', 'texture_9', 'rough_entropy', 'rel_length', 'in_shape', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7673611111111112,
# Recall: 0.7982062780269058,
# F1: 0.7798466593647316
#
# Reward: 0.7798466593647316
#
# Epoch 54
# Feature set: ['darker', 'gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_3', 'texture_4', 'texture_8', 'texture_9', 'rough_entropy', 'lengthy', 'lengthy_aspect_ratio', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_7'],
# Accuracy: 0.7627314814814815,
# Recall: 0.7825112107623319,
# F1: 0.7729789590254706
#
# Reward: 0.7729789590254706
#
# Epoch 55
# Feature set: ['darker', 'gradient', 'colorful', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_4', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'rough', 'texture_0', 'texture_1', 'texture_4', 'texture_7', 'texture_9', 'rough_entropy', 'rel_length', 'in_shape', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7650462962962963,
# Recall: 0.8116591928251121,
# F1: 0.7810140237324703
#
# Reward: 0.7810140237324703
#
# Epoch 56
# Feature set: ['darker', 'gradient', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_entropy', 'rough', 'texture_0', 'texture_1', 'texture_3', 'texture_4', 'texture_8', 'texture_9', 'rough_entropy', 'lengthy', 'lengthy_aspect_ratio', 'rel_length', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7696759259259259,
# Recall: 0.7869955156950673,
# F1: 0.7791342952275251
#
# Reward: 0.7791342952275251
#
# Epoch 57
# Feature set: ['darker', 'gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'rough', 'texture_1', 'texture_3', 'texture_4', 'texture_8', 'texture_9', 'rough_entropy', 'lengthy', 'rel_length', 'in_shape', 'roundness', 'hu_moment_1', 'hu_moment_2', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7650462962962963,
# Recall: 0.7847533632286996,
# F1: 0.7751937984496124
#
# Reward: 0.7751937984496124
#
# Epoch 58
# Feature set: ['darker', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_7', 'color_entropy', 'rough', 'texture_0', 'texture_1', 'texture_3', 'texture_4', 'texture_7', 'texture_8', 'texture_9', 'rough_entropy', 'lengthy', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_3', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7523148148148148,
# Recall: 0.7802690582959642,
# F1: 0.7648351648351649
#
# Reward: 0.7648351648351649
#
# Epoch 59
# Feature set: ['darker', 'gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'rough', 'texture_1', 'texture_3', 'texture_4', 'texture_9', 'rough_entropy', 'lengthy', 'rel_length', 'in_shape', 'roundness', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_7'],
# Accuracy: 0.7627314814814815,
# Recall: 0.8004484304932735,
# F1: 0.7769314472252448
#
# Reward: 0.7769314472252448
#
# Epoch 60
# Feature set: ['darker', 'gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_entropy', 'rough', 'texture_0', 'texture_1', 'texture_4', 'texture_7', 'texture_8', 'texture_9', 'rough_entropy', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_3', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7615740740740741,
# Recall: 0.7982062780269058,
# F1: 0.775599128540305
#
# Reward: 0.775599128540305
#
# Epoch 61
# Feature set: ['darker', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'rough', 'texture_1', 'texture_3', 'texture_4', 'texture_6', 'texture_9', 'rough_entropy', 'lengthy', 'rel_length', 'in_shape', 'roundness', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_5', 'hu_moment_7'],
# Accuracy: 0.7511574074074074,
# Recall: 0.7802690582959642,
# F1: 0.7639956092206367
#
# Reward: 0.7639956092206367
#
# Epoch 62
# Feature set: ['darker', 'gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_entropy', 'rough', 'texture_0', 'texture_1', 'texture_4', 'texture_8', 'texture_9', 'rough_entropy', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_3', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7754629629629629,
# Recall: 0.804932735426009,
# F1: 0.7872807017543859
#
# Reward: 0.7872807017543859
#
# Epoch 63
# Feature set: ['darker', 'gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'rough', 'texture_1', 'texture_3', 'texture_4', 'texture_9', 'rough_entropy', 'lengthy', 'rel_length', 'in_shape', 'roundness', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7650462962962963,
# Recall: 0.7869955156950673,
# F1: 0.7756906077348067
#
# Reward: 0.7756906077348067
#
# Epoch 64
# Feature set: ['darker', 'gradient', 'metallic', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_entropy', 'rough', 'texture_0', 'texture_1', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'lengthy_aspect_ratio', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_3', 'hu_moment_7'],
# Accuracy: 0.7592592592592593,
# Recall: 0.7937219730941704,
# F1: 0.7729257641921398
#
# Reward: 0.7729257641921398
#
# Epoch 65
# Feature set: ['darker', 'gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_entropy', 'rough', 'texture_0', 'texture_1', 'texture_3', 'texture_4', 'texture_8', 'texture_9', 'rough_entropy', 'lengthy', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7615740740740741,
# Recall: 0.8004484304932735,
# F1: 0.7760869565217392
#
# Reward: 0.7760869565217392
#
# Epoch 66
# Feature set: ['darker', 'gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'rough', 'texture_1', 'texture_4', 'texture_9', 'rough_entropy', 'lengthy', 'rel_length', 'in_shape', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_6'],
# Accuracy: 0.7685185185185185,
# Recall: 0.7869955156950673,
# F1: 0.7782705099778271
#
# Reward: 0.7782705099778271
#
# Epoch 67
# Feature set: ['darker', 'gradient', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'rough', 'texture_0', 'texture_1', 'texture_2', 'texture_3', 'texture_4', 'texture_8', 'texture_9', 'rough_entropy', 'lengthy', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7685185185185185,
# Recall: 0.7982062780269058,
# F1: 0.780701754385965
#
# Reward: 0.780701754385965
#
# Epoch 68
# Feature set: ['darker', 'gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_entropy', 'rough', 'texture_1', 'texture_4', 'texture_9', 'rough_entropy', 'rel_length', 'in_shape', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_7'],
# Accuracy: 0.7696759259259259,
# Recall: 0.8004484304932735,
# F1: 0.7820372398685652
#
# Reward: 0.7820372398685652
#
# Epoch 69
# Feature set: ['darker', 'gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_entropy', 'rough', 'texture_0', 'texture_1', 'texture_3', 'texture_4', 'texture_8', 'texture_9', 'rough_entropy', 'lengthy', 'rel_length', 'in_shape', 'roundness', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7592592592592593,
# Recall: 0.7869955156950673,
# F1: 0.7714285714285715
#
# Reward: 0.7714285714285715
#
# Epoch 70
# Feature set: ['darker', 'gradient', 'metallic', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'rough', 'texture_1', 'texture_3', 'texture_4', 'texture_9', 'rough_entropy', 'lengthy', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_3', 'hu_moment_4', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7546296296296297,
# Recall: 0.7825112107623319,
# F1: 0.7670329670329671
#
# Reward: 0.7670329670329671
#
# Epoch 71
# Feature set: ['gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_entropy', 'rough', 'dominating_texture', 'texture_0', 'texture_1', 'texture_4', 'texture_7', 'texture_8', 'texture_9', 'rough_entropy', 'rel_length', 'roundness', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_7'],
# Accuracy: 0.7581018518518519,
# Recall: 0.7982062780269058,
# F1: 0.7730727470141151
#
# Reward: 0.7730727470141151
#
# Epoch 72
# Feature set: ['darker', 'reddish', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'rough', 'texture_0', 'texture_1', 'texture_3', 'texture_4', 'texture_5', 'texture_9', 'rough_entropy', 'lengthy', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_3', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.75,
# Recall: 0.7780269058295964,
# F1: 0.7626373626373626
#
# Reward: 0.7626373626373626
#
# Epoch 73
# Feature set: ['darker', 'gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_entropy', 'rough', 'texture_0', 'texture_1', 'texture_3', 'texture_4', 'texture_8', 'rough_entropy', 'lengthy', 'rel_length', 'in_shape', 'roundness', 'hu_moment_1', 'hu_moment_2', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7638888888888888,
# Recall: 0.7959641255605381,
# F1: 0.7768052516411379
#
# Reward: 0.7768052516411379
#
# Epoch 74
# Feature set: ['darker', 'gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'rough', 'texture_0', 'texture_1', 'texture_3', 'texture_4', 'texture_9', 'lengthy', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_3', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7696759259259259,
# Recall: 0.8004484304932735,
# F1: 0.7820372398685652
#
# Reward: 0.7820372398685652
#
# Epoch 75
# Feature set: ['darker', 'gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_entropy', 'rough', 'texture_0', 'texture_1', 'texture_3', 'texture_4', 'texture_7', 'texture_8', 'texture_9', 'rough_entropy', 'lengthy', 'rel_length', 'roundness', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7673611111111112,
# Recall: 0.7892376681614349,
# F1: 0.7779005524861877
#
# Reward: 0.7779005524861877
#
# Epoch 76
# Feature set: ['darker', 'gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'rough', 'texture_1', 'texture_3', 'texture_4', 'texture_8', 'texture_9', 'rough_entropy', 'lengthy', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7604166666666666,
# Recall: 0.7959641255605381,
# F1: 0.7742639040348964
#
# Reward: 0.7742639040348964
#
# Epoch 77
# Feature set: ['darker', 'gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_entropy', 'rough', 'texture_0', 'texture_1', 'texture_4', 'texture_9', 'rough_entropy', 'rel_length', 'in_shape', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_7'],
# Accuracy: 0.7662037037037037,
# Recall: 0.7914798206278026,
# F1: 0.7775330396475771
#
# Reward: 0.7775330396475771
#
# Epoch 78
# Feature set: ['darker', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'rough', 'dominating_texture', 'texture_1', 'texture_3', 'texture_4', 'texture_8', 'texture_9', 'rough_entropy', 'lengthy', 'number_lengthy_objects', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_2', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7488425925925926,
# Recall: 0.7713004484304933,
# F1: 0.7602209944751381
#
# Reward: 0.7602209944751381
#
# Epoch 79
# Feature set: ['darker', 'gradient', 'reddish', 'metallic', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_entropy', 'rough', 'texture_0', 'texture_1', 'texture_3', 'texture_4', 'rough_entropy', 'lengthy', 'rel_length', 'in_shape', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7604166666666666,
# Recall: 0.7959641255605381,
# F1: 0.7742639040348964
#
# Reward: 0.7742639040348964
#
# Epoch 80
# Feature set: ['darker', 'gradient', 'colorful', 'black', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'rough', 'texture_1', 'texture_4', 'texture_8', 'texture_9', 'rough_entropy', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_7'],
# Accuracy: 0.7673611111111112,
# Recall: 0.7937219730941704,
# F1: 0.7788778877887789
#
# Reward: 0.7788778877887789
#
# Epoch 81
# Feature set: ['darker', 'gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_entropy', 'rough', 'texture_0', 'texture_1', 'texture_3', 'texture_4', 'texture_8', 'texture_9', 'rough_entropy', 'lengthy', 'rel_length', 'in_shape', 'roundness', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7719907407407407,
# Recall: 0.8094170403587444,
# F1: 0.7856365614798694
#
# Reward: 0.7856365614798694
#
# Epoch 82
# Feature set: ['darker', 'gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'texture_1', 'texture_4', 'texture_9', 'rough_entropy', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_3', 'hu_moment_7'],
# Accuracy: 0.7534722222222222,
# Recall: 0.773542600896861,
# F1: 0.7641196013289037
#
# Reward: 0.7641196013289037
#
# Epoch 83
# Feature set: ['gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_0', 'texture_1', 'texture_3', 'texture_4', 'texture_8', 'texture_9', 'rough_entropy', 'lengthy', 'rel_length', 'in_shape', 'roundness', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7685185185185185,
# Recall: 0.8094170403587444,
# F1: 0.7830802603036876
#
# Reward: 0.7830802603036876
#
# Epoch 84
# Feature set: ['darker', 'gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'rough', 'texture_1', 'texture_4', 'texture_9', 'rough_entropy', 'lengthy', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_3', 'hu_moment_7'],
# Accuracy: 0.7766203703703703,
# Recall: 0.8004484304932735,
# F1: 0.7872105843439912
#
# Reward: 0.7872105843439912
#
# Epoch 85
# Feature set: ['darker', 'gradient', 'metallic', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_0', 'texture_1', 'texture_3', 'texture_4', 'texture_7', 'texture_8', 'texture_9', 'rough_entropy', 'rel_length', 'in_shape', 'roundness', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_5', 'hu_moment_6'],
# Accuracy: 0.7673611111111112,
# Recall: 0.7847533632286996,
# F1: 0.7769145394006659
#
# Reward: 0.7769145394006659
#
# Epoch 86
# Feature set: ['darker', 'gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'rough', 'texture_0', 'texture_1', 'texture_4', 'texture_9', 'rough_entropy', 'lengthy', 'rel_length', 'in_shape', 'roundness', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7743055555555556,
# Recall: 0.7982062780269058,
# F1: 0.7850055126791621
#
# Reward: 0.7850055126791621
#
# Epoch 87
# Feature set: ['darker', 'gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_entropy', 'rough', 'texture_1', 'texture_3', 'texture_4', 'texture_7', 'texture_8', 'texture_9', 'rough_entropy', 'number_lengthy_objects', 'lengthy_aspect_ratio', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_3', 'hu_moment_5', 'hu_moment_7'],
# Accuracy: 0.7673611111111112,
# Recall: 0.8004484304932735,
# F1: 0.780327868852459
#
# Reward: 0.780327868852459
#
# Epoch 88
# Feature set: ['darker', 'gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'rough', 'texture_0', 'texture_1', 'texture_4', 'texture_5', 'texture_9', 'rough_entropy', 'lengthy', 'rel_length', 'in_shape', 'roundness', 'hu_moment_1', 'hu_moment_2', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7650462962962963,
# Recall: 0.8094170403587444,
# F1: 0.7805405405405406
#
# Reward: 0.7805405405405406
#
# Epoch 89
# Feature set: ['darker', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_entropy', 'rough', 'texture_1', 'texture_2', 'texture_3', 'texture_7', 'texture_8', 'rough_entropy', 'number_lengthy_objects', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_3', 'hu_moment_5', 'hu_moment_7'],
# Accuracy: 0.7638888888888888,
# Recall: 0.7937219730941704,
# F1: 0.7763157894736843
#
# Reward: 0.7763157894736843
#
# Epoch 90
# Feature set: ['darker', 'gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_entropy', 'rough', 'texture_1', 'texture_3', 'texture_4', 'texture_8', 'texture_9', 'rough_entropy', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_5', 'hu_moment_7'],
# Accuracy: 0.7685185185185185,
# Recall: 0.7914798206278026,
# F1: 0.7792494481236202
#
# Reward: 0.7792494481236202
#
# Epoch 91
# ...
# F1: 0.7744774477447744
#
# Reward: 0.7744774477447744
#
# Epoch 219
# Feature set: ['darker', 'gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_entropy', 'rough', 'texture_1', 'texture_3', 'texture_9', 'rough_entropy', 'lengthy', 'rel_length', 'in_shape', 'roundness', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_7'],
# Accuracy: 0.7627314814814815,
# Recall: 0.7892376681614349,
# F1: 0.7744774477447744
#
# Reward: 0.7744774477447744
#
# Epoch 220
# Feature set: ['darker', 'gradient', 'colorful', 'black_thin', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'color_entropy', 'texture_0', 'texture_1', 'texture_3', 'texture_4', 'texture_8', 'texture_9', 'rough_entropy', 'lengthy', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_4', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7581018518518519,
# Recall: 0.8004484304932735,
# F1: 0.7735644637053087
#
# Reward: 0.7735644637053087
#
# Epoch 221
# Feature set: ['darker', 'gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'rough', 'texture_0', 'texture_1', 'texture_3', 'texture_4', 'texture_8', 'texture_9', 'rough_entropy', 'in_shape', 'roundness', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_7'],
# Accuracy: 0.7569444444444444,
# Recall: 0.7959641255605381,
# F1: 0.7717391304347826
#
# Reward: 0.7717391304347826
#
# Epoch 222
# Feature set: ['darker', 'gradient', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'dominating_texture', 'texture_1', 'texture_4', 'texture_7', 'texture_9', 'rough_entropy', 'lengthy', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_3', 'hu_moment_5', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7581018518518519,
# Recall: 0.7982062780269058,
# F1: 0.7730727470141151
#
# Reward: 0.7730727470141151
#
# Epoch 223
# Feature set: ['darker', 'gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_0', 'texture_1', 'texture_3', 'texture_4', 'texture_8', 'texture_9', 'rough_entropy', 'lengthy', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7604166666666666,
# Recall: 0.7869955156950673,
# F1: 0.7722772277227723
#
# Reward: 0.7722772277227723
#
# Epoch 224
# Feature set: ['darker', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'rough', 'texture_1', 'texture_4', 'texture_7', 'texture_9', 'rough_entropy', 'rel_length', 'in_shape', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_5', 'hu_moment_7'],
# Accuracy: 0.7557870370370371,
# Recall: 0.7847533632286996,
# F1: 0.7683863885839736
#
# Reward: 0.7683863885839736
#
# Epoch 225
# Feature set: ['darker', 'gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'rough', 'texture_0', 'texture_1', 'texture_3', 'texture_4', 'texture_8', 'texture_9', 'rough_entropy', 'lengthy', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7835648148148148,
# Recall: 0.8094170403587444,
# F1: 0.7942794279427944
#
# Reward: 0.7942794279427944
#
# Epoch 226
# Feature set: ['darker', 'gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_5', 'color_bin_7', 'color_bin_8', 'color_entropy', 'rough', 'texture_1', 'texture_4', 'texture_9', 'rough_entropy', 'lengthy', 'rel_length', 'in_shape', 'roundness', 'hu_moment_3', 'hu_moment_5', 'hu_moment_7'],
# Accuracy: 0.7627314814814815,
# Recall: 0.7914798206278026,
# F1: 0.7749725576289792
#
# Reward: 0.7749725576289792
#
# Epoch 227
# Feature set: ['darker', 'gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_0', 'texture_1', 'texture_3', 'texture_4', 'texture_8', 'texture_9', 'rough_entropy', 'lengthy', 'rel_length', 'in_shape', 'roundness', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7662037037037037,
# Recall: 0.8004484304932735,
# F1: 0.7794759825327511
#
# Reward: 0.7794759825327511
#
# Epoch 228
# Feature set: ['reddish', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_5', 'color_bin_6', 'color_bin_8', 'rough', 'texture_1', 'texture_4', 'texture_7', 'rough_entropy', 'hu_moment_1', 'hu_moment_5', 'hu_moment_7'],
# Accuracy: 0.7268518518518519,
# Recall: 0.7847533632286996,
# F1: 0.747863247863248
#
# Reward: 0.747863247863248
#
# Epoch 229
# Feature set: ['darker', 'reddish', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'rough', 'texture_1', 'texture_4', 'texture_6', 'texture_7', 'texture_9', 'rough_entropy', 'in_shape', 'hu_moment_1', 'hu_moment_3', 'hu_moment_5', 'hu_moment_7'],
# Accuracy: 0.75,
# Recall: 0.7937219730941704,
# F1: 0.7662337662337662
#
# Reward: 0.7662337662337662
#
# Epoch 230
# Feature set: ['darker', 'gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'texture_1', 'texture_3', 'texture_4', 'texture_8', 'texture_9', 'rough_entropy', 'lengthy', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7615740740740741,
# Recall: 0.7959641255605381,
# F1: 0.7751091703056768
#
# Reward: 0.7751091703056768
#
# Epoch 231
# Feature set: ['darker', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'rough', 'dominating_texture', 'texture_0', 'texture_1', 'texture_4', 'texture_7', 'texture_9', 'rough_entropy', 'rel_length', 'in_shape', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_5', 'hu_moment_7'],
# Accuracy: 0.7372685185185185,
# Recall: 0.773542600896861,
# F1: 0.752453653217012
#
# Reward: 0.752453653217012
#
# Epoch 232
# Feature set: ['darker', 'gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_9', 'rough', 'texture_0', 'texture_1', 'texture_3', 'texture_4', 'texture_8', 'texture_9', 'rough_entropy', 'lengthy', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7673611111111112,
# Recall: 0.7937219730941704,
# F1: 0.7788778877887789
#
# Reward: 0.7788778877887789
#
# Epoch 233
# Feature set: ['darker', 'gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_entropy', 'rough', 'texture_1', 'texture_3', 'texture_4', 'texture_9', 'rough_entropy', 'lengthy', 'rel_length', 'in_shape', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7523148148148148,
# Recall: 0.7757847533632287,
# F1: 0.7637969094922736
#
# Reward: 0.7637969094922736
#
# Epoch 234
# Feature set: ['darker', 'gradient', 'reddish', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'rough', 'texture_0', 'texture_1', 'texture_3', 'texture_4', 'texture_8', 'texture_9', 'rough_entropy', 'lengthy', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7708333333333334,
# Recall: 0.7869955156950673,
# F1: 0.78
#
# Reward: 0.78
#
# Epoch 235
# Feature set: ['darker', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_entropy', 'rough', 'texture_1', 'texture_2', 'texture_4', 'texture_7', 'texture_9', 'rough_entropy', 'rel_length', 'in_shape', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_5', 'hu_moment_7'],
# Accuracy: 0.7592592592592593,
# Recall: 0.7892376681614349,
# F1: 0.7719298245614035
#
# Reward: 0.7719298245614035
#
# Epoch 236
# Feature set: ['darker', 'gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_0', 'texture_1', 'texture_3', 'texture_4', 'texture_8', 'texture_9', 'rough_entropy', 'lengthy', 'lengthy_aspect_ratio', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7858796296296297,
# Recall: 0.8161434977578476,
# F1: 0.7973713033953997
#
# Reward: 0.7973713033953997
#
# Epoch 237
# Feature set: ['darker', 'gradient', 'colorful', 'black', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'rough', 'texture_1', 'texture_4', 'texture_7', 'rough_entropy', 'in_shape', 'roundness', 'hu_moment_1', 'hu_moment_7'],
# Accuracy: 0.7534722222222222,
# Recall: 0.7802690582959642,
# F1: 0.7656765676567657
#
# Reward: 0.7656765676567657
#
# Epoch 238
# Feature set: ['darker', 'gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'rough', 'texture_1', 'texture_2', 'texture_4', 'texture_9', 'rough_entropy', 'lengthy', 'rel_length', 'in_shape', 'roundness', 'hu_moment_1', 'hu_moment_3', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7731481481481481,
# Recall: 0.804932735426009,
# F1: 0.7855579868708972
#
# Reward: 0.7855579868708972
#
# Epoch 239
# Feature set: ['darker', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_4', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'rough', 'texture_0', 'texture_1', 'texture_3', 'texture_4', 'texture_7', 'texture_8', 'texture_9', 'rough_entropy', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_5', 'hu_moment_7'],
# Accuracy: 0.7592592592592593,
# Recall: 0.7869955156950673,
# F1: 0.7714285714285715
#
# Reward: 0.7714285714285715
#
# Epoch 240
# Feature set: ['darker', 'gradient', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'rough', 'texture_1', 'texture_4', 'texture_9', 'rough_entropy', 'lengthy', 'rel_length', 'in_shape', 'roundness', 'hu_moment_3', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7511574074074074,
# Recall: 0.7825112107623319,
# F1: 0.7645125958378971
#
# Reward: 0.7645125958378971
#
# Epoch 241
# Feature set: ['darker', 'gradient', 'colorful', 'black_thin', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_bin_9', 'color_entropy', 'rough', 'texture_0', 'texture_1', 'texture_3', 'texture_4', 'texture_8', 'texture_9', 'rough_entropy', 'lengthy', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_7'],
# Accuracy: 0.7719907407407407,
# Recall: 0.8183856502242153,
# F1: 0.7874865156418555
#
# Reward: 0.7874865156418555
#
# Epoch 242
# Feature set: ['darker', 'gradient', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'rough', 'texture_0', 'texture_1', 'texture_2', 'texture_3', 'texture_4', 'texture_8', 'texture_9', 'rough_entropy', 'lengthy', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7604166666666666,
# Recall: 0.8026905829596412,
# F1: 0.7757313109425785
#
# Reward: 0.7757313109425785
#
# Epoch 243
# Feature set: ['darker', 'gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_0', 'texture_1', 'texture_3', 'texture_4', 'texture_8', 'texture_9', 'rough_entropy', 'lengthy', 'rel_length', 'in_shape', 'roundness', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7662037037037037,
# Recall: 0.8004484304932735,
# F1: 0.7794759825327511
#
# Reward: 0.7794759825327511
#
# Epoch 244
# Feature set: ['darker', 'gradient', 'reddish', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'rough', 'dominating_texture', 'texture_1', 'texture_4', 'texture_7', 'texture_9', 'rough_entropy', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_3', 'hu_moment_5', 'hu_moment_7'],
# Accuracy: 0.7534722222222222,
# Recall: 0.7802690582959642,
# F1: 0.7656765676567657
#
# Reward: 0.7656765676567657
#
# Epoch 245
# Feature set: ['darker', 'gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_4', 'color_bin_5', 'color_bin_6', 'color_entropy', 'rough', 'texture_0', 'texture_1', 'texture_3', 'texture_4', 'texture_8', 'texture_9', 'rough_entropy', 'lengthy', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7673611111111112,
# Recall: 0.8026905829596412,
# F1: 0.7808069792802618
#
# Reward: 0.7808069792802618
#
# Epoch 246
# Feature set: ['darker', 'gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_7', 'color_bin_9', 'rough', 'texture_1', 'texture_3', 'texture_4', 'texture_6', 'texture_9', 'rough_entropy', 'lengthy', 'in_shape', 'roundness', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7557870370370371,
# Recall: 0.7982062780269058,
# F1: 0.7713976164680391
#
# Reward: 0.7713976164680391
#
# Epoch 247
# Feature set: ['darker', 'gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_8', 'color_entropy', 'rough', 'texture_0', 'texture_1', 'texture_4', 'texture_7', 'texture_8', 'rough_entropy', 'lengthy', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_3', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7824074074074074,
# Recall: 0.8094170403587444,
# F1: 0.7934065934065935
#
# Reward: 0.7934065934065935
#
# Epoch 248
# Feature set: ['darker', 'gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_0', 'texture_1', 'texture_3', 'texture_4', 'texture_8', 'texture_9', 'rough_entropy', 'lengthy', 'rel_length', 'in_shape', 'roundness', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7662037037037037,
# Recall: 0.8004484304932735,
# F1: 0.7794759825327511
#
# Reward: 0.7794759825327511
#
# Epoch 249
# Feature set: ['darker', 'gradient', 'colorful', 'black_thin', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'rough', 'texture_1', 'texture_3', 'texture_5', 'texture_9', 'rough_entropy', 'lengthy', 'rel_length', 'in_shape', 'hu_moment_3', 'hu_moment_6', 'hu_moment_7'],
# Accuracy: 0.7662037037037037,
# Recall: 0.7959641255605381,
# F1: 0.7785087719298245
#
# Reward: 0.7785087719298245
# Best Feature set: ('darker', 'gradient', 'colorful', 'black_thin', 'dominating_color', 'color_bin_1', 'color_bin_2', 'color_bin_3', 'color_bin_5', 'color_bin_6', 'color_bin_7', 'color_bin_9', 'color_entropy', 'rough', 'texture_0', 'texture_1', 'texture_3', 'texture_4', 'texture_8', 'texture_9', 'rough_entropy', 'lengthy', 'lengthy_aspect_ratio', 'rel_length', 'in_shape', 'hu_moment_1', 'hu_moment_2', 'hu_moment_3', 'hu_moment_6', 'hu_moment_7')
# Reward: 0.7973713033953997
